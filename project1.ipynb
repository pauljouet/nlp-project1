# %%
from typing import List

# %%
import pandas as pd
import matplotlib
import re
import spacy
from spacy.tokenizer import Tokenizer
from spacy.tokens import Doc

# %%
nlp_fr = spacy.load("fr_core_news_sm")

# %% [markdown]
# The file is way too big to open it with a regular notepad. But we still need to know how it was formatted in order to import it:

# %% [markdown]
# cpt=0
# with open("openfoodfacts.csv") as f:
#     for line in f:
#         cpt+=1
#         print(line)
#         if cpt>5:
#             break

# %% [markdown]
# This allows us to see that the delimiter is the '\t' special character

# %% [markdown]
# df = pd.read_csv("openfoodfacts.csv", encoding = 'utf-8', delimiter="\t")

# %% [markdown]
# df

# %% [markdown]
# print(df.columns)

# %% [markdown]
# na_counts = df.isna().sum()

# %% [markdown]
# dict(na_counts)

# %% [markdown]
# df.loc[df['code'] == 225]

# %% [markdown]
# Apply a condition on every entry of a column, then filter the dataframe using the boolean array:

# %% [markdown]
# %%time
# df.loc[pd.Series(list(map(lambda f: "Prince Chocolat" in str(f), df['product_name'])))]

# %% [markdown]
# %%time
# df.loc[df['product_name'].str.contains("Prince Chocolat", na=False)]

# %% [markdown]
# df["ingredients_text"].loc[14454]#.split(" ")

# %% [markdown]
# from collections import defaultdict
# ingredients = defaultdict(int)
# for ingr in df["ingredients_text"].dropna():
#     for token in ingr.split(" "):
#         ingredients[token] += 1
#
# ingredients

# %% [markdown]
# packaging = defaultdict(int)
# for ingr in df["packaging_text"].dropna():
#     for token in ingr.split(" "):
#         packaging[token] += 1
#
# packaging

# %% [markdown]
# sorted(ingredients.items(), key=lambda k_v: k_v[1], reverse=True)

# %% [markdown]
# sorted(packaging.items(), key=lambda k_v: k_v[1], reverse=True)

# %% [markdown]
# df['countries_tags'].head(10)

# %% [markdown]
# countries_tags = defaultdict(int)
# for product in df["countries_tags"].dropna():
#     for country in product.split(","):
#         countries_tags[country] += 1
#
# countries_tags

# %% [markdown]
# fr_db_temp = df.loc[df['countries_tags'].str.contains("france", na=False)]
# fr_db_temp

# %% [markdown]
# relevant_columns = ['code', 'product_name', 'ingredients_text', 'packaging_text']

# %% [markdown]
# fr_db= fr_db_temp.dropna(subset= ['ingredients_text', 'product_name']).filter(items= relevant_columns)
# fr_db

# %% [markdown]
# ingredient_lists = list(fr_db['ingredients_text'])
# ingredient_lists

# %% [markdown]
# def custom_tokenizer(nlp):
#
#
#     special_cases = {":)": [{"ORTH": ":)"}]}
#     prefix_re = re.compile(r'''^[\[\("']''')
#     suffix_re = re.compile(r'''[\]\)"'\%]$''')
#     infix_re = re.compile(r'''[-~]''')
#     simple_url_re = re.compile(r'''^https?://''')
#
#     return Tokenizer(nlp.vocab, rules=special_cases,
#                                 prefix_search=prefix_re.search,
#                                 suffix_search=suffix_re.search,
#                                 infix_finditer=infix_re.finditer,
#                                 url_match=simple_url_re.match)
#
#
#
#
#
# nlp_fr = spacy.load("fr_core_news_sm")
# nlp_fr.tokenizer = custom_tokenizer(nlp_fr)
#
#
# my_str= u"PAIN BAGEL nature 44,2 % : farine de BLE, eau, huile végétale raffinée de colza, sucre, GLUTEN DE BLE, farine de MALT DE BLE, levure, sel, farine de SOJA, émulsifiants : E471, E322, agents de traitement de la farine : E300, E920. Garniture 55,8% : Aubergines grillées 41,4%, tomate 27.6%, FROMAGE FRAIS 13,8% (BABEURRE, CREME pasteurisée 13,3%, protéines de LAIT, acidifiant : acide citrique, sel, épaississant : farine de graines de caroube  conservateur : sorbate de potassium, arôme naturel), GRANA PADANO 13,8% (LAIT de vache cru, sel, présure, conservateur : lysozyme [protéine d'OEUF]), SAUCE PESTO 3,4% (huile de tournesol 42 %, basilic 29%, FROMAGES italiens 12,7% [grana padano, pecorino romano], farine de NOIX DE CAJOU, sel, BABEURRE en poudre/PIGNONS 9.8% fibres de BLE. acidifiant : acide lactique  antioxydant: acide ascorbique, ail). (% exprimés sur le garniture)"
# doc = nlp_fr(my_str)
# print([t.text for t in doc])
# print(doc.char_span(18, 24))
# indexes = [m.span() for m in re.finditer('[0-9]?[0-9] ?[,.]? ?[0-9]?[0-9]? ?%,?',my_str,flags=re.IGNORECASE)]
# print(indexes)
# for start, end in indexes:
#     print(doc.char_span(start, end+1))
#     print(doc.char_span(start, end))
#     if doc.char_span(start, end):
#         with doc.retokenize() as retokenizer:
#             retokenizer.merge(doc.char_span(start, end))
#
# print([t.text for t in doc])

# %% [markdown]
# def tokenize_ingredients(ingredient_lists: List[str]):
#     nlp = spacy.load("fr_core_news_sm", disable= ['tagger', 'parser', 'ner', 'lemmatizer'])
#     return list(nlp.pipe(ingredients))

# %% [markdown]
# tokenize_ingredients(ingredient_lists)

# %% [markdown]
# ## Language detection

# %%
from langdetect import detect

# %%
def try_detect(text):
    try:
        language = detect(text)
    except:
        language = "error"
        print("This throws an error:", text)
    return language

# %% [markdown]
# fr_db['detected_lang'] = fr_db['ingredients_text'].apply(try_detect)

# %% [markdown]
# fr_db2 = fr_db.loc[fr_db['detected_lang'].str.contains("fr", na=False)]

# %%
fr_db2 = pd.read_csv('filtered_openfoodfacts.csv', sep = '\t')

# %%
fr_db2
# Out:
#         Unnamed: 0           code                  product_name  \
# 0                6  0000000000100   moutarde au moût de raisin
# 1               25  0000000001199        Solène céréales poulet
# 2               41  0000000002264             Baguette Poitevin
# 3               52  0000000003827                Suedois saumon
# 4               58  0000000004510         Salade shaker taboulé
# ...            ...            ...                           ...
# 201107     1989475       99903336               Jus multifruits
# 201108     1989480  9991111111154   Compote à Boire Pomme Poire
# 201109     1989483       99911522                    Chipolatas
# 201110     1989531  9999200847366                  Choco pearls
# 201111     1989542  9999864004549           Boudin à l’ancienne
#
#                                          ingredients_text packaging_text  \
# 0       eau graines de téguments de moutarde vinaigre ...            NaN
# 1       antioxydant : érythorbate de sodium, colorant ...            NaN
# 2       baguette Poite vin Pain baguette 50,6%: farine...            NaN
# 3       Paln suédois 42,6%: farine de BLÉ, eau, farine...            NaN
# 4       Taboulé 76,2%, légumes 12%, huile de colza, se...            NaN
# ...                                                   ...            ...
# 201107  Jus de fruits à base de jus concentrés et puré...            NaN
# 201108  Pomme 71 %, poire 26 %, sucre 4%, antioxydant ...            NaN
# 201109  Viande de porc 92%(origine France) eau,sel,aro...            NaN
# 201110  sucre,beurre de cacao,poudre de jait.entier,fa...            NaN
# 201111  BIOCOOP BORDEAUX LAC distribue par les eleveur...            NaN
#
#        detected_lang
# 0                 fr
# 1                 fr
# 2                 fr
# 3                 fr
# 4                 fr
# ...              ...
# 201107            fr
# 201108            fr
# 201109            fr
# 201110            fr
# 201111            fr
#
# [201112 rows x 6 columns]

# %% [markdown]
# fr_db2.to_csv("filtered_openfoodfacts.csv", sep= "\t")

# %% [markdown]
# # Clustering

# %%
RELEVANT_COLUMNS = ['code', 'product_name', 'ingredients_text', 'packaging_text']

def country_filter(df) -> pd.DataFrame:
    """Filters products which do not exist in France"""
    return df.loc[df['countries_tags'].str.contains("france", na=False)]

def na_filter(df) -> pd.DataFrame:
    """Filters products without an ingredient list"""
    return df.dropna(subset= ['ingredients_text', 'product_name']).filter(items=RELEVANT_COLUMNS)

# ~45 minutes on 250k entries
def detect_language(text: str) -> str:
    """Returns the language of the text. 'fr' for French"""
    try:
        language = detect(text)
    except:
        language = "error"
        # print("This throws an error:", text)
    return language

def language_filter(df) -> pd.DataFrame:
    """Filters products whose ingredient list is not in French"""
    df['detected_lang'] = df['ingredients_text'].apply(detect_language)
    return df.loc[df['detected_lang'].str.contains("fr", na=False)]

def filter_df(df) -> pd.DataFrame:
    """Applies all filters on the DataFrame"""
    df1 = country_filter(df)
    df2 = na_filter(df1)
    return language_filter(df2)

def read_data():
    df = pd.read_csv('en.openfoodfacts.org.products.csv', encoding = 'utf-8', delimiter="\t")
    return filter_df(df).to_csv("filtered_openfoodfacts.csv", sep= "\t") 

def compute_similarity(str1, str2) -> float:
    """Compute similarity ratio between two strings."""
    return ratio(str1, str2)

def remove_accent(accented_string) -> str:
    return unidecode.unidecode(accented_string)

def remove_special_char(noisy_string) -> str:
    """remove special characters from noisy strings."""
    return noisy_string.translate(str.maketrans("", "", "*•"))

def replace_char(noisy_string) -> str:
    return noisy_string.replace("_", " ")

def split_numbers(transaction_description) -> list:
    """This function separate the numbers and words if there is no space in between.
    Return a list containing the words and numbers of the transaction description """
    transaction_description_unglued = []
    for word in transaction_description:
        split = re.split(r'(\d+/?\d+)', word)
        transaction_description_unglued += split
    transaction_description_unglued = list(filter(lambda a: a != '' and a is not None,
                                                  transaction_description_unglued))
    return transaction_description_unglued

def remove_pourcentage(ingredient) -> list:
    """This function remove any pourcentage from a string"""
    return re.sub(r'(\d+( |.)?(\d+)?( )?%)', "", ingredient)

def preprocess_ingredient_list(ingredient_list) -> str:
    """Pre-processing Pipeline"""
    #ingredient_list = replace_slash(ingredient_list)
    ingredient_list = replace_char(ingredient_list.lower())
    #ingredient_list = remove_accent(ingredient_list)
    return remove_special_char(ingredient_list)

def parse_ingredient(data, index) -> pd.DataFrame:
    """This is a function to extract 'root ingredients' from ingredient lists.
    A 'root ingredient' is defined as a basic component of an item 
    (similar to a factor in mathematics)"""
    columns = ["ingredient", "subingredient_1", "subingredient_2", "root_ingredient"]
    new_data = pd.DataFrame(columns=columns)
    ingredient = ''
    subingredient_1 = ''
    subingredient_2 = ''
    paren_count = 0
    last_delimiter = ''
    to_append = pd.DataFrame(columns=columns)
    for token in data:
        #print(str(token))
        #print()
        if str(token) in ['(', '[', ':']:
            last_delimiter = str(token)
            paren_count = paren_count + 1
        elif (str(token) in [')', ']']) or (str(token) in [','] and last_delimiter == ':'):
            last_delimiter = str(token)
            paren_count = paren_count - 1
            
        if str(token) in ['%', ]:
            if paren_count == 0:
                ingredient = ingredient + ' ' + str(token)
            elif paren_count == 1:   
                subingredient_1 = subingredient_1 + ' ' + str(token)
            elif paren_count == 2:
                subingredient_2 = subingredient_2 + ' ' + str(token) 
                
            if (ingredient != '') | (subingredient_1 != '') | (subingredient_2 != ''):
                new_data=new_data.append(to_append)
                to_append = pd.DataFrame({'ingredient': ingredient.strip(), 
                                          'subingredient_1': subingredient_1.strip(),
                                          'subingredient_2': subingredient_2.strip()},
                                         index=[index])
            if paren_count == 0:
                ingredient = ''
                subingredient_1 = ''
                subingredient_2 = ''
            elif paren_count == 1:
                subingredient_1 = ''
                subingredient_2 = ''
            elif paren_count == 2:
                subingredient_2 = ''
            
        elif str(token) not in ['(', ')', '[', ']', ',', ':', '.']:
            if paren_count == 0:
                ingredient = ingredient + ' ' + str(token)
            elif paren_count == 1:   
                subingredient_1 = subingredient_1 + ' ' + str(token)
            elif paren_count == 2:
                subingredient_2 = subingredient_2 + ' ' + str(token)        

        elif str(token) in [',', ':', '.']:
            #print(str(token))
            #print(ingredient)
            #print(subingredient_1)
            #print(subingredient_2)
            
            if (ingredient != '') | (subingredient_1 != '') | (subingredient_2 != ''):
                new_data=new_data.append(to_append)
                to_append = pd.DataFrame({'ingredient': ingredient.strip(), 
                                          'subingredient_1': subingredient_1.strip(),
                                          'subingredient_2': subingredient_2.strip()},
                                         index=[index])
            if paren_count == 0:
                ingredient = ''
                subingredient_1 = ''
                subingredient_2 = ''
            elif paren_count == 1:
                subingredient_1 = ''
                subingredient_2 = ''
            elif paren_count == 2:
                subingredient_2 = ''

    return new_data
    
def parse_ingredients(ingredients_dataframe) -> pd.DataFrame:
    new_data = pd.DataFrame()
    ingredients_dataframe["tokenized"] = [nlp_fr(preprocess_ingredient_list(text)) for text in ingredients_dataframe.ingredients]
    for i in range(len(ingredients_dataframe)):
        new_data = new_data.append(parse_ingredient(ingredients_dataframe.tokenized[i], i))
    return new_data

def parse_ingredients_test() -> pd.DataFrame:
    """Unit test"""
    data = pd.DataFrame(
    ["""45 % massepain (44% amandes, sucre, sirop de glucose et de fructose, eau), farine de blé, 10 % de raisins secs, 10% beurre, dextrose, sucre, 2% amandes, levure, œuf entier*, sel de cuisine, graisse de palme, amidon de blé. *d'élevage au sol. Peut contenir traces des arachides, de soja et des autres fruits à coque. 
     Conserver à l'abri de la chaleur et au sec.""",
     """BRIOCHE TRANCHÉE AU BEURRE ET À LA CRÉME FRAÏCHE Farine de blé française 53%, 
     sucre, beurre pâtissier 8%, œufs entiers frais 7.5%, eau, crème fraîche française 3.2%, 
     sirop de sucre inverti, sel, ez/ uten de blé, levure, arômes naturels (contient ainol), 
     émulsifiant (E471), protéines de lait, levwe désactivée, colorant (béta carotène).""", 
     """antioxydant : érythorbate de sodium, colorant : caramel - origine UE), 
     tomate 33,3%, MAYONNAISE 11,1% (huile de colza 78,9%, eau, jaunes d'OEUF 6%, 
     vinaigre, MOUTARDE [eau, graines de MOUTARDE, sel, vinaigre, curcuma], sel, 
     dextrose, stabilisateur : gomme de cellulose, conservateur : sorbate de potassium, colorant : ?-carotène, arôme)""",
     """MAItSON GAUCHER chocolat de couverture noir 64% chocolat de couverture lait 38,2% amandes,
     noisettes, pistaches, noix, raisins, écorces d'oranges"""], 
    columns = ["ingredients"])
    return parse_ingredients(data)

def get_ingredients(ingredients_dataframe):
    ingredients_dataframe = parse_ingredients(ingredients_dataframe)
    ingredients = []
    for i in range(len(ingredients_dataframe)):
        if ingredients_dataframe.iloc[i]["subingredient_2"] != "":
            ingredient = remove_pourcentage(ingredients_dataframe.iloc[i]["subingredient_2"])
            if ingredient != "":
                ingredients.append(ingredient)
        elif ingredients_dataframe.iloc[i]["subingredient_1"] != "":
            ingredient = remove_pourcentage(ingredients_dataframe.iloc[i]["subingredient_1"])
            if ingredient != "":
                ingredients.append(ingredient)
        elif ingredients_dataframe.iloc[i]["ingredient"] != "":   
            ingredient = remove_pourcentage(ingredients_dataframe.iloc[i]["ingredient"])
            if ingredient != "":
                ingredients.append(ingredient)
    return ingredients

def correct_ingredients(misspelled):
    spell = SpellChecker(language='fr')
    misspelled = misspelled.split()
    correction = ""
    for word in misspelled:
        correction += ' ' + spell.correction(word)
        print("original word: "+ word)
        print("corrected word: "+ spell.correction(word))
    return correction

def correct_ingredients_test():
    misspelled = """Sucre, blanc d’oeufs frais, poudre d’amande, 16.5%, beurre co/centré, 
    farine de_blé, oeufs frais. sirop de glucose-fructose, 
    stabilsant : glycérol, sel, poudres à lever : carbonatesdesodium-diphosphates (blé), arôm."""
    return correct_ingredients(preprocess_ingredient_list(misspelled))

# %%
for i in range(50):
    print(preprocess_ingredient_list(fr_db2.iloc[i]['ingredients_text']), '\n')
# Out:
# eau graines de téguments de moutarde vinaigre de vin rouge sel vin rouge sucre   moût de raisin (6.2%) oignons colorants extraits de carotte et extrait de paprika huile de tournesol son de moutarde sel (cette  moutarde  uniquement disponible chez courte paille)
#
# antioxydant : érythorbate de sodium, colorant : caramel - origine ue), tomate 33,3%, mayonnaise 11,1% (huile de colza 78,9%, eau, jaunes d'oeuf 6%, vinaigre, moutarde [eau, graines de moutarde, sel, vinaigre, curcuma], sel, dextrose, stabilisateur : gomme de cellulose, conservateur : sorbate de potassium, colorant : ?-carotène, arôme)
#
# baguette poite vin pain baguette 50,6%: farine de blé, eau, sel, levure, gluten, farine de ble maité, levure désactivée, acide ascorbique, garniture fromage mi-chèvre 46% (lait pasteurisé [95 0% lait de vache, 5 0% lait de chèvre], sel, ferments lactiques et daffinage, coagulant), tomate saladg 20,4%, huile d'olive i basilic 1%
#
# paln suédois 42,6%: farine de blé, eau, farine de seigle, sucre, huile de colza non hydrogénée, sirop de sucre, gluten de blé, sel, levure, levain en poudre (seigle), poudre à lever: e503, fructose, agent de traitement de la farine: e300, enzymes. garniture 57,4%: saumon atlantique, sel origine frane6,-fdorvège, éëòs%echlli), salade 29,6%, fromage blano.z,8% mg 14,8%, c)b'oulette
#
# taboulé 76,2%, légumes 12%, huile de colza, sel , menthe, jus de citron, sucre, conservateur : e202, arôme
#
# fromage blanc 7.896 mg 73,304, crème de marron vanillée 26,71 % (sucre. pur60 do châtaignes 38%, naturel do vanil!o).
#
# jus et purée d'abricots (50% minimun), eau, sucre.
#
# pain aux 6 céréqles 61,7 % farine (farine de blé, gluten de ble), eu, mélange 6 céréales-3 graines 17,6% (farine de ble complet, crème d'orge, farine d'avolne, farine de maïs, semoule de blé dur, graines cie millet, graines de lin, graines de sésame, farine de seigle), sel, levure, garniture 38,3% , coppa 30,2% (échine de porc, sel, dextrose de maïs, fenouil, arome naturel, sucre, conservateur: nitrate de potassium et nitrite de sodium -origine ue), salade 30,2%, tomate 30,2%, basilic 5%, huile d'olive.
#
# bâguette bressan pain baguette 46,2%,' farine de blé, eau, sel, levure, gluten, farine de ble malté, levure désactivée, acide ascorbique, garniture 53,8%: filet de poulet braisé 34,3% (filet de poulet 82%, eau, acidifiant : lactate de potassium et acétate de sodium, amidon modifié de manioc, sel, dextrose glucose, arômes, gélifiants e407ayam$xydant : érythèfbate de sodium, colorant : grafnel  origine ue), tomaten25x8%, oeuf dur 22,70/ , 'salade 17,20/ o
#
# glycérine d'origine naturelle (stabilisant), spiruline (spirulina maxima) d'origine naturelle, extrait de fruits de camu camu (myrciaria dubia), arôme naturel de citron vert.
#
# pâte à tartiner à la noisette de la région du piémont, avec édulcorant maltitol ingrédients: 46% noisette de la région du piémont, édulcorant maltitol (25%), lait en poudre écrémé, cacao en poudre, huile de colza, lécithine de tournesol. allergènes présents: lait, noisette
#
# riz précuit 40,4 % (eau, riz, huile de colza, sel), viande de dinde précuite 28,1 % (viande de dinde (origine france), eau, sirop de glucose, sel, stabilisant : e451i, amidon modifié de maïs), eau, carotte 4,7 %,  crème  fraîche épaisse 3,2 % champignon de paris 2,5 %, oignon, amidon modifié de maïs, arôme naturel, extrait de vin blanc 0.2 % [ sulfites ], sel.
#
# sucre, poudre de  lait , poudre au beurre ( lait ) (émulsifiant:e471), matière grasse végétale hydrogénée (coprah), jaune d' œuf  déshydraté 4 %, amidon de manioc, protéines de  lait , gélifiant: carraghénanes e407, sirop de glucose, arôme, colorants e102 - e110.
#
# lait de chèvre ferment &quot;produit issus de l'agriculture biologique
#
# sucre, chocolat 40% (cacao min 70%) (sucre, pâte de cacao, poudre de cacao, beurre de cacao, émulsifiant: lécithine de soja, arôme), glucose, gomme arabique, sirop de glucose, arome,agents d'enrobage (shellac,cire de carnauba,cire d'abeille), concentré (patate douce, radis), colorants :e102/e110/e122/e124/ el 29/e131/ el 32/ el 331e 171. peut contenir des traces de fruits a coques colorants e102/e110/e122/e124/e12!) peuvent avoir des 'ets indésirables sur l'activité et l'attention chez les enfants. nutritionelles/10gg : valeurs energél:iques : 1974kj/
#
# rucola à l'huile d'olive vierge extra 39% (rucola 52%, huile d'olive vierge extra 41,5%, sel),  noix de cajou , huile d'olive vierge extra, parmigiano reggiano a.o.p.  ( lait , sel, présure), ail. (ingrédients biologiques).
#
# artichauts 70%, huile d'olive vierge extra, sel, régulateur d'acidité : e330. (ingrédients biologiques)
#
# lentilles vertes
#
# eau gazéifiée, sirop de maïs à haute teneur en fructose, colorant : caramel, conservateur : e211, arômes naturels et artificiels, moussant : e999.
#
# sucre, farine de  blé , graisse et huiles végétales (karité, colza et tournesol), cacao maigre en poudre 7%, sirop de glucose, dextrine,  beurre  concentré,  oeufs , pâte de  noisette , pâte de cacao, émulsifiants : lécithines (colza et tournesol), sel, poudre à lever : carbonates d'ammonium, arômes.
#
# eau gazéifiée, sirop de mais riche en fructose (produit à partir de mats génétiquement modifié) e150a, colorant de conservateur benzoate sodium, exhausteur de goût colorants naturel et artificiel, 9 humectant : extrait de auillaia.
#
# flocons de pommes 76 % (pomme, amidon de maïs, saccharose, émulsifiant : lécithine de tournesol), sucre.
#
# thé noir aromatisé à la fleur de violette et parsemé de bleuets
#
# thé noir de chine, zestes d'oranges 7,5 %, arômes naturels (cannelle 4,7 %, orange 4,7 %, poudre de cannelle 3,9 %).
#
# sirop saveur pistache 5 cl : sirop 99,16 % (sucre cristallisé, eau), arôme, acidifiant : acide citrique e330, denrée alimentaire colorante (concentrés de carthame, pomme), colorant : mélange d'additifs : e171, e211, e131. sirop saveur framboise 5 cl : sirop 93,98 % (sucre, eau), denrée alimentaire colorante (concentrés de patate douce, cerise, pomme, radis, carthame), arôme naturel, acidifiant : acide citrique e330, colorant : mélange d'additifs : e171, e211. sirop saveur citron 5 cl : sirop 98,86 % (sucre cristallisé, eau), arôme naturel, acidifiant : acide citrique e330, denrée alimentaire colorante (concentré de pomme, carthame), colorant : mélange d'additifs : e171, e211. sirop saveur violette 4 cl : sirop 88,40 % (sucre, eau), arôme, acidifiant : acide citrique e330, denrée alimentaire colorante (concentré de cassis, carotte, pomme), colorant : mélange d'additifs : e131, e211, e171.
#
# sucre. sirop de glucose, eau stabilisant e471, acide citrique e330, conservateur e202.
#
# farine de blé (gluten), sucre de canne, pépites de chocolat n ir à 50 % de cacao minimum 19,9 % (pâte de cacao, sucre de canne, beurre de cacao, émulsifiant : lécithine de soja), cacao biologique en poudre 7,9 0%, caramel tendre d'isigny au beurre salé 5,9 % (sirop de glucose, sucre, lait entier en salé isigny aop (lait), eau, sel de guérande, arôme naturel vanille, poudre à lever : bicarbonate de soude, émulsifiant : sucroesters d'acides gras), bicarbonate de soude, diphosphate dissodique. peut contenir des traces de fruits à coques moutjrde, sésame, gluten, lait, œuf, soja et sulfites.
#
# velours en s ray dessert, passé préalableme bien agiter avant emploi. l'on souhaite traiter à ure distance cz de cacao, colorants : e171, el)) des traces de lait, soja, fruits à : ne pas ingérer direce&lt; sin aler les vapeurs directeme,: viter l'emploi excessif utiliser sev zk. ne pas perforer ni brûler, lamer avers une flamme ou garder la bombe hors de la tfdernent s'il est complétement f est possible.dans des ne pas' avaler tel quel. un endroit sec et frais, à te du soleil elauw in velours dessert dat net ult de d eq - k.dden voor cjebrujk.
#
# sucre (74 %), sirop de glucose, huiles et graisses végétales (palme, tournesol, illipé), sirop de sucre inverti, stabilisant : e420ii, eau, humectant : e422, épaississant : e415, émulsifiant : e471, acidifiant : e330, arôme, conservateur.
#
# ingrédients: sucre de canne (96%), blanc d'œuf, eau, stabilisant : e336, épaississant : e414, arôme naturel de vanille, carthame, colorants : e153, e133, e171, e132, e120.
#
# farine de riz, sucre, amidon de maïs, cacao (4.8%), farine de noisette arômes, émulsifiants esters polyglycériques d'acides gras, monooléate de polyoxyéthylène de sorbitane ; épaississants : gomme guar, carboxyméthylcellu- lose ; poudre à lever : carbonate de sodium; correcteur d'acidité . glucono-delta-lactine, sel. peut contenir des traces de lait œufs, soja et autres fruits à coque.
#
# fr - chocolat lait (40% min. caéao) avec noisettes : beurre de cacao, lait enfer en poudre, sucre de cannet sucre, pâte de cacao, noisettes(4%), émulsifiant : lécithine de (e322), arôme naturel de noisette, arôme naturel de vanille, arôme naturel de nougat sel. peut contenir des fraces de glutenzsoja, conseils de conservation : a conserver entre 15 c et 200c, à l'abri de la chaleur et de l'humidité. plongez et mélangez la cuillère&ns une tasse de lait chaud.
#
# pâtes à l'épeautre - rêve de neptune - spelt neptunes dream (500g e) ingrédients ingrediënten speltbloem, tomaat, spinazie, biet&quot;, spirulina farine d'épeautre , tomates , épinards , betteraves , spiruline
#
# vin rouge, sec. contient des  sulfites .
#
# farine: ble, soja huiles et graisses vegetales (palme, coprah, colza, karite, tournesol); eau; sucre dextrose; poudre de cacao degraissee (1, 5%); levure; lactoserum en poudre (lait) , sel poudre a lever : e450i, e500i; emulsifiant: e471, e481, e472e ; poudre de lait ecreme;aromes. produit dans une usine qui utilise soja, lait, oeufs, fruits a coque. allergènes: ble lait soja produit congelé, ne pas recongeler
#
# édulcorants (sorbitol, aspartame), agent d'enrobage (sels de magnésium d'acides), extraits des eaux de vichy (0,3 %), arôme. consommation excessive peut avoir des effets laxatifs. contient une source de phénylalanine.
#
# passiflore 20g, aubépine sf 20g, eschscholtzia 20g aspérule odorante 20g, mélilot 10g, oranger fe 10g
#
# chocolat au lait (sucre, beurre de cacao, chocolat, lait,lactose [lait])
#
# chocolat au lait beurre cacao, lait éereme. grasse du lait, lactose, émulsifiants : lécithine de et sucre, dextroses dans an endroit sec et frais. se conserve jours après
#
# nichons ('ttc paysanne igres-doux deux fois kuhne leur et leur croquant' ils sont préparés sclon la g 3 kijhnc, on n'y résiste pas ! cornichons pasteurisés cornichons, cou, vinaigre. couvcrdc, après ouvcrtorc, conscrvcr ct consommer rapidement'
#
# sucre,  arachide , pâte de cacao, lait écrémé en poudre,  lactose  et protéine de  lait , matières grasses végétales, beurre de cacao,  beurre  concentré, amidon, sirop de glucose, iécithine de  soja , gomme arabique, colorant, arôme, sel, huile végétale.
#
# eau gazéifiée, sucre, colorant caramel e150d, acidifiant : acide phosphorique, arômes (dont : extraits naturels de végétaux, caféine)
#
# vinaigre d'alcool, eau, huile de pépins de raisin 22%, sucre, farine de maïs,  moutarde , jaune d’ œuf  pasteurisé 3%, sel, colorant : riboflavine.
#
# marmelade de citrons et de citrons verts - 454g inqrédlents: sirop de glucose-fructose, citrons (10%), citrons verts (10%), sucre gélifiant: pectine, acide citrique, correcteur : dacidité. citrates de sodium colorants. complexes cuivre - chlorophyllines, lutéine préparé avec 20g de fruits pour 100g de marmelade condltlons de conservation et diutilisation
#
# sucre, orahges agent ',l'lfiant : egulateur citrique, citrate de .mdiurn ; huile dorange douce. proté ttnsommer de preiçtt1ite avant l&quot; voir sir te a endroit frais et x, à l'abri de la lumière. auès ouverture : a au refrigerateur et à conmmmer dans les 6 emaines qui 100g) : energie : 1265kj/2%kcal, matière gras : o.lg dont %turees? glucides : 71.9g dont wcre 67.4g ; fibre 3.9g ; protéine : 0.6g , : convient aux végetar'lens vegans et coeliaques produit gluten olttrlbué par ?.ijs ndukmabke
#
# eau azéifiée ; sucre : colorant : acidifiant : e338 ; arômes naturels (dont extraits végétau et caféine). a consommer de préférence avant le : voir
#
# chou blanc 50%, garniture 50% (viande de porc 29%, viande bovine 28%, chou blanc, eau, farine de blé, oignons, sel iodé (sel, iodate de potassium), épices (poivre blanc, coriandre, piment chili, carvi), levure, dextrose),
#
# nom scientifique : pollachius virens, pêché en : atlantique nord-est (islande), catégorie d'engin de pêche : chaluts
#
# filet de saumon
#
# pomme de terre 83 %, amidon de pomme de terre, huile de palme,  œuf , épices (oignon, curcuma), farine de riz, sel, farine de  blé , dextrose.

# %%
def remove_special_characters(text: str):
    text = text.translate(str.maketrans("", "", r"*•&\=+_~#²<>!?"))
    return text

# %%
def test_remove_special_characters():
    print(remove_special_characters("ndgn*dbs•z&\\\/=kvcxng+_sbdbfs~#²sbbs<sb> sbcdjbokdsc"))
    
test_remove_special_characters()
# Out:
# ndgndbsz/kvcxngsbdbfssbbssb sbcdjbokdsc

# %%
import unidecode
def remove_accent(accented_string) -> str:
    return unidecode.unidecode(accented_string)

# %%
INFIX_DELIMITERS = {
    ':': ' ', 
    '-': ' ', 
    ',': ' ', 
    ';':' ', 
    '.':' ', 
    "'": ' ',
    "/": ' ',
    "%": ' ',
    'œ': 'oe'}
def replace_infix(text):
    for delimiter in INFIX_DELIMITERS.keys():
        text = text.replace(delimiter, INFIX_DELIMITERS[delimiter])
    return text

# %%
def test_replace_infix():
    print(replace_infix("je mange des œufs-mimosas..."))
test_replace_infix()
# Out:
# je mange des oeufs mimosas

# %%
def remove_percentage(text) -> list:
    """This function remove any percentage from a string"""
    return re.sub(r'(\d+( |.)?(\d+)?( )?%)', "", text)

# %%
def test_remove_percentage():
    print(remove_percentage("acide15.1%, nitrate15,1%, ammoniac 15.1%, levure 15,1%, banane 15.6 %, orange 20,8 %, fruit 25 %, cassis 15.7%ù kiwi 7815%, trucmuche 15 . 1 % autre 15 , 1 % jaipludinspi 15 . 1% gngn 15 , 1% "))
    
test_remove_percentage()
# Out:
# acide, nitrate, ammoniac , levure , banane , orange , fruit , cassis ù kiwi , trucmuche 15 .  autre 15 ,  jaipludinspi 15 .  gngn 15 ,

# %%
def remove_numbers(tokens):
    return list(filter(lambda x: not x.isnumeric(), tokens))

# %%
def test_remove_numbers():
    print(remove_numbers("dfhdi 15 dijv 75 vjsoi 14.7, dijviv e205, dvov15, 14, 14,7    19, kd".split()))
test_remove_numbers()
# Out:
# ['dfhdi', 'dijv', 'vjsoi', '14.7,', 'dijviv', 'e205,', 'dvov15,', '14,', '14,7', '19,', 'kd']

# %%
def flatten_tokens(tokens):
    flat_tokens = []
    for token in tokens:
        if type(token) == list:
            flat_tokens += token
        else:
            flat_tokens.append(token)
    return flat_tokens

# %%
PREFIX_DELIMITERS = ['(', '[']
SUFFIX_DELIMITERS = [')', ']', '.', ',', ';', ':']

def split_punct_prefix(tokens):
    for i in range(len(tokens)):
         if len(tokens[i]) > 1:   
            if tokens[i][0] in PREFIX_DELIMITERS:
                tokens[i] = [tokens[i][0], tokens[i][1:]]
    # print(tokens)
    return flatten_tokens(tokens)

def split_punct_suffix(tokens):
    # print("len:", len(tokens), "suffix:", tokens)
    for i in range(len(tokens)):
        # print(tokens[i])
        if len(tokens[i]) > 1:
            if tokens[i][-1] in SUFFIX_DELIMITERS:
                tokens[i] = [tokens[i][:-1], tokens[i][-1]]
    return flatten_tokens(tokens)

def split_puncts(tokens):
    return split_punct_suffix(split_punct_prefix(tokens))

split_puncts("hello, world! (hihi)".split())
# Out:
# ['hello', ',', 'world!', '(', 'hihi', ')']

# %%
def tokenizer(ingr: str):
    ingr1 = remove_special_characters(ingr.lower())
    ingr2 = remove_accent(ingr1)
    ingr3 = remove_percentage(ingr2)
    ingr4 = replace_infix(ingr3)
    ingr_list = remove_numbers(ingr4.split())
    ingr_list1 = list(filter(lambda tok: tok != '', ingr_list))
    # print("tokenizer:", ingr_list1)
    return split_puncts(ingr_list1)

# %%
from nltk.stem.snowball import SnowballStemmer
def tokenizer2(ingr: str):
    ingr = ingr.lower().translate(str.maketrans("", "", r"*•&\/=+_~#²<>!?{}()[]."))
    ingr = remove_accent(ingr)
    ingr = remove_percentage(ingr)
    ingr = replace_infix(ingr)
    toks = "".join(filter(lambda x: not x.isdigit(), ingr)).split()
    toks = list(filter(lambda tok: len(tok) > 2, toks))
    stemmer = SnowballStemmer(language = "french")
    return list(map(stemmer.stem, toks))

# %%
# %%time
test_list = []
for i in range(len(fr_db2)):
    test_list.append(tokenizer2(fr_db2.iloc[i]['ingredients_text']))
    
test_list
# Out:
# Wall time: 1min 31s
# [['eau',
#   'grain',
#   'tegu',
#   'moutard',
#   'vinaigr',
#   'vin',
#   'roug',
#   'sel',
#   'vin',
#   'roug',
#   'sucr',
#   'mout',
#   'raisin',
#   'oignon',
#   'color',
#   'extrait',
#   'carott',
#   'extrait',
#   'paprik',
#   'huil',
#   'tournesol',
#   'son',
#   'moutard',
#   'sel',
#   'cet',
#   'moutard',
#   'uniqu',
#   'disponibl',
#   'chez',
#   'court',
#   'paill'],
#  ['antioxyd',
#   'erythorbat',
#   'sodium',
#   'color',
#   'caramel',
#   'origin',
#   'tomat',
#   'mayonnais',
#   'huil',
#   'colz',
#   'eau',
#   'jaun',
#   'oeuf',
#   'vinaigr',
#   'moutard',
#   'eau',
#   'grain',
#   'moutard',
#   'sel',
#   'vinaigr',
#   'curcum',
#   'sel',
#   'dextros',
#   'stabilis',
#   'gomm',
#   'cellulos',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'color',
#   'caroten',
#   'arom'],
#  ['baguet',
#   'poit',
#   'vin',
#   'pain',
#   'baguet',
#   'farin',
#   'ble',
#   'eau',
#   'sel',
#   'levur',
#   'gluten',
#   'farin',
#   'ble',
#   'mait',
#   'levur',
#   'desactive',
#   'acid',
#   'ascorb',
#   'garnitur',
#   'fromag',
#   'chevr',
#   'lait',
#   'pasteuris',
#   'lait',
#   'vach',
#   'lait',
#   'chevr',
#   'sel',
#   'ferment',
#   'lactiqu',
#   'daffinag',
#   'coagul',
#   'tomat',
#   'saladg',
#   'huil',
#   'oliv',
#   'basilic'],
#  ['paln',
#   'suedois',
#   'farin',
#   'ble',
#   'eau',
#   'farin',
#   'seigl',
#   'sucr',
#   'huil',
#   'colz',
#   'non',
#   'hydrogene',
#   'sirop',
#   'sucr',
#   'gluten',
#   'ble',
#   'sel',
#   'levur',
#   'levain',
#   'poudr',
#   'seigl',
#   'poudr',
#   'lev',
#   'fructos',
#   'agent',
#   'trait',
#   'farin',
#   'enzym',
#   'garnitur',
#   'saumon',
#   'atlant',
#   'sel',
#   'origin',
#   'fran',
#   'fdorveg',
#   'eeos',
#   'echlli',
#   'salad',
#   'fromag',
#   'blanoz',
#   'oulet'],
#  ['taboul',
#   'legum',
#   'huil',
#   'colz',
#   'sel',
#   'menth',
#   'jus',
#   'citron',
#   'sucr',
#   'conserv',
#   'arom'],
#  ['fromag',
#   'blanc',
#   'crem',
#   'marron',
#   'vanille',
#   'sucr',
#   'pur',
#   'chataign',
#   'naturel',
#   'vanilo'],
#  ['jus', 'pure', 'abricot', 'minimun', 'eau', 'sucr'],
#  ['pain',
#   'aux',
#   'cereql',
#   'farin',
#   'farin',
#   'ble',
#   'gluten',
#   'ble',
#   'melang',
#   'cereal',
#   'rain',
#   'farin',
#   'ble',
#   'complet',
#   'crem',
#   'orge',
#   'farin',
#   'avoln',
#   'farin',
#   'mais',
#   'semoul',
#   'ble',
#   'dur',
#   'grain',
#   'ci',
#   'millet',
#   'grain',
#   'lin',
#   'grain',
#   'sesam',
#   'farin',
#   'seigl',
#   'sel',
#   'levur',
#   'garnitur',
#   'copp',
#   'echin',
#   'porc',
#   'sel',
#   'dextros',
#   'mais',
#   'fenouil',
#   'arom',
#   'naturel',
#   'sucr',
#   'conserv',
#   'nitrat',
#   'potassium',
#   'nitrit',
#   'sodium',
#   'origin',
#   'salad',
#   'tomat',
#   'basilic',
#   'huil',
#   'oliv'],
#  ['baguet',
#   'bressan',
#   'pain',
#   'baguet',
#   'farin',
#   'ble',
#   'eau',
#   'sel',
#   'levur',
#   'gluten',
#   'farin',
#   'ble',
#   'malt',
#   'levur',
#   'desactive',
#   'acid',
#   'ascorb',
#   'garnitur',
#   'filet',
#   'poulet',
#   'brais',
#   'filet',
#   'poulet',
#   'eau',
#   'acidifi',
#   'lactat',
#   'potassium',
#   'acetat',
#   'sodium',
#   'amidon',
#   'modif',
#   'manioc',
#   'sel',
#   'dextros',
#   'glucos',
#   'arom',
#   'gelifi',
#   'eayam$xyd',
#   'erythefbat',
#   'sodium',
#   'color',
#   'grafnel',
#   'origin',
#   'tomatenx',
#   'oeuf',
#   'dur',
#   'salad'],
#  ['glycerin',
#   'origin',
#   'naturel',
#   'stabilis',
#   'spirulin',
#   'spirulin',
#   'maxim',
#   'origin',
#   'naturel',
#   'extrait',
#   'fruit',
#   'camu',
#   'camu',
#   'myrciari',
#   'dubi',
#   'arom',
#   'naturel',
#   'citron',
#   'vert'],
#  ['pat',
#   'tartin',
#   'noiset',
#   'region',
#   'piemont',
#   'avec',
#   'edulcor',
#   'maltitol',
#   'ingredient',
#   'noiset',
#   'region',
#   'piemont',
#   'edulcor',
#   'maltitol',
#   'lait',
#   'poudr',
#   'ecrem',
#   'cacao',
#   'poudr',
#   'huil',
#   'colz',
#   'lecithin',
#   'tournesol',
#   'allergen',
#   'present',
#   'lait',
#   'noiset'],
#  ['riz',
#   'precuit',
#   'eau',
#   'riz',
#   'huil',
#   'colz',
#   'sel',
#   'viand',
#   'dind',
#   'precuit',
#   'viand',
#   'dind',
#   'origin',
#   'franc',
#   'eau',
#   'sirop',
#   'glucos',
#   'sel',
#   'stabilis',
#   'amidon',
#   'modif',
#   'mais',
#   'eau',
#   'carott',
#   'crem',
#   'fraich',
#   'epaiss',
#   'champignon',
#   'paris',
#   'oignon',
#   'amidon',
#   'modif',
#   'mais',
#   'arom',
#   'naturel',
#   'extrait',
#   'vin',
#   'blanc',
#   'sulfit',
#   'sel'],
#  ['sucr',
#   'poudr',
#   'lait',
#   'poudr',
#   'beurr',
#   'lait',
#   'emulsifi',
#   'matier',
#   'grass',
#   'vegetal',
#   'hydrogene',
#   'coprah',
#   'jaun',
#   'oeuf',
#   'deshydrat',
#   'amidon',
#   'manioc',
#   'protein',
#   'lait',
#   'gelifi',
#   'carraghenan',
#   'sirop',
#   'glucos',
#   'arom',
#   'color'],
#  ['lait',
#   'chevr',
#   'ferment',
#   'quot',
#   'produit',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['sucr',
#   'chocolat',
#   'cacao',
#   'min',
#   'sucr',
#   'pat',
#   'cacao',
#   'poudr',
#   'cacao',
#   'beurr',
#   'cacao',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'arom',
#   'glucos',
#   'gomm',
#   'arab',
#   'sirop',
#   'glucos',
#   'arom',
#   'agent',
#   'enrobag',
#   'shellac',
#   'cir',
#   'carnaub',
#   'cir',
#   'abeil',
#   'concentr',
#   'patat',
#   'douc',
#   'rad',
#   'color',
#   'eee',
#   'peut',
#   'conten',
#   'de',
#   'trac',
#   'fruit',
#   'coqu',
#   'color',
#   'eeee',
#   'peuvent',
#   'avoir',
#   'de',
#   'et',
#   'indesir',
#   'sur',
#   'activit',
#   'attent',
#   'chez',
#   'le',
#   'enfant',
#   'nutritionel',
#   'valeur',
#   'energel',
#   'ique'],
#  ['rucol',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'rucol',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'sel',
#   'noix',
#   'cajou',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'parmigiano',
#   'reggiano',
#   'aop',
#   'lait',
#   'sel',
#   'presur',
#   'ail',
#   'ingredient',
#   'biolog'],
#  ['artichaut',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'sel',
#   'regul',
#   'acidit',
#   'ingredient',
#   'biolog'],
#  ['lentill', 'vert'],
#  ['eau',
#   'gazeifie',
#   'sirop',
#   'mais',
#   'haut',
#   'teneur',
#   'fructos',
#   'color',
#   'caramel',
#   'conserv',
#   'arom',
#   'naturel',
#   'artificiel',
#   'mouss'],
#  ['sucr',
#   'farin',
#   'ble',
#   'graiss',
#   'huil',
#   'vegetal',
#   'karit',
#   'colz',
#   'tournesol',
#   'cacao',
#   'maigr',
#   'poudr',
#   'sirop',
#   'glucos',
#   'dextrin',
#   'beurr',
#   'concentr',
#   'oeuf',
#   'pat',
#   'noiset',
#   'pat',
#   'cacao',
#   'emulsifi',
#   'lecithin',
#   'colz',
#   'tournesol',
#   'sel',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'arom'],
#  ['eau',
#   'gazeifie',
#   'sirop',
#   'mais',
#   'rich',
#   'fructos',
#   'produit',
#   'part',
#   'mat',
#   'genet',
#   'modif',
#   'color',
#   'conserv',
#   'benzoat',
#   'sodium',
#   'exhausteur',
#   'gout',
#   'color',
#   'naturel',
#   'artificiel',
#   'humect',
#   'extrait',
#   'deauillai'],
#  ['flocon',
#   'pomm',
#   'pomm',
#   'amidon',
#   'mais',
#   'saccharos',
#   'emulsifi',
#   'lecithin',
#   'tournesol',
#   'sucr'],
#  ['the', 'noir', 'aromatis', 'fleur', 'violet', 'parsem', 'bleuet'],
#  ['the',
#   'noir',
#   'chin',
#   'zest',
#   'orang',
#   'arom',
#   'naturel',
#   'cannel',
#   'orang',
#   'poudr',
#   'cannel'],
#  ['sirop',
#   'saveur',
#   'pistach',
#   'sirop',
#   'sucr',
#   'cristallis',
#   'eau',
#   'arom',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'denre',
#   'alimentair',
#   'color',
#   'concentr',
#   'cartham',
#   'pomm',
#   'color',
#   'melang',
#   'addit',
#   'sirop',
#   'saveur',
#   'frambois',
#   'sirop',
#   'sucr',
#   'eau',
#   'denre',
#   'alimentair',
#   'color',
#   'concentr',
#   'patat',
#   'douc',
#   'ceris',
#   'pomm',
#   'rad',
#   'cartham',
#   'arom',
#   'naturel',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'color',
#   'melang',
#   'addit',
#   'sirop',
#   'saveur',
#   'citron',
#   'sirop',
#   'sucr',
#   'cristallis',
#   'eau',
#   'arom',
#   'naturel',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'denre',
#   'alimentair',
#   'color',
#   'concentr',
#   'pomm',
#   'cartham',
#   'color',
#   'melang',
#   'addit',
#   'sirop',
#   'saveur',
#   'violet',
#   'sirop',
#   'sucr',
#   'eau',
#   'arom',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'denre',
#   'alimentair',
#   'color',
#   'concentr',
#   'cass',
#   'carott',
#   'pomm',
#   'color',
#   'melang',
#   'addit'],
#  ['sucr', 'sirop', 'glucos', 'eau', 'stabilis', 'acid', 'citriqu', 'conserv'],
#  ['farin',
#   'ble',
#   'gluten',
#   'sucr',
#   'cann',
#   'pepit',
#   'chocolat',
#   'cacao',
#   'minimum',
#   'pat',
#   'cacao',
#   'sucr',
#   'cann',
#   'beurr',
#   'cacao',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'cacao',
#   'biolog',
#   'poudr',
#   'caramel',
#   'tendr',
#   'isigny',
#   'beurr',
#   'sal',
#   'sirop',
#   'glucos',
#   'sucr',
#   'lait',
#   'enti',
#   'sal',
#   'isigny',
#   'aop',
#   'lait',
#   'eau',
#   'sel',
#   'guerand',
#   'arom',
#   'naturel',
#   'vanill',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'emulsifi',
#   'sucroester',
#   'acid',
#   'gras',
#   'bicarbonat',
#   'soud',
#   'diphosphat',
#   'dissod',
#   'peut',
#   'conten',
#   'de',
#   'trac',
#   'fruit',
#   'coqu',
#   'moutjrd',
#   'sesam',
#   'gluten',
#   'lait',
#   'oeuf',
#   'soj',
#   'sulfit'],
#  ['velour',
#   'ray',
#   'dessert',
#   'pass',
#   'prealablem',
#   'bien',
#   'agit',
#   'avant',
#   'emploi',
#   'souhait',
#   'trait',
#   'ure',
#   'distanc',
#   'cacao',
#   'color',
#   'de',
#   'trac',
#   'lait',
#   'soj',
#   'fruit',
#   'pas',
#   'inger',
#   'direcelt',
#   'sin',
#   'aler',
#   'le',
#   'vapeur',
#   'directem',
#   'vit',
#   'emploi',
#   'excess',
#   'utilis',
#   'sev',
#   'pas',
#   'perfor',
#   'brul',
#   'lam',
#   'aver',
#   'une',
#   'flamm',
#   'gard',
#   'bomb',
#   'hor',
#   'tfdernent',
#   'est',
#   'complet',
#   'est',
#   'possibledan',
#   'de',
#   'pas',
#   'aval',
#   'tel',
#   'quel',
#   'endroit',
#   'sec',
#   'frais',
#   'soleil',
#   'elauw',
#   'velour',
#   'dessert',
#   'dat',
#   'net',
#   'ult',
#   'kdden',
#   'voor',
#   'cjebrujk'],
#  ['sucr',
#   'sirop',
#   'glucos',
#   'huil',
#   'graiss',
#   'vegetal',
#   'palm',
#   'tournesol',
#   'illip',
#   'sirop',
#   'sucr',
#   'invert',
#   'stabilis',
#   'eii',
#   'eau',
#   'humect',
#   'epaiss',
#   'emulsifi',
#   'acidifi',
#   'arom',
#   'conserv'],
#  ['ingredient',
#   'sucr',
#   'cann',
#   'blanc',
#   'oeuf',
#   'eau',
#   'stabilis',
#   'epaiss',
#   'arom',
#   'naturel',
#   'vanill',
#   'cartham',
#   'color'],
#  ['farin',
#   'riz',
#   'sucr',
#   'amidon',
#   'mais',
#   'cacao',
#   'farin',
#   'noiset',
#   'arom',
#   'emulsifi',
#   'ester',
#   'polyglycer',
#   'acid',
#   'gras',
#   'monooleat',
#   'polyoxyethylen',
#   'sorbitan',
#   'epaiss',
#   'gomm',
#   'guar',
#   'carboxymethylcellu',
#   'los',
#   'poudr',
#   'lev',
#   'carbonat',
#   'sodium',
#   'correcteur',
#   'acidit',
#   'glucono',
#   'delt',
#   'lactin',
#   'sel',
#   'peut',
#   'conten',
#   'de',
#   'trac',
#   'lait',
#   'oeuf',
#   'soj',
#   'autr',
#   'fruit',
#   'coqu'],
#  ['chocolat',
#   'lait',
#   'min',
#   'caeao',
#   'avec',
#   'noiset',
#   'beurr',
#   'cacao',
#   'lait',
#   'enfer',
#   'poudr',
#   'sucr',
#   'cannet',
#   'sucr',
#   'pat',
#   'cacao',
#   'noiset',
#   'emulsifi',
#   'lecithin',
#   'arom',
#   'naturel',
#   'noiset',
#   'arom',
#   'naturel',
#   'vanill',
#   'arom',
#   'naturel',
#   'nougat',
#   'sel',
#   'peut',
#   'conten',
#   'de',
#   'frac',
#   'glutenzsoj',
#   'conseil',
#   'conserv',
#   'conserv',
#   'entre',
#   'abri',
#   'chaleur',
#   'humidit',
#   'plong',
#   'melang',
#   'cuilleren',
#   'une',
#   'tass',
#   'lait',
#   'chaud'],
#  ['pat',
#   'epeautr',
#   'rev',
#   'neptun',
#   'spelt',
#   'neptun',
#   'dream',
#   'ingredient',
#   'ingredienten',
#   'speltbloem',
#   'tomaat',
#   'spinaz',
#   'bietquot',
#   'spirulin',
#   'farin',
#   'epeautr',
#   'tomat',
#   'epinard',
#   'betterav',
#   'spirulin'],
#  ['vin', 'roug', 'sec', 'contient', 'de', 'sulfit'],
#  ['farin',
#   'ble',
#   'soj',
#   'huil',
#   'graiss',
#   'vegetal',
#   'palm',
#   'coprah',
#   'colz',
#   'karit',
#   'tournesol',
#   'eau',
#   'sucr',
#   'dextros',
#   'poudr',
#   'cacao',
#   'degraisse',
#   'levur',
#   'lactoserum',
#   'poudr',
#   'lait',
#   'sel',
#   'poudr',
#   'lev',
#   'emulsifi',
#   'poudr',
#   'lait',
#   'ecrem',
#   'arom',
#   'produit',
#   'dan',
#   'une',
#   'usin',
#   'qui',
#   'utilis',
#   'soj',
#   'lait',
#   'oeuf',
#   'fruit',
#   'coqu',
#   'allergen',
#   'ble',
#   'lait',
#   'soj',
#   'produit',
#   'congel',
#   'pas',
#   'recongel'],
#  ['edulcor',
#   'sorbitol',
#   'aspartam',
#   'agent',
#   'enrobag',
#   'sel',
#   'magnesium',
#   'acid',
#   'extrait',
#   'de',
#   'eau',
#   'vichy',
#   'arom',
#   'consomm',
#   'excess',
#   'peut',
#   'avoir',
#   'de',
#   'effet',
#   'laxat',
#   'contient',
#   'une',
#   'sourc',
#   'phenylalanin'],
#  ['passiflor',
#   'aubepin',
#   'eschscholtzi',
#   'asperul',
#   'odor',
#   'melilot',
#   'orang'],
#  ['chocolat',
#   'lait',
#   'sucr',
#   'beurr',
#   'cacao',
#   'chocolat',
#   'lait',
#   'lactos',
#   'lait'],
#  ['chocolat',
#   'lait',
#   'beurr',
#   'cacao',
#   'lait',
#   'eerem',
#   'grass',
#   'lait',
#   'lactos',
#   'emulsifi',
#   'lecithin',
#   'sucr',
#   'dextros',
#   'dan',
#   'endroit',
#   'sec',
#   'frais',
#   'conserv',
#   'jour',
#   'apre'],
#  ['nichon',
#   'ttc',
#   'paysann',
#   'igre',
#   'doux',
#   'deux',
#   'fois',
#   'kuhn',
#   'leur',
#   'leur',
#   'croqu',
#   'il',
#   'sont',
#   'prepar',
#   'sclon',
#   'kijhnc',
#   'resist',
#   'pas',
#   'cornichon',
#   'pasteuris',
#   'cornichon',
#   'cou',
#   'vinaigr',
#   'couvcrdc',
#   'apre',
#   'ouvcrtorc',
#   'conscrvcr',
#   'consomm',
#   'rapid'],
#  ['sucr',
#   'arachid',
#   'pat',
#   'cacao',
#   'lait',
#   'ecrem',
#   'poudr',
#   'lactos',
#   'protein',
#   'lait',
#   'matier',
#   'grass',
#   'vegetal',
#   'beurr',
#   'cacao',
#   'beurr',
#   'concentr',
#   'amidon',
#   'sirop',
#   'glucos',
#   'iecithin',
#   'soj',
#   'gomm',
#   'arab',
#   'color',
#   'arom',
#   'sel',
#   'huil',
#   'vegetal'],
#  ['eau',
#   'gazeifie',
#   'sucr',
#   'color',
#   'caramel',
#   'acidifi',
#   'acid',
#   'phosphor',
#   'arom',
#   'dont',
#   'extrait',
#   'naturel',
#   'vegetal',
#   'cafein'],
#  ['vinaigr',
#   'alcool',
#   'eau',
#   'huil',
#   'pepin',
#   'raisin',
#   'sucr',
#   'farin',
#   'mais',
#   'moutard',
#   'jaun',
#   'oeuf',
#   'pasteuris',
#   'sel',
#   'color',
#   'riboflavin'],
#  ['marmelad',
#   'citron',
#   'citron',
#   'vert',
#   'inqredlent',
#   'sirop',
#   'glucos',
#   'fructos',
#   'citron',
#   'citron',
#   'vert',
#   'sucr',
#   'gelifi',
#   'pectin',
#   'acid',
#   'citriqu',
#   'correcteur',
#   'dacidit',
#   'citrat',
#   'sodium',
#   'color',
#   'complex',
#   'cuivr',
#   'chlorophyllin',
#   'lutein',
#   'prepar',
#   'avec',
#   'fruit',
#   'pour',
#   'marmelad',
#   'condltlon',
#   'conserv',
#   'diutilis'],
#  ['sucr',
#   'orahg',
#   'agent',
#   'lfi',
#   'egul',
#   'citriqu',
#   'citrat',
#   'mdiurn',
#   'huil',
#   'dorang',
#   'douc',
#   'prot',
#   'ttnsomm',
#   'preicttit',
#   'avant',
#   'lquot',
#   'voir',
#   'sir',
#   'endroit',
#   'frais',
#   'abri',
#   'lumier',
#   'aue',
#   'ouvertur',
#   'refriger',
#   'conmmm',
#   'dan',
#   'le',
#   'emain',
#   'qui',
#   'energ',
#   'kcal',
#   'matier',
#   'gras',
#   'olg',
#   'dont',
#   'ture',
#   'glucid',
#   'dont',
#   'wcre',
#   'fibr',
#   'protein',
#   'convient',
#   'aux',
#   'vegetar',
#   'len',
#   'vegan',
#   'coeliaqu',
#   'produit',
#   'gluten',
#   'olttrlbu',
#   'par',
#   'ij',
#   'ndukmabk'],
#  ['eau',
#   'azeifie',
#   'sucr',
#   'color',
#   'acidifi',
#   'arom',
#   'naturel',
#   'dont',
#   'extrait',
#   'vegetau',
#   'cafein',
#   'consomm',
#   'preferent',
#   'avant',
#   'voir'],
#  ['chou',
#   'blanc',
#   'garnitur',
#   'viand',
#   'porc',
#   'viand',
#   'bovin',
#   'chou',
#   'blanc',
#   'eau',
#   'farin',
#   'ble',
#   'oignon',
#   'sel',
#   'iod',
#   'sel',
#   'iodat',
#   'potassium',
#   'epic',
#   'poivr',
#   'blanc',
#   'coriandr',
#   'piment',
#   'chil',
#   'carv',
#   'levur',
#   'dextros'],
#  ['nom',
#   'scientif',
#   'pollachius',
#   'viren',
#   'pech',
#   'atlant',
#   'nord',
#   'est',
#   'island',
#   'categor',
#   'engin',
#   'pech',
#   'chalut'],
#  ['filet', 'saumon'],
#  ['pomm',
#   'terr',
#   'amidon',
#   'pomm',
#   'terr',
#   'huil',
#   'palm',
#   'oeuf',
#   'epic',
#   'oignon',
#   'curcum',
#   'farin',
#   'riz',
#   'sel',
#   'farin',
#   'ble',
#   'dextros'],
#  ['pomm',
#   'terr',
#   'huil',
#   'tournesol',
#   'amidon',
#   'modif',
#   'mais',
#   'tapioc',
#   'epic',
#   'oignon',
#   'paprik',
#   'ail',
#   'poivr',
#   'piment',
#   'sel',
#   'sucr',
#   'tomat',
#   'poudr',
#   'farin',
#   'riz',
#   'extrait',
#   'dtepic',
#   'paprik',
#   'coriandr',
#   'persil',
#   'trac',
#   'ble',
#   'lait',
#   'oeuf',
#   'celer',
#   'soj'],
#  ['filet',
#   'poulet',
#   'mais',
#   'eau',
#   'huil',
#   'colz',
#   'amidon',
#   'modif',
#   'ble',
#   'sel',
#   'farin',
#   'ble',
#   'sucr',
#   'dextros',
#   'extrait',
#   'malt',
#   'orge',
#   'extrait',
#   'poivr'],
#  ['filet',
#   'dorad',
#   'sebast',
#   'farin',
#   'ble',
#   'eau',
#   'poudr',
#   'riz',
#   'oeuf',
#   'enti',
#   'poudr',
#   'amidon',
#   'modif',
#   'ble',
#   'mais',
#   'sel',
#   'persil',
#   'sucr',
#   'poivr',
#   'levur',
#   'acidifi',
#   'acid',
#   'citriqu'],
#  ['garnitur',
#   'sauc',
#   'bechamel',
#   'eau',
#   'jam',
#   'bon',
#   'cuit',
#   'superieur',
#   'jambon',
#   'porc',
#   'sel',
#   'sirop',
#   'glucos',
#   'dextros',
#   'antioxyd',
#   'ascorbat',
#   'sodium',
#   'conserv',
#   'nitrit',
#   'sodium',
#   'farin',
#   'ble',
#   'lait',
#   'ecrem',
#   'poudr',
#   'huil',
#   'tournesol',
#   'emmental',
#   'lait',
#   'sel',
#   'ferment',
#   'coagul',
#   'crem',
#   'fraich',
#   'comt',
#   'lait',
#   'ferment',
#   'sel',
#   'presur',
#   'sel',
#   'poivr',
#   'blanc',
#   'muscad',
#   'pat',
#   'eau',
#   'farin',
#   'ble',
#   'oeuf',
#   'lait',
#   'ecrem',
#   'poudr',
#   'huil',
#   'tournesol',
#   'dextros',
#   'sel',
#   'sucr',
#   'viand',
#   'porc',
#   'origin',
#   'franc',
#   'trac',
#   'celer'],
#  ['pomm',
#   'terr',
#   'oeuf',
#   'eau',
#   'beurr',
#   'farin',
#   'ble',
#   'huil',
#   'tournesol',
#   'flocon',
#   'pomm',
#   'terr',
#   'pomm',
#   'terr',
#   'deshydrate',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'extrait',
#   'epic',
#   'curcum',
#   'poudr',
#   'lait',
#   'enti',
#   'poudr',
#   'lev',
#   'pyrophosphat',
#   'soud',
#   'bicarbonat',
#   'soud',
#   'sel',
#   'amidon',
#   'ble',
#   'poivr',
#   'gris',
#   'muscad',
#   'trac',
#   'mollusqu',
#   'poisson',
#   'crustac',
#   'fruit',
#   'coqu',
#   'celer',
#   'soj',
#   'moutard'],
#  ['potiron',
#   'eau',
#   'lait',
#   'dem',
#   'ecrem',
#   'chataign',
#   'cam',
#   'pomm',
#   'terr',
#   'pomm',
#   'terr',
#   'sel',
#   'oignon',
#   'beurr',
#   'sel',
#   'amidon',
#   'modif',
#   'hais',
#   'riz',
#   'manioc',
#   'extrait',
#   'poivr'],
#  ['chocolat',
#   'noir',
#   'pat',
#   'cacao',
#   'sucr',
#   'beurr',
#   'cacao',
#   'beurr',
#   'deshydrat',
#   'lait',
#   'enti',
#   'poudr',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'arom',
#   'naturel',
#   'vanill',
#   'lait',
#   'ecrem',
#   'crem',
#   'jus',
#   'frambois',
#   'bas',
#   'concentr',
#   'sauc',
#   'frambois',
#   'pure',
#   'frambois',
#   'sucr',
#   'sirop',
#   'glucos',
#   'sirop',
#   'sucr',
#   'invert',
#   'stabilis',
#   'agar',
#   'agar',
#   'emulsifi',
#   'pectin',
#   'arom',
#   'naturel',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'sucr',
#   'biscuit',
#   'farin',
#   'ble',
#   'huil',
#   'tournesol',
#   'sucr',
#   'oeuf',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'sodium',
#   'sel',
#   'poudr',
#   'lait',
#   'ecrem',
#   'sirop',
#   'glucos',
#   'fructos',
#   'gouss',
#   'vanill',
#   'bourbon',
#   'broye',
#   'sirop',
#   'glucos',
#   'fructos',
#   'poudr',
#   'lait',
#   'ecrem',
#   'arom',
#   'naturel',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'concentr',
#   'jus',
#   'betterav',
#   'roug',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'stabilis',
#   'farin',
#   'grain',
#   'caroub',
#   'gomm',
#   'guar'],
#  ['garnitur',
#   'crem',
#   'fraich',
#   'eau',
#   'fromag',
#   'oeuf',
#   'epinard',
#   'saumon',
#   'emmental',
#   'lait',
#   'vach',
#   'sel',
#   'ferment',
#   'lactiqu',
#   'enzym',
#   'coagu',
#   'lant',
#   'fromag',
#   'lait',
#   'vach',
#   'sel',
#   'presur',
#   'amidon',
#   'modif',
#   'mais',
#   'sel',
#   'extrait',
#   'povr',
#   'muscad',
#   'pat',
#   'farin',
#   'ble',
#   'beurr',
#   'eau',
#   'sel',
#   'trac',
#   'mollusqu',
#   'crustac',
#   'celer',
#   'moutard'],
#  ['pet',
#   'epeautr',
#   'contient',
#   'gluten',
#   'carott',
#   'orang',
#   'carott',
#   'jaun',
#   'fev',
#   'soj',
#   'huil',
#   'oliv',
#   'eau',
#   'basilic',
#   'jus',
#   'citron',
#   'menth',
#   'modif',
#   'pomm',
#   'terr',
#   'sirop',
#   'glucos',
#   'xannan',
#   'alginat',
#   'sodium'],
#  ['garnitur',
#   'noix',
#   'saint',
#   'jacqu',
#   'eau',
#   'crem',
#   'fraich',
#   'oignon',
#   'echalot',
#   'poireau',
#   'carott',
#   'vin',
#   'blanc',
#   'amidon',
#   'modif',
#   'mais',
#   'beurr',
#   'jaun',
#   'oeuf',
#   'pasteuris',
#   'ail',
#   'sel',
#   'mer',
#   'persil',
#   'poivr',
#   'blanc',
#   'pat',
#   'feuillete',
#   'farin',
#   'ble',
#   'beurr',
#   'eau',
#   'jaun',
#   'oeuf',
#   'pasteuris',
#   'sel',
#   'mer',
#   'trac',
#   'crustac',
#   'poisson',
#   'soj',
#   'fruit',
#   'coqu',
#   'celer',
#   'moutard',
#   'grain',
#   'sesam'],
#  ['ingredient',
#   'pat',
#   'farin',
#   'ble',
#   'eau',
#   'huil',
#   'tournerot',
#   'grai',
#   'palm',
#   'persil',
#   'sucr',
#   'levur',
#   'poudr',
#   'cvc',
#   'diphoe>>phatceu',
#   'carbonate',
#   'sodium',
#   'amelior',
#   'farin',
#   'ble',
#   'emulsifi',
#   'mono',
#   'digty',
#   'cerid',
#   'diacid',
#   'gras',
#   'tcr',
#   'diacethytartriquc',
#   'der',
#   'rnono',
#   'digtycerid',
#   'acid',
#   'gras',
#   'agent',
#   'trait',
#   'farin',
#   'acid',
#   'ascorb',
#   'huil',
#   'tournesol',
#   'farc',
#   'mozzarctl',
#   'produit',
#   'fin',
#   'lait',
#   'set',
#   'presur',
#   'microbien',
#   'ferment',
#   'lactiqu',
#   'tomat',
#   'produit',
#   'fin',
#   'concentr',
#   'tomat',
#   'produit',
#   'fin',
#   'fromag',
#   'ractettc',
#   'produit',
#   'fi',
#   'lait',
#   'sel',
#   'ferment',
#   'lactiqu',
#   'presur',
#   'eau',
#   'fromag',
#   'frais',
#   'produit',
#   'fin',
#   'tait',
#   'crem',
#   'ferment',
#   'lactiqu',
#   'presur',
#   'microbien',
#   'basilic',
#   'ait',
#   'bouillon',
#   'poudr',
#   'set',
#   'maltodcxtrin',
#   'sucr',
#   'oignon',
#   'pan',
#   'ail',
#   'extrait',
#   'epic',
#   'curcu',
#   'noix',
#   'muscad',
#   'amidon',
#   'modif',
#   'mais',
#   'plant',
#   'aromat',
#   'epic',
#   'poivr',
#   'noir',
#   'poivr',
#   'cayen',
#   'origan',
#   'marjolain',
#   'farin',
#   'ble',
#   'epaiss',
#   'gomm',
#   'xanthan',
#   'trac',
#   'soj',
#   'oeuf',
#   'celer',
#   'grain',
#   'sesam'],
#  ['raviol',
#   'dauphin',
#   'igp',
#   'label',
#   'roug',
#   'farin',
#   'ble',
#   'fromag',
#   'blanc',
#   'lait',
#   'vach',
#   'ferment',
#   'sel',
#   'chlorur',
#   'calcium',
#   'presur',
#   'comt',
#   'lait',
#   'vach',
#   'presur',
#   'sel',
#   'ferment',
#   'emmental',
#   'lait',
#   'vach',
#   'presur',
#   'sel',
#   'ferment',
#   'eau',
#   'oeuf',
#   'persil',
#   'sel',
#   'huil',
#   'tournesol',
#   'beurr',
#   'courget',
#   'grille',
#   'eau',
#   'tomat',
#   'crem',
#   'eminc',
#   'poulet',
#   'cuit',
#   'aiguillet',
#   'poulet',
#   'eau',
#   'amidon',
#   'tapioc',
#   'dextros',
#   'sel',
#   'oignon',
#   'prefr',
#   'oignon',
#   'huil',
#   'tournesol',
#   'concentr',
#   'tomat',
#   'basilic',
#   'huil',
#   'tournesol',
#   'amidon',
#   'modif',
#   'pomm',
#   'terr',
#   'sel',
#   'epaiss',
#   'gomm',
#   'xanthan',
#   'poivr',
#   'noir',
#   'trac',
#   'poisson',
#   'crustac'],
#  ['oreillon',
#   'abricot',
#   'sirop',
#   'abricot',
#   'eau',
#   'sucr',
#   'farin',
#   'ble',
#   'sucr',
#   'beurr',
#   'nappag',
#   'eau',
#   'sirop',
#   'glucos',
#   'sucr',
#   'gelifi',
#   'pectin',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'correcteur',
#   'acidit',
#   'citrat',
#   'sodium',
#   'stabilis',
#   'chlorur',
#   'calcium',
#   'oeuf',
#   'enti',
#   'liquid',
#   'eau',
#   'crem',
#   'patissier',
#   'sucr',
#   'amidon',
#   'modif',
#   'pomm',
#   'terr',
#   'lactoserum',
#   'lait',
#   'enti',
#   'poudr',
#   'arom',
#   'naturel',
#   'vanill',
#   'extrait',
#   'vegetal',
#   'color',
#   'carott',
#   'amand',
#   'poudr',
#   'poudr',
#   'lev',
#   'diphosphat',
#   'carbonat',
#   'sodium',
#   'amidon',
#   'ble',
#   'blanc',
#   'oeuf',
#   'sel'],
#  ['chicken',
#   'nachos',
#   'morceau',
#   'filet',
#   'poulet',
#   'marin',
#   'morceau',
#   'filet',
#   'poulet',
#   'eau',
#   'sel',
#   'dextros',
#   'epic',
#   'paprik',
#   'piment',
#   'cumin',
#   'poivr',
#   'coriandr',
#   'curcum',
#   'fenugrec',
#   'tomat',
#   'poudr',
#   'ail',
#   'poudr',
#   'oignon',
#   'poudr',
#   'amidon',
#   'pomm',
#   'terr',
#   'sucr',
#   'jus',
#   'citron',
#   'poudr',
#   'extrait',
#   'epic',
#   'paprik',
#   'piment',
#   'gingembr',
#   'quatr',
#   'epic',
#   'origan',
#   'celer',
#   'panur',
#   'nachos',
#   'chip',
#   'bas',
#   'farin',
#   'mais',
#   'farin',
#   'mais',
#   'huil',
#   'tournesol',
#   'farin',
#   'ble',
#   'amidon',
#   'modif',
#   'ble',
#   'eau',
#   'sel',
#   'levur',
#   'paprik',
#   'poudr',
#   'huil',
#   'colz',
#   'sauc',
#   'fromag',
#   'cheddar',
#   'eau',
#   'fromag',
#   'frais',
#   'doubl',
#   'crem',
#   'crem',
#   'lait',
#   'ecrem',
#   'sel',
#   'huil',
#   'tournesol',
#   'poivron',
#   'roug',
#   'fromag',
#   'cheddar',
#   'oignon',
#   'sucr',
#   'poivron',
#   'vert',
#   'vinaigr',
#   'alcool',
#   'amidon',
#   'modif',
#   'mais',
#   'sel',
#   'piment',
#   'jalapeho',
#   'vert',
#   'pure',
#   'tomat',
#   'ail',
#   'poudr',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'extrait',
#   'paprik',
#   'stabilis',
#   'gomm',
#   'xanthan',
#   'sauc',
#   'mexicain',
#   'tomat',
#   'oignon',
#   'poivron',
#   'vert',
#   'sucr',
#   'pure',
#   'tomat',
#   'vinaigr',
#   'alcool',
#   'poivron',
#   'roug',
#   'epic',
#   'piment',
#   'feuill',
#   'coriandr',
#   'cumin',
#   'coriandr',
#   'origan',
#   'quatr',
#   'epic',
#   'pure',
#   'ail',
#   'sel',
#   'amidon',
#   'modif',
#   'mais',
#   'jus',
#   'citron',
#   'bas',
#   'concentr',
#   'stabilis',
#   'gomm',
#   'xanthan',
#   'trac',
#   'soj',
#   'moutard',
#   'oeuf'],
#  ['malv', 'verticefat', 'mauv', 'frise'],
#  ['viand',
#   'boeuf',
#   'sel',
#   'arom',
#   'naturel',
#   'conserv',
#   'emball',
#   'sous',
#   'atmospher',
#   'protectric',
#   'valeur',
#   'nutritinnel',
#   'moyen',
#   'pour'],
#  ['ivlarmit',
#   'original',
#   'extrait',
#   'levu',
#   'edientg',
#   'extrait',
#   'levur',
#   'acl',
#   'extrait',
#   'vegetal',
#   'niacin',
#   'flamin',
#   'vitamin',
#   'epic',
#   'celer',
#   'riboflavin',
#   'acid',
#   'foliqu',
#   'vitamino',
#   'vitamino',
#   'tondit',
#   'congerv',
#   'utiligatlon',
#   'consomm',
#   'preferent',
#   'avril',
#   'lot',
#   'las',
#   'conget',
#   'vor',
#   'dang',
#   'tndroit',
#   'frais',
#   'aec',
#   'declar',
#   'nutritionnel',
#   'pour',
#   'valeur',
#   'eneraetlqu',
#   'xipldeg',
#   'dont',
#   'acid',
#   'qrag',
#   'gatureg',
#   'tracec',
#   'iglucideg',
#   'dont',
#   'fibreg',
#   'sel',
#   'thiamin',
#   'rda',
#   'niacin',
#   'vitamin',
#   'apport',
#   'journali',
#   'recommand'],
#  ['tomat',
#   'pour',
#   'tomato',
#   'ketchup',
#   'vinaigr',
#   'sucr',
#   'sel',
#   'extrait',
#   'epic',
#   'herb',
#   'contiennent',
#   'celer',
#   'epic'],
#  ['tomat',
#   'pour',
#   'tomato',
#   'ketchup',
#   'vinaigr',
#   'sucr',
#   'sel',
#   'extrait',
#   'epic',
#   'herb',
#   'contiennent',
#   'celer',
#   'epic'],
#  ['eau',
#   'gazeifie',
#   'sucr',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'acid',
#   'maliqu',
#   'arom',
#   'extrait',
#   'naturel',
#   'citron',
#   'citron',
#   'vert',
#   'correcteur',
#   'acidit',
#   'citrat',
#   'sodium'],
#  ['farin',
#   'ble',
#   'huil',
#   'colz',
#   'sucr',
#   'oeuf',
#   'frais',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'lait',
#   'ecrem',
#   'poudr',
#   'arom'],
#  ['farin',
#   'ble',
#   'sucr',
#   'huil',
#   'colz',
#   'oeuf',
#   'frais',
#   'sirop',
#   'glucos',
#   'fructos',
#   'beurr',
#   'cacao',
#   'lait',
#   'enti',
#   'poudr',
#   'stabilis',
#   'glycerol',
#   'pat',
#   'cacao',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'lecithin',
#   'soj',
#   'sel',
#   'lait',
#   'ecrem',
#   'poudr',
#   'arom'],
#  ['farin',
#   'ble',
#   'chocolat',
#   'noir',
#   'pat',
#   'cacao',
#   'sucr',
#   'beurr',
#   'cacao',
#   'matier',
#   'grass',
#   'laitier',
#   'lecithin',
#   'soj',
#   'arom',
#   'huil',
#   'colz',
#   'sucr',
#   'oeuf',
#   'frais',
#   'sirop',
#   'glucos',
#   'fructos',
#   'glycerol',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'lait',
#   'ecrem',
#   'poudr',
#   'arom'],
#  ['madelein',
#   'choconoir',
#   'madelein',
#   'nappe',
#   'chocolat',
#   'noir',
#   'farin',
#   'ble',
#   'chocolat',
#   'noir',
#   'pat',
#   'cacao',
#   'sucr',
#   'beurr',
#   'cacao',
#   'matier',
#   'grass',
#   'laitier',
#   'anhydr',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'arom',
#   'naturel',
#   'vanill',
#   'sucr',
#   'huil',
#   'colz',
#   'oeuf',
#   'poul',
#   'eleve',
#   'plein',
#   'air',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'citrat',
#   'sodium',
#   'ble',
#   'sel',
#   'gluten',
#   'ble',
#   'lait',
#   'ecrem',
#   'poudr',
#   'fibr',
#   'vegetal',
#   'arom',
#   'naturel',
#   'peut',
#   'conten',
#   'de',
#   'trac',
#   'fruit',
#   'coqu',
#   'tout',
#   'vos',
#   'remarqu',
#   'suggest',
#   'sont',
#   'le',
#   'bienvenu',
#   'contact',
#   'notr',
#   'servic',
#   'qualit',
#   'indiqu',
#   'nom',
#   'numero',
#   'lot',
#   'produit',
#   'concern',
#   'figur',
#   'sur',
#   'dessus',
#   'boit',
#   'pour',
#   'conserv',
#   'tout',
#   'le',
#   'qualit',
#   'produit',
#   'mainten',
#   'dan',
#   'milieu',
#   'temper',
#   'abri',
#   'chaleur',
#   'humidit',
#   'froid'],
#  ['glycerin',
#   'vegetal',
#   'propylen',
#   'glycol',
#   'arom',
#   'tart',
#   'frais',
#   'sel',
#   'sucralos',
#   'ingredienten',
#   'plantaardig',
#   'glycerin',
#   'propyleenglycol',
#   'aardbeientaartarom',
#   'zout',
#   'sucralos',
#   'zulaten',
#   'pflanzlich',
#   'glycerin'],
#  ['farin',
#   'ble',
#   'oeuf',
#   'frais',
#   'huil',
#   'colz',
#   'sucr',
#   'raisin',
#   'sec',
#   'raisin',
#   'huil',
#   'colz',
#   'dextros',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'lait',
#   'ecrem',
#   'poudr',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'arom',
#   'naturel',
#   'orang'],
#  ['fruit',
#   'fruit',
#   'confit',
#   'fruit',
#   'pastequ',
#   'bigarreau',
#   'ecorc',
#   'orang',
#   'sirop',
#   'glucos',
#   'fructos',
#   'sucr',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'anhydrid',
#   'sulfur',
#   'color',
#   'caramel',
#   'ordinair',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'raisin',
#   'sec',
#   'rhum',
#   'farin',
#   'ble',
#   'huil',
#   'colz',
#   'oeuf',
#   'frais',
#   'sucr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'lait',
#   'ecrem',
#   'poudr',
#   'arom',
#   'naturel',
#   'orang'],
#  ['viand',
#   'porc',
#   'eau',
#   'acidifi',
#   'sel',
#   'dextros',
#   'acidifi',
#   'exhausteur',
#   'gout',
#   'antioxygen',
#   'color',
#   'arom'],
#  ['sucr',
#   'farin',
#   'ble',
#   'oeuf',
#   'frais',
#   'beurr',
#   'concentr',
#   'soit',
#   'beurr',
#   'reconstitu',
#   'beurr',
#   'cacao',
#   'lait',
#   'enti',
#   'poudr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'pat',
#   'cacao',
#   'stabilis',
#   'glycerol',
#   'lait',
#   'ecrem',
#   'poudr',
#   'poudr',
#   'lev',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'bi',
#   'sel',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'lecithin',
#   'soj',
#   'arom',
#   'peut',
#   'conten',
#   'de',
#   'trac',
#   'fruit',
#   'coqu',
#   'respect',
#   'de',
#   'notr',
#   'vous',
#   'offre',
#   'pour',
#   'votr',
#   'valeur',
#   'nutritionnel',
#   'moyen',
#   'pour',
#   'patisser',
#   'pour'],
#  ['concentr',
#   'protein',
#   'lait',
#   'non',
#   'denature',
#   'arom',
#   'fruit',
#   'roug',
#   'crem',
#   'stabilis',
#   'gomm',
#   'xanthan',
#   'color',
#   'naturel',
#   'roug',
#   'betterav',
#   'edulcor',
#   'sucralos',
#   'agent',
#   'instantaneis',
#   'lecithin',
#   'soj'],
#  ['concentr',
#   'protein',
#   'lactoserum',
#   'non',
#   'denature',
#   'lait',
#   'lecithin',
#   'soj',
#   'poudr',
#   'cacao',
#   'arom',
#   'chocolat',
#   'cacahuet',
#   'stabilis',
#   'gomm',
#   'xanthan',
#   'edulcor',
#   'sucralos',
#   'agent',
#   'instantaneis',
#   'lecithin',
#   'soj'],
#  ['isolat',
#   'protein',
#   'soj',
#   'fructos',
#   'inulin',
#   'fibr',
#   'avoin',
#   'san',
#   'gluten',
#   'huil',
#   'soj',
#   'melang',
#   'mineral',
#   'citrat',
#   'calcium',
#   'oxyd',
#   'magnesium',
#   'fumarat',
#   'ferreux',
#   'selenit',
#   'sodium',
#   'oxyd',
#   'zinc',
#   'carbonat',
#   'manganes',
#   'chlorur',
#   'chrom',
#   'iii',
#   'iodur',
#   'potassium',
#   'citrat',
#   'cuivr',
#   'poudr',
#   'caf',
#   'decafein',
#   'phosphat',
#   'potassium',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'arom',
#   'naturel',
#   'poudr',
#   'lin',
#   'biolog',
#   'epaiss',
#   'gomm',
#   'xanthan',
#   'gomm',
#   'guar',
#   'color',
#   'caramel',
#   'melang',
#   'vitamin',
#   'acid',
#   'ascorb',
#   'vit',
#   'acetat',
#   'alpha',
#   'tocopheryl',
#   'vit',
#   'nicotinamid',
#   'niacin',
#   'acetat',
#   'retinyl',
#   'vit',
#   'pantothenat',
#   'calcium',
#   'acid',
#   'pantothen',
#   'biotin',
#   'biotin',
#   'cholecalciferol',
#   'vit',
#   'phylloquinon',
#   'vit',
#   'chlorhydrat',
#   'pyridoxin',
#   'vit',
#   'chlorhydrat',
#   'thiamin',
#   'vit',
#   'cyanocobalamin',
#   'vit',
#   'riboflavin',
#   'vit',
#   'acid',
#   'pteroylmonoglutam',
#   'acid',
#   'foliqu',
#   'chlorur',
#   'sodium',
#   'edulcor',
#   'glycosid',
#   'steviol',
#   'poudr',
#   'fruit',
#   'papay',
#   'grenad',
#   'myrtill',
#   'persil',
#   'poudr',
#   'antiagglomer',
#   'dioxyd',
#   'silicium'],
#  ['sucr',
#   'blanc',
#   'oeufsfr',
#   'poudr',
#   'amand',
#   'beurreconcentr',
#   'farin',
#   'debl',
#   'oeufsfr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'sel',
#   'poudr',
#   'lev',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'arom'],
#  ['pure',
#   'tomat',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'cep',
#   'carott',
#   'celer',
#   'oignon',
#   'sel',
#   'persil',
#   'basilic',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['pure',
#   'tomat',
#   'oliv',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'capr',
#   'ail',
#   'poivr',
#   'noir',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['pure',
#   'tomat',
#   'courget',
#   'huil',
#   'oliv',
#   'extra',
#   'vierg',
#   'oignon',
#   'carott',
#   'celer',
#   'sel',
#   'poivr',
#   'noir',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['pure',
#   'tomat',
#   'thon',
#   'oliv',
#   'huil',
#   'oliv',
#   'extra',
#   'vierg',
#   'oignon',
#   'sel',
#   'persil',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['pure',
#   'tomat',
#   'carott',
#   'huil',
#   'oliv',
#   'extra',
#   'vierg',
#   'oignon',
#   'courget',
#   'aubergin',
#   'celer',
#   'basilic',
#   'sel',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['sucr',
#   'blanc',
#   'oeuf',
#   'frais',
#   'poudr',
#   'amand',
#   'beurr',
#   'patissi',
#   'farin',
#   'ble',
#   'pepit',
#   'citron',
#   'sucr',
#   'pomm',
#   'pulp',
#   'citron',
#   'dextros',
#   'fibr',
#   'anan',
#   'gelifi',
#   'alginat',
#   'sodium',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'citrat',
#   'potassium',
#   'stabilis',
#   'phosphat',
#   'calcium',
#   'arom',
#   'naturel',
#   'citron',
#   'color',
#   'curcumin',
#   'oeuf',
#   'frais',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'citron',
#   'equivalent',
#   'jus',
#   'citron',
#   'jus',
#   'concentr',
#   'citron',
#   'maltodextrin',
#   'sel',
#   'poudr',
#   'lev',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'arom',
#   'naturel',
#   'citron',
#   'exprim',
#   'sur',
#   'le',
#   'pepit',
#   'equivalent',
#   'sur',
#   'ensembl',
#   'produit'],
#  ['farin',
#   'riz',
#   'farin',
#   'sarrasin',
#   'farin',
#   'millet',
#   'farin',
#   'souchet',
#   'toast',
#   'sel',
#   'marin',
#   'produit',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['sucr',
#   'blanc',
#   'oeuf',
#   'frais',
#   'beurr',
#   'concentr',
#   'poudr',
#   'amand',
#   'farin',
#   'ble',
#   'pat',
#   'cacao',
#   'oeuf',
#   'frais',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'cacao',
#   'maigr',
#   'poudr',
#   'beurr',
#   'cacao',
#   'sel',
#   'arom',
#   'matier',
#   'grass',
#   'laitier',
#   'emulsifi',
#   'lecithin',
#   'soj'],
#  ['eau',
#   'fecul',
#   'tapioc',
#   'farin',
#   'riz',
#   'fecul',
#   'pomm',
#   'terr',
#   'huil',
#   'vegetal',
#   'huil',
#   'colz',
#   'huil',
#   'tournesol',
#   'levur',
#   'humect',
#   'glycerol',
#   'vegetal',
#   'stabilis',
#   'hydroxypropyl',
#   'methyl',
#   'cellulos',
#   'amidon',
#   'mais',
#   'blanc',
#   'oeuf',
#   'deshydrat',
#   'sucr',
#   'poudr',
#   'envelopp',
#   'psyllium',
#   'poudr',
#   'farin',
#   'mais',
#   'sel',
#   'iod',
#   'sel',
#   'iodat',
#   'potassium',
#   'amidon',
#   'mais',
#   'ferment',
#   'amidon',
#   'riz'],
#  ['dextros',
#   'maltodextrin',
#   'arom',
#   'fruit',
#   'roug',
#   'color',
#   'roug',
#   'betterav',
#   'acid',
#   'citriqu'],
#  ['ingredient',
#   'nectar',
#   'fleur',
#   'coco',
#   'biolog',
#   'allergen',
#   'le',
#   'allergen',
#   'sont',
#   'indiqu',
#   'par',
#   'le',
#   'ingredient',
#   'figur',
#   'caracter',
#   'gras'],
#  ['farin',
#   'ble',
#   'farin',
#   'ble',
#   'gluten',
#   'ble',
#   'farin',
#   'ble',
#   'malt',
#   'eau',
#   'grain',
#   'sesam',
#   'decortique',
#   'toaste',
#   'sel',
#   'germ',
#   'ble',
#   'levur',
#   'emulsifi',
#   'agent',
#   'trait',
#   'farin'],
#  ['farin',
#   'ble',
#   'complet',
#   'eau',
#   'sel',
#   'levur',
#   'gluten',
#   'ble',
#   'farin',
#   'ble',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'huil',
#   'colz',
#   'total',
#   'hydrogene',
#   'agent',
#   'trait',
#   'farin',
#   'acid',
#   'ascorb'],
#  ['epic',
#   'pain',
#   'epic',
#   'epic',
#   'cannel',
#   'gingembr',
#   'coriandr',
#   'anis',
#   'clous',
#   'girofl',
#   'anis',
#   'etoil',
#   'muscad',
#   'poivr',
#   'scicr'],
#  ['pat',
#   'farin',
#   'saindoux',
#   'eau',
#   'oeuf',
#   'sel',
#   'vinaigr',
#   'garnitur',
#   'bleuet',
#   'sauvag',
#   'sucr',
#   'farin',
#   'contient',
#   'gluten',
#   'oeuf'],
#  ['glycin', 'poudr'],
#  ['viand',
#   'cuiss',
#   'dind',
#   'avec',
#   'peau',
#   'origin',
#   'franc',
#   'eau',
#   'epic',
#   'plant',
#   'aromat',
#   'sel',
#   'fecul',
#   'pomm',
#   'terr',
#   'arom',
#   'naturel',
#   'conserv',
#   'acetat',
#   'sodium'],
#  ['patisser',
#   'fourre',
#   'pulp',
#   'pech',
#   'farin',
#   'ble',
#   'fourrag',
#   'pech',
#   'sirop',
#   'glucos',
#   'fructos',
#   'pure',
#   'pech',
#   'sucr',
#   'gelifi',
#   'pectin',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'citrat',
#   'sodium',
#   'arom',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'huil',
#   'colz',
#   'oeuf',
#   'frais',
#   'sucr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'lait',
#   'ecrem',
#   'poudr',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'arom',
#   'exprim',
#   'sur',
#   'fourrag',
#   'equivalent',
#   'sur',
#   'ensembl',
#   'produit',
#   'patisser',
#   'fourre',
#   'pulp',
#   'abricot',
#   'farin',
#   'ble',
#   'fourrag',
#   'abricot',
#   'sirop',
#   'glucos',
#   'fructos',
#   'pure',
#   'abricot',
#   'sucr',
#   'gelifi',
#   'pectin',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'citrat',
#   'sodium',
#   'arom',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'huil',
#   'colz',
#   'oeuf',
#   'frais',
#   'sucr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'lait',
#   'ecrem',
#   'poudr',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'arom',
#   'exprim',
#   'sur',
#   'fourrag',
#   'equivalent',
#   'sur',
#   'ensembl',
#   'produit',
#   'patisser',
#   'fourre',
#   'pulp',
#   'fruit',
#   'roug',
#   'farin',
#   'ble',
#   'fourrag',
#   'fruit',
#   'roug',
#   'sirop',
#   'glucos',
#   'fructos',
#   'pure',
#   'frais',
#   'sucr',
#   'pure',
#   'frambois',
#   'concentre',
#   'equivalent',
#   'pure',
#   'frambois',
#   'pure',
#   'ceris',
#   'concentre',
#   'equivalent',
#   'pure',
#   'ceris',
#   'gelifi',
#   'pectin',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'citrat',
#   'sodium',
#   'arom',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'huil',
#   'colz',
#   'oeuf',
#   'frais',
#   'sucr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'lait',
#   'ecrem',
#   'poudr',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'arom',
#   'soit',
#   'equivalent',
#   'pure',
#   'fruit',
#   'sur',
#   'fourrag',
#   'equivalent',
#   'sur',
#   'ensembl',
#   'produit'],
#  ['pain',
#   'burg',
#   'pavot',
#   'farin',
#   'ble',
#   'eau',
#   'levur',
#   'dextros',
#   'huil',
#   'olza',
#   'sucr',
#   'arom',
#   'grain',
#   'pavot',
#   'sarrasin',
#   'sel',
#   'gluten',
#   'ble',
#   'farin',
#   'fev',
#   'conserv',
#   'propionat',
#   'calcium',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'gras',
#   'antioxyd',
#   'acid',
#   'ascorb',
#   'garnitur',
#   'aiguillet',
#   'poulet',
#   'pan',
#   'aiguillet',
#   'poulet',
#   'farin',
#   'ble',
#   'eau',
#   'huil',
#   'tournesol',
#   'sel',
#   'amidon',
#   'modif',
#   'arom',
#   'lactos',
#   'gluten',
#   'stabilis',
#   'elil',
#   'levur',
#   'epaiss',
#   'fromag',
#   'cheddar',
#   'fromag',
#   'dont',
#   'cheddar',
#   'lait',
#   'ecrem',
#   'rehydrat',
#   'beurr',
#   'sel',
#   'font',
#   'citrat',
#   'sodium',
#   'acid',
#   'citriqu',
#   'protein',
#   'lait',
#   'sel',
#   'color',
#   'extrait',
#   'paprik',
#   'antiagglomer',
#   'lecithin',
#   'tourneso',
#   'guacamol',
#   'avocat',
#   'hass',
#   'poivron',
#   'roug',
#   'sel',
#   'piment',
#   'jalapeno',
#   'antioxygen',
#   'acid',
#   'ascorb',
#   'oignon',
#   'epaiss',
#   'gomm',
#   'xanthan',
#   'acidifi',
#   'ascorbat',
#   'sodium',
#   'ail',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'coriandr',
#   'salad',
#   'batavi',
#   'tomat'],
#  ['focon',
#   'davoin',
#   'complet',
#   'arin',
#   'avoin',
#   'complet',
#   'sirop',
#   'sucr',
#   'oligoructos',
#   'sucr',
#   'brun',
#   'cereal',
#   'croustil',
#   'arin',
#   'riz',
#   'farin',
#   'avoin',
#   'suar',
#   'carbonat',
#   'calaum',
#   'extrait',
#   'mat',
#   'orge',
#   'hul',
#   'tournesol',
#   'emulsii',
#   'glycerol',
#   'lecthin',
#   'soj',
#   'amidon',
#   'moditf',
#   'arin',
#   'damand',
#   'moulu',
#   'poudr',
#   'lait',
#   'ecrem',
#   'antioxyd',
#   'extrait',
#   'tocopherol',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'socium',
#   'carbonat',
#   'calcum',
#   'aom',
#   'naturel',
#   'inorm',
#   'alergeness',
#   'le',
#   'aleroen',
#   'sont',
#   'eart',
#   'gras',
#   'peut',
#   'conten',
#   'de',
#   'trac',
#   'noix',
#   'ble',
#   'sesam',
#   'cauet'],
#  ['taboul',
#   'semoul',
#   'ble',
#   'dur',
#   'rehydrate',
#   'legum',
#   'poivron',
#   'roug',
#   'vert',
#   'tomat',
#   'tomat',
#   'deshydrate',
#   'huil',
#   'colz',
#   'raisin',
#   'sec',
#   'enrobag',
#   'huil',
#   'colz',
#   'vinaigr',
#   'alcool',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'sel',
#   'menth',
#   'jus',
#   'citon',
#   'concentr',
#   'sucr',
#   'conserv',
#   'arom',
#   'salad'],
#  ['foi', 'gras', 'canard', 'perigord', 'eau', 'armagnac', 'sel', 'poivr'],
#  ['viand',
#   'canard',
#   'origin',
#   'franc',
#   'graiss',
#   'canard',
#   'gorg',
#   'porc',
#   'origin',
#   'franc',
#   'eau',
#   'sel',
#   'pulp',
#   'ail',
#   'ail',
#   'rehydrat',
#   'sel',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'echalot',
#   'deshydrate',
#   'poivr'],
#  ['chou',
#   'carott',
#   'huil',
#   'colz',
#   'eau',
#   'vinaigr',
#   'alcool',
#   'sucr',
#   'oignon',
#   'moutard',
#   'dijon',
#   'eau',
#   'grain',
#   'moutard',
#   'vinaigr',
#   'alcool',
#   'sel',
#   'acidifi',
#   'conserv',
#   'jaun',
#   'oeuf',
#   'sel',
#   'amidon',
#   'modif',
#   'mais',
#   'jus',
#   'concentr',
#   'citron',
#   'conserv',
#   'epaiss',
#   'poivr'],
#  ['pain',
#   'baguet',
#   'farin',
#   'froment',
#   'eau',
#   'levur',
#   'sel',
#   'garnitur',
#   'jambon',
#   'jambon',
#   'porc',
#   'origin',
#   'franc',
#   'eau',
#   'sel',
#   'arom',
#   'naturel',
#   'dextros',
#   'bouillon',
#   'porc',
#   'deshydrat',
#   'eau',
#   'viand',
#   'porc',
#   'extrait',
#   'carott',
#   'extrait',
#   'poireau',
#   'sirop',
#   'glucos',
#   'chlorur',
#   'potassium',
#   'antioxyd',
#   'ascorbat',
#   'sodium',
#   'conserv',
#   'nitrit',
#   'sodium',
#   'beurr',
#   'leg',
#   'eau',
#   'beurr',
#   'amidon',
#   'modif',
#   'amidon',
#   'pomm',
#   'terr',
#   'acidifi',
#   'acid',
#   'lactiqu',
#   'sel',
#   'emulsifi',
#   'epaiss',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'color',
#   'bet',
#   'caroten',
#   'arom',
#   'naturel',
#   'exprim',
#   'sur',
#   'garnitur'],
#  ['pain',
#   'baguet',
#   'farin',
#   'froment',
#   'eau',
#   'levur',
#   'sel',
#   'garnitur',
#   'roset',
#   'viand',
#   'porc',
#   'origin',
#   'sel',
#   'lactos',
#   'dextros',
#   'epic',
#   'ail',
#   'antioxyd',
#   'erythorbat',
#   'sodium',
#   'conserv',
#   'nitrat',
#   'potassium',
#   'nitrit',
#   'sodium',
#   'ferment',
#   'beurr',
#   'leg',
#   'eau',
#   'beurr',
#   'amidon',
#   'modif',
#   'amidon',
#   'pomm',
#   'terr',
#   'acidifi',
#   'acid',
#   'lactiqu',
#   'sel',
#   'emulsifi',
#   'epaiss',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'color',
#   'bet',
#   'caroten',
#   'arom',
#   'naturel'],
#  ['farin',
#   'ble',
#   'eau',
#   'farin',
#   'seigl',
#   'sucr',
#   'sirop',
#   'sucr',
#   'huil',
#   'colz',
#   'gluten',
#   'ble',
#   'sel',
#   'levur',
#   'levain',
#   'poudr',
#   'emulsifi',
#   'poudr',
#   'lev',
#   'fructos',
#   'farin',
#   'malt',
#   'orge',
#   'agent',
#   'trait',
#   'de',
#   'farin',
#   'enzym',
#   'garnitur',
#   'salad',
#   'vert',
#   'filet',
#   'poulet',
#   'rot',
#   'filet',
#   'poulet',
#   'origin',
#   'franc',
#   'eau',
#   'dextros',
#   'huil',
#   'tournesol',
#   'sel',
#   'protein',
#   'pois',
#   'arom',
#   'stabilis',
#   'fibr',
#   'ble',
#   'san',
#   'gluten',
#   'gelifi',
#   'carott',
#   'rape',
#   'mayonnais',
#   'huil',
#   'colz',
#   'eau',
#   'vinaigr',
#   'jaun',
#   'oeuf',
#   'moutard',
#   'dijon',
#   'eau',
#   'grain',
#   'moutard',
#   'vinaigr',
#   'sel',
#   'antioxyd',
#   'disulfit',
#   'potassium',
#   'acidifi',
#   'acid',
#   'oltriqu'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'sucr',
#   'beurr',
#   'lait',
#   'raisin',
#   'smyrn',
#   'sirop',
#   'glucos',
#   'lait',
#   'poudr',
#   'ecrem',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'sel'],
#  ['morceau',
#   'chocolat',
#   'blanc',
#   'sucr',
#   'lait',
#   'poudr',
#   'enti',
#   'beurr',
#   'cacao',
#   'lait',
#   'poudr',
#   'ecrem',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'arom',
#   'vanill',
#   'farin',
#   'ble',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'beurr',
#   'sucr',
#   'fecul',
#   'mais',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'sirop',
#   'sucr',
#   'invert',
#   'sel'],
#  ['sucr',
#   'beurr',
#   'lait',
#   'flocon',
#   'avoin',
#   'contient',
#   'gluten',
#   'farin',
#   'blecontient',
#   'gluten',
#   'avec',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'raisin',
#   'sec',
#   'noix',
#   'coco',
#   'desseche',
#   'abricot',
#   'sech',
#   'abricot',
#   'farin',
#   'riz',
#   'conserv',
#   'sulfit',
#   'golden',
#   'syrup',
#   'sirop',
#   'sucr',
#   'invert',
#   'oeuf',
#   'pasteuris',
#   'agent',
#   'levag',
#   'bicarbonat',
#   'sodium',
#   'sel',
#   'mel'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'beurr',
#   'lait',
#   'sucr',
#   'eclat',
#   'pistach',
#   'eclat',
#   'amand',
#   'sirop',
#   'sucr',
#   'invert',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'lait',
#   'poudr',
#   'sel'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'beurr',
#   'lait',
#   'gingembr',
#   'conf',
#   'cristallis',
#   'gingembr',
#   'conf',
#   'sucr',
#   'sucr',
#   'flocon',
#   'avoin',
#   'contiennent',
#   'gluten',
#   'sirop',
#   'sucr',
#   'invert',
#   'gingembr',
#   'moulu',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'lait',
#   'poudr',
#   'ecrem',
#   'sel'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'sucr',
#   'gingembr',
#   'conf',
#   'cristallis',
#   'ingembr',
#   'sucr',
#   'cann',
#   'beurr',
#   'lait',
#   'flocon',
#   'avoin',
#   'contient',
#   'gluten',
#   'avoin',
#   'grossier',
#   'moulu',
#   'contient',
#   'gluten',
#   'fecul',
#   'mais',
#   'lait',
#   'poudr',
#   'ecrem',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'sirop',
#   'sucr',
#   'invert',
#   'gingembr',
#   'moulu',
#   'sel'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'beurr',
#   'lait',
#   'gingembr',
#   'conf',
#   'cristallis',
#   'gingembr',
#   'conf',
#   'sucr',
#   'sucr',
#   'flocon',
#   'avoin',
#   'contiennent',
#   'gluten',
#   'sirop',
#   'sucr',
#   'invert',
#   'gingembr',
#   'moulu',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'lait',
#   'poudr',
#   'ecrem',
#   'sel'],
#  ['jus',
#   'pomm',
#   'pure',
#   'frais',
#   'pure',
#   'banan',
#   'pure',
#   'pomm',
#   'pure',
#   'bai',
#   'sureau',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'antioxyd',
#   'acid',
#   'ascorb'],
#  ['carott',
#   'sauc',
#   'typ',
#   'vinaigret',
#   'eau',
#   'huil',
#   'colz',
#   'vinaigr',
#   'alcool',
#   'moutard',
#   'eau',
#   'grain',
#   'moutard',
#   'vinaigr',
#   'alcool',
#   'sel',
#   'sel',
#   'epaiss',
#   'arom',
#   'conserv'],
#  ['fruit', 'passion'],
#  ['salad',
#   'vert',
#   'concombr',
#   'taboul',
#   'semoul',
#   'ble',
#   'dur',
#   'rehydrate',
#   'legum',
#   'poivron',
#   'roug',
#   'vert',
#   'tomat',
#   'tomat',
#   'deshydrate',
#   'huil',
#   'colz',
#   'raisin',
#   'sec',
#   'enrobag',
#   'huil',
#   'colz',
#   'vinaigr',
#   'alcool',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'sel',
#   'mentbejus',
#   'citron',
#   'concentr',
#   'sucr',
#   'conserv',
#   'arom',
#   'mais',
#   'tomat',
#   'ceris',
#   'oeuf',
#   'dur',
#   'carott',
#   'rape'],
#  ['pat',
#   'farin',
#   'ble',
#   'tendr',
#   'eau',
#   'huil',
#   'oliv',
#   'extra',
#   'vierg',
#   'sel',
#   'levur',
#   'sauc',
#   'blanch',
#   'eau',
#   'crem',
#   'lait',
#   'poudr',
#   'protein',
#   'lait',
#   'lait',
#   'enti',
#   'poudr',
#   'amidon',
#   'mais',
#   'modif',
#   'sel',
#   'fromag',
#   'bleu',
#   'equivalent',
#   'produit',
#   'fin',
#   'lait',
#   'sel',
#   'ferment',
#   'lactiqu',
#   'presur',
#   'microbien',
#   'penicillium',
#   'roquefort',
#   'huil',
# ...
#  ['sirop',
#   'glucos',
#   'sucr',
#   'gelatin',
#   'poisson',
#   'dextros',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'arom',
#   'agent',
#   'enrobag',
#   'cir',
#   'abeil',
#   'blanch',
#   'etjaun',
#   'cir',
#   'carnaub',
#   'concentr',
#   'fruit',
#   'plant',
#   'citrouill',
#   'pomm',
#   'carott',
#   'hibiscus',
#   'spirulin'],
#  ['sirop',
#   'glucos',
#   'sucr',
#   'gelatin',
#   'poisson',
#   'dextros',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'sirop',
#   'caramel',
#   'arom',
#   'agent',
#   'enrobag',
#   'cir',
#   'abeil',
#   'blanch',
#   'cir',
#   'carnaub'],
#  ['sirop',
#   'glucos',
#   'sucr',
#   'dextros',
#   'gelatin',
#   'poisson',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'arom',
#   'agent',
#   'enrobag',
#   'cir',
#   'abeil',
#   'blanch',
#   'jaun',
#   'cir',
#   'carnaub',
#   'concentr',
#   'fruit',
#   'plant',
#   'citrouill',
#   'pomm',
#   'paprik',
#   'tomat',
#   'carott',
#   'hibiscus',
#   'spirulin'],
#  ['sirop',
#   'glucos',
#   'gelatin',
#   'poisson',
#   'dextros',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'arom',
#   'enrobag',
#   'cir',
#   'abeil',
#   'blanch',
#   'cir',
#   'desamaub',
#   'concentr',
#   'plant',
#   'citrouill',
#   'pomm',
#   'paprik',
#   'tomat',
#   'carott',
#   'hibiscus',
#   'sprne',
#   'sirop',
#   'sucr',
#   'invert'],
#  ['sirop',
#   'glucos',
#   'sucr',
#   'gelatin',
#   'poissan',
#   'dextros',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'arom',
#   'agent',
#   'enrobag',
#   'cir',
#   'abeil',
#   'blanch',
#   'jaun',
#   'cir',
#   'carnaub',
#   'concentr',
#   'fruit',
#   'plant',
#   'citrouill',
#   'pomm',
#   'paprik',
#   'tomat',
#   'carott',
#   'hibiscus',
#   'spirulin'],
#  ['sirop',
#   'glucos',
#   'sucr',
#   'amidon',
#   'gelatin',
#   'poisson',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'acid',
#   'maliqu',
#   'arom',
#   'concentr',
#   'fruit',
#   'plant',
#   'carott',
#   'hibiscus',
#   'agent',
#   'camaub',
#   'aconsommerd',
#   'preferenceavantfinvoir',
#   'dan',
#   'bord',
#   'emballag',
#   'ten',
#   'abri',
#   'chaleur'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'beurr',
#   'lait',
#   'eau',
#   'pure',
#   'ail',
#   'fibr',
#   'betterav',
#   'sucrier',
#   'levur',
#   'sel',
#   'jus',
#   'citron',
#   'persil',
#   'agent',
#   'trait',
#   'farin',
#   'acid',
#   'ascorb'],
#  ['ingredient',
#   'protein',
#   'soj',
#   'texture',
#   'san',
#   'hexan',
#   'oignon',
#   'fibr',
#   'soj',
#   'champignon',
#   'eau',
#   'gluten',
#   'ble',
#   'boulgour',
#   'ble',
#   'celer',
#   'carott',
#   'noix',
#   'fruit',
#   'coqu',
#   'avoin',
#   'poivron',
#   'doux',
#   'huil',
#   'tournesol',
#   'farin',
#   'riz',
#   'doux',
#   'sel',
#   'pure',
#   'tomat',
#   'pomm',
#   'terr',
#   'epic',
#   'ail',
#   'sucr',
#   'vinaigr',
#   'cidr',
#   'pomm',
#   'mel',
#   'vinaigr',
#   'cereal',
#   'grain',
#   'moutard',
#   'moulu',
#   'arom',
#   'naturel',
#   'fume',
#   'cari',
#   'poivr',
#   'noir',
#   'huil',
#   'clous',
#   'girofl'],
#  ['redlent',
#   'pijre',
#   'deiomat',
#   'tomat',
#   'eau',
#   'crem',
#   'lait',
#   'sucr',
#   'fel',
#   'poivr',
#   'noir',
#   'moulu',
#   'ingredient',
#   'issu',
#   'agricultur',
#   'biolog',
#   'pour',
#   'le',
#   'allergen',
#   'consult',
#   'le',
#   'ingredient',
#   'gras',
#   'votr',
#   'avis',
#   'nous',
#   'interess',
#   'vous',
#   'avez',
#   'de',
#   'question',
#   'de',
#   'commentair',
#   'ecriv',
#   'nous',
#   'adress',
#   'suiv',
#   'san',
#   'ble'],
#  ['legum',
#   'oignon',
#   'tomat',
#   'concasse',
#   'poivron',
#   'courget',
#   'ail',
#   'chou',
#   'fris',
#   'pure',
#   'tomat',
#   'eau',
#   'pois',
#   'chich',
#   'riz',
#   'brun',
#   'champignon',
#   'huil',
#   'oliv',
#   'sel',
#   'marin',
#   'epic',
#   'basilic'],
#  ['vegetalien',
#   'eau',
#   'filtre',
#   'tomat',
#   'oignon',
#   'harcot',
#   'blanc',
#   'courget',
#   'champignon',
#   'riz',
#   'roug',
#   'cuit',
#   'poivron',
#   'roug',
#   'doux',
#   'huil',
#   'oliv',
#   'sel',
#   'marin',
#   'ail',
#   'epic',
#   'poivr',
#   'ingredient',
#   'issu',
#   'agricultur',
#   'biolog',
#   'votr',
#   'avis',
#   'nous',
#   'interess',
#   'vous',
#   'avez',
#   'de',
#   'question',
#   'de',
#   'san',
#   'ble',
#   'commentairao'],
#  ['eau',
#   'champignon',
#   'legum',
#   'oignon',
#   'poireau',
#   'celer',
#   'riz',
#   'arborio',
#   'crem',
#   'beurr',
#   'sel',
#   'marin',
#   'poudr',
#   'cep',
#   'epic',
#   'celer'],
#  ['legum',
#   'pure',
#   'tomat',
#   'courget',
#   'epinard',
#   'oignon',
#   'carott',
#   'feuill',
#   'riz',
#   'eau',
#   'filtre',
#   'fromag',
#   'mozzarel',
#   'ricott',
#   'fromag',
#   'blanc',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'basilic',
#   'fromag',
#   'italien',
#   'pat',
#   'dur',
#   'beurr',
#   'sel',
#   'marin',
#   'ail',
#   'epic'],
#  ['mozzarel',
#   'lait',
#   'vach',
#   'partiel',
#   'ecrem',
#   'farin',
#   'riz',
#   'pure',
#   'tomat',
#   'eau',
#   'filtre',
#   'farin',
#   'grain',
#   'tournesol',
#   'pomm',
#   'terr',
#   'fecul',
#   'tapioc',
#   'huil',
#   'oliv',
#   'jus',
#   'agav',
#   'huil',
#   'tournesol',
#   'oignon',
#   'roug',
#   'sel',
#   'marin',
#   'levur',
#   'miel',
#   'epic',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'ail',
#   'poivr',
#   'noir',
#   'contient',
#   'lait',
#   'soj',
#   'de',
#   'grain',
#   'tournesol'],
#  ['riz',
#   'arborio',
#   'cuit',
#   'riz',
#   'arborio',
#   'eau',
#   'champignon',
#   'eau',
#   'petit',
#   'pois',
#   'beurr',
#   'lait',
#   'fromag',
#   'styl',
#   'italien',
#   'pat',
#   'dur',
#   'lait',
#   'oignon',
#   'sel',
#   'marin',
#   'poudr',
#   'cep',
#   'poivr',
#   'noir',
#   'agricultur',
#   'biolog'],
#  ['pat',
#   'riz',
#   'farin',
#   'riz',
#   'fecul',
#   'pomm',
#   'terr',
#   'fecul',
#   'riz',
#   'farin',
#   'soj',
#   'lait',
#   'brocol',
#   'cheddar',
#   'lait',
#   'beurr',
#   'lait',
#   'farin',
#   'riz',
#   'doux',
#   'farin',
#   'riz',
#   'eau',
#   'filtre',
#   'farin',
#   'grain',
#   'tournesol',
#   'pomm',
#   'terr',
#   'fecul',
#   'tapioc',
#   'sel',
#   'marin',
#   'jus',
#   'agav',
#   'huil',
#   'oliv',
#   'huil',
#   'tournesol',
#   'lecithin',
#   'soj',
#   'emulsifi',
#   'levur',
#   'rocou',
#   'color',
#   'ingredient',
#   'issu',
#   'agricultur',
#   'biolog'],
#  ['feuill',
#   'riz',
#   'pure',
#   'tomat',
#   'fromag',
#   'ricott',
#   'lait',
#   'eau',
#   'fromag',
#   'mozzarel',
#   'lait',
#   'oignon',
#   'courget',
#   'epinard',
#   'huil',
#   'oliv',
#   'carott',
#   'basilic',
#   'italien',
#   'pat',
#   'dur',
#   'lait',
#   'beurr',
#   'lait',
#   'sel',
#   'marin',
#   'ail',
#   'poivr',
#   'noir',
#   'epic',
#   'ingredient',
#   'issu',
#   'agricultur',
#   'biolog'],
#  ['lait',
#   'coco',
#   'sucr',
#   'cann',
#   'extrait',
#   'vanill',
#   'sel',
#   'mer',
#   'emulsifi',
#   'epaiss',
#   'gomm',
#   'guar',
#   'gouss',
#   'vanill',
#   'ingredient',
#   'issu',
#   'agricultur',
#   'biolog'],
#  ['lait',
#   'coco',
#   'sirop',
#   'agav',
#   'poudr',
#   'cacao',
#   'non',
#   'sucr',
#   'chocolat',
#   'noir',
#   'extrait',
#   'vanill',
#   'sel',
#   'mer',
#   'gomm',
#   'guar'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'beurr',
#   'lait',
#   'sucr',
#   'fecul',
#   'mais',
#   'sel',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'arom',
#   'pour',
#   'le',
#   'allerad',
#   'voir',
#   'le',
#   'ingredient',
#   'indiqu',
#   'gras',
#   'convient',
#   'pas',
#   'aux',
#   'person',
#   'allerg',
#   'aux',
#   'aranhin',
#   'de',
#   'method',
#   'fabriqu',
#   'conserv',
#   'consommo'],
#  ['pomm'],
#  ['spaghet',
#   'cuit',
#   'semoul',
#   'ble',
#   'dur',
#   'contient',
#   'gluten',
#   'eau',
#   'colz',
#   'tomat',
#   'boulet',
#   'viand',
#   'cuit',
#   'porc',
#   'cuit',
#   'boeuf',
#   'cuit',
#   'farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'persil',
#   'sel',
#   'origan',
#   'huil',
#   'colz',
#   'pure',
#   'ail',
#   'poivr',
#   'noir',
#   'conc',
#   'levur',
#   'eau',
#   'tomat',
#   'oignon',
#   'huil',
#   'colz',
#   'vin',
#   'roug',
#   'carott',
#   'celer',
#   'vinaigr',
#   'vin',
#   'roug',
#   'sucr',
#   'sel',
#   'fecul',
#   'mais',
#   'gelifi',
#   'pectin',
#   'poivr',
#   'noir',
#   'conc',
#   'romarin',
#   'origan',
#   'pour',
#   'le',
#   'allergen',
#   'voir',
#   'le',
#   'ingredient',
#   'indiqu',
#   'gras',
#   'import',
#   'apre',
#   'cuisson',
#   'retir',
#   'le',
#   'produit',
#   'chaud',
#   'avec',
#   'precaut',
#   'conten'],
#  ['farin',
#   'ble',
#   'contient',
#   'carbonat',
#   'calcium',
#   'fer',
#   'acid',
#   'nicotin',
#   'thiamin',
#   'eau',
#   'beurr',
#   'ail',
#   'persil',
#   'sel',
#   'levur',
#   'farin',
#   'org',
#   'malt',
#   'agent',
#   'trait',
#   'farin',
#   'acid',
#   'ascorb'],
#  ['sucr',
#   'huil',
#   'palm',
#   'mass',
#   'cacao',
#   'beurr',
#   'cacao',
#   'lait',
#   'poudr',
#   'butteroil',
#   'lait',
#   'sirop',
#   'glucos',
#   'caf',
#   'deshvdrat',
#   'lait',
#   'poudr',
#   'enti',
#   'sirop',
#   'sucr',
#   'invert',
#   'lecithin',
#   'soj',
#   'cacao',
#   'maigr',
#   'poudr',
#   'arom',
#   'vanill',
#   'chocolat',
#   'blanc',
#   'contient',
#   'matier',
#   'sechedel',
#   'minimum',
#   'chocolat',
#   'lait',
#   'contient',
#   'cacao',
#   'minimum',
#   'matier',
#   'sech',
#   'lait',
#   'opir',
#   'cacaop',
#   'minimum'],
#  ['sucr',
#   'fructos',
#   'acid',
#   'citriqu',
#   'contient',
#   'moin',
#   'arom',
#   'naturel',
#   'acid',
#   'ascorb',
#   'vitamin',
#   'maltodextrin',
#   'phosphat',
#   'calcium',
#   'gomm',
#   'guar',
#   'gomm',
#   'xanthan',
#   'agent',
#   'textur',
#   'pyrophosphat',
#   'acid',
#   'sodium',
#   'color',
#   'artificiel',
#   'yellow',
#   'yellow',
#   'bha',
#   'agent',
#   'saveur'],
#  ['jello',
#   'pouding',
#   'cook',
#   'cream',
#   'facon',
#   'oreos',
#   'poid',
#   'net',
#   'ingredient',
#   'sucr',
#   'cook',
#   'farin',
#   'non',
#   'blanch',
#   'enrich',
#   'farin',
#   'ble',
#   'fer',
#   'reduit',
#   'vitamin',
#   'sucr',
#   'le',
#   'palm',
#   'etou',
#   'colz',
#   'cacao',
#   'alcalis',
#   'isoglucos',
#   'agent',
#   'lev',
#   'sel',
#   'lecithin',
#   'soj',
#   'chocolat',
#   'amidon',
#   'mais',
#   'arom',
#   'artificiel',
#   'amidon',
#   'mais',
#   'modif',
#   'moin',
#   'epaiss',
#   'color',
#   'sel',
#   'antemouss',
#   'antioxyd',
#   'contient',
#   'de',
#   'ogm',
#   'deciar',
#   'nutritionnel',
#   'pour',
#   'energ'],
#  ['noix',
#   'coco',
#   'biolog',
#   'rap',
#   'deshydrat',
#   'oconuf',
#   'color',
#   'may',
#   'vary',
#   'this',
#   'product',
#   'contain',
#   'added',
#   'produit',
#   'contient',
#   'aucun',
#   'sulfit',
#   'ajoute',
#   'alor',
#   'couleur',
#   'peut',
#   'vari'],
#  ['sucr',
#   'noiset',
#   'entier',
#   'beurr',
#   'cacao',
#   'lait',
#   'enti',
#   'deshydrat',
#   'pat',
#   'cacao',
#   'noiset',
#   'moulu',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'vanillin',
#   'arom'],
#  ['mass',
#   'cacao',
#   'sucr',
#   'beurr',
#   'cacao',
#   'cacao',
#   'poudr',
#   'miel',
#   'amand',
#   'blanc',
#   'oeuf',
#   'poudr',
#   'arom'],
#  ['mis',
#   'venscral',
#   'dub',
#   'noo',
#   'carton',
#   'pap',
#   'widely',
#   'recycled',
#   'dlin',
#   'trelad',
#   'eland',
#   'chocolat',
#   'noir',
#   'suiss',
#   'extra',
#   'fin',
#   'ngredient',
#   'mass',
#   'cacao',
#   'sucr',
#   'beurr',
#   'cacao*',
#   'cacao',
#   'poudr',
#   'arin',
#   'chocolat',
#   'noir',
#   'contient',
#   'cacao',
#   'minimum',
#   'convient',
#   'pas',
#   'aux',
#   'person',
#   'allergiqu',
#   'fruit',
#   'coqu',
#   'aux',
#   'arachid',
#   'aul',
#   'soj',
#   'raison',
#   'de',
#   'method',
#   'aoriqu',
#   'conserv',
#   'consomm',
#   'prefe',
#   'avant',
#   'voir',
#   'sur',
#   'dessous',
#   'embal',
#   'conserv',
#   'preferent',
#   'dan',
#   'endrot',
#   'sec',
#   'abri',
#   'lumier'],
#  ['chocolat',
#   'noir',
#   'sucr',
#   'chocolat',
#   'non',
#   'sucr',
#   'beurr',
#   'cacao',
#   'lecithin',
#   'soj',
#   'polyricinoleat',
#   'polyclycerol',
#   'arom',
#   'naturel',
#   'vanill',
#   'mais'],
#  ['farin',
#   'mais',
#   'huil',
#   'tournesol',
#   'piment',
#   'jalapefio',
#   'deshydrat',
#   'sel',
#   'sucr',
#   'oignon',
#   'deshydrat',
#   'tomat',
#   'deshydrate',
#   'extrait',
#   'levur',
#   'poivron',
#   'roug',
#   'deshydrat',
#   'ail',
#   'deshydrat',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'jus',
#   'citron',
#   'vert',
#   'deshydrat',
#   'poudr',
#   'piment',
#   'cumin',
#   'origan',
#   'piment',
#   'cayen',
#   'extrait',
#   'piment',
#   'extrait',
#   'coriandr',
#   'conserv'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'huil',
#   'palm',
#   'boeuf',
#   'hach',
#   'origin',
#   'britann',
#   'pomm',
#   'terr',
#   'oignon',
#   'rutabag',
#   'eau',
#   'oeuf',
#   'pasteuris',
#   'huil',
#   'colz',
#   'fecul',
#   'mais',
#   'sel',
#   'bouillon',
#   'boeuf',
#   'eau',
#   'boeuf',
#   'pure',
#   'tomat',
#   'oignon',
#   'carott',
#   'lait',
#   'enti',
#   'poivr',
#   'noir',
#   'moulu',
#   'farin',
#   'moutard'],
#  ['eau',
#   'grain',
#   'moutard',
#   'vinaigr',
#   'sel',
#   'raifort',
#   'acid',
#   'citriqu',
#   'sulfit'],
#  ['eau',
#   'grain',
#   'moutard',
#   'poivron',
#   'roug',
#   'vin',
#   'blanc',
#   'huil',
#   'tournesol',
#   'sel',
#   'ail',
#   'herb',
#   'arom',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'conserv',
#   'sulfit'],
#  ['vinaigr',
#   'balsam',
#   'mout',
#   'raisin',
#   'color',
#   'caramel',
#   'conserv',
#   'metabisulfit',
#   'potassium'],
#  ['sucr',
#   'frambois',
#   'gelifi',
#   'pectin',
#   'agrum',
#   'regul',
#   'acidit',
#   'citrat',
#   'sodium',
#   'conserv',
#   'temperatur',
#   'ambi',
#   'avant',
#   'ouvertur',
#   'fabrique',
#   'angleterr',
#   'par',
#   'wilkin',
#   'son',
#   'ltd',
#   'tiptre',
#   'essex',
#   'orf'],
#  ['sucr', 'myrtill', 'gelifi', 'pectin', 'agrum'],
#  ['sucr',
#   'gingembr',
#   'gelifi',
#   'pectin',
#   'agrum',
#   'regul',
#   'acidit',
#   'acid',
#   'citriqu'],
#  ['sucr', 'orang', 'sevill'],
#  ['sucr', 'orang', 'sevill', 'gingembr', 'gelifi', 'pectin', 'agrum'],
#  ['sucr', 'orang', 'sevill', 'pectin', 'agrum'],
#  ['marmelad',
#   'oranc',
#   'citron',
#   'vert',
#   'san',
#   'zest',
#   'prepare',
#   'avec',
#   'orang',
#   'pour',
#   'avec',
#   'citron',
#   'vert',
#   'ieneur',
#   'total',
#   'sucr',
#   'pour',
#   'ynreurlt',
#   'ient',
#   'sucr',
#   'orang',
#   'variet',
#   'citron',
#   'vert',
#   'huil',
#   'citron',
#   'vert',
#   'gelifi',
#   'pectin',
#   'agrum',
#   'ciuul',
#   'acidit',
#   'citrat',
#   'sod',
#   'temperatur',
#   'ambi',
#   'avant',
#   'fabrique',
#   'angleterr',
#   'son',
#   'ltd',
#   'tlptre',
#   'essex',
#   'rmation',
#   'nutritionnel',
#   'pour',
#   'grass',
#   'acid',
#   'gras',
#   'satur'],
#  ['sucr',
#   'citron',
#   'regul',
#   'acidit',
#   'citrat',
#   'sodium',
#   'gelifi',
#   'pectin',
#   'agrum'],
#  ['marmelad',
#   'citron',
#   'avec',
#   'ecorc',
#   'moyen',
#   'prepare',
#   'avec',
#   'orang',
#   'pour',
#   'prepare',
#   'avec',
#   'citron',
#   'pour',
#   'teneur',
#   'total',
#   'sucr',
#   'pour',
#   'ingredient',
#   'sucr',
#   'orang',
#   'variet',
#   'sevill',
#   'citron',
#   'gelifi',
#   'pectin',
#   'agrum',
#   'regul',
#   'acidit',
#   'citrat',
#   'sodium'],
#  ['sugar', 'orang', 'lemon', 'grapefruit'],
#  ['raisin',
#   'sultan',
#   'corinth',
#   'raisin',
#   'sucr',
#   'cidr',
#   'chapelur',
#   'farin',
#   'ble',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'sel',
#   'levur',
#   'suif',
#   'vegetal',
#   'huil',
#   'palm',
#   'huil',
#   'tournesol',
#   'farin',
#   'riz',
#   'melang',
#   'ecorc',
#   'ecorc',
#   'orang',
#   'ecorc',
#   'citron',
#   'sucr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'sel',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'oeuf',
#   'entier',
#   'marmelad',
#   'orang',
#   'tawny',
#   'sucr',
#   'orang',
#   'sevill',
#   'brandy',
#   'farin',
#   'ble',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'melang',
#   'epic',
#   'sel'],
#  ['raisin',
#   'sultan',
#   'corinth',
#   'raisin',
#   'sucr',
#   'cidr',
#   'chapelur',
#   'farin',
#   'ble',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'sel',
#   'levur',
#   'suif',
#   'vegetal',
#   'huil',
#   'palm',
#   'huil',
#   'toumesol',
#   'farin',
#   'riz',
#   'melang',
#   'ecorc',
#   'ecorc',
#   'orang',
#   'ecorc',
#   'citron',
#   'sucr',
#   'sirop',
#   'glucosefructos',
#   'sel',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'oeuf',
#   'entier',
#   'marmelad',
#   'orang',
#   'tawny',
#   'sucr',
#   'orang',
#   'sevill',
#   'brandy',
#   'farin',
#   'ble',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'melang',
#   'epic',
#   'sel',
#   'pour',
#   'le',
#   'allergen',
#   'ytompr',
#   'le',
#   'cereal',
#   'conten',
#   'gluten',
#   'voir',
#   'le',
#   'ingredient',
#   'marqu',
#   'gras'],
#  ['sucr',
#   'beurr',
#   'lait',
#   'brandy',
#   'pour',
#   'le',
#   'allergen',
#   'voir',
#   'le',
#   'ingredient',
#   'marqu'],
#  ['sucr',
#   'beurr',
#   'sal',
#   'lait',
#   'jus',
#   'citron',
#   'jaun',
#   'oeuf',
#   'elevag',
#   'plein',
#   'air',
#   'oeoeuf',
#   'entier',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'gelifi',
#   'pectin',
#   'agrum',
#   'huil',
#   'citron'],
#  ['sucr',
#   'jus',
#   'fruit',
#   'passion',
#   'beurr',
#   'lait',
#   'jaun',
#   'oeuf',
#   'oeuf',
#   'enti',
#   'gelifi',
#   'pectin',
#   'agrum'],
#  ...]

# %%
print(os.path.exists("./data/filtered_openfoodfacts.csv"))
# Out:
# True

# %%
from collections import defaultdict
ingredients = defaultdict(int)
for ingr_list in test_list:
    for ingr in ingr_list:
        ingredients[ingr] += 1
        
ingredients
# Out:
# defaultdict(int,
#             {'eau': 108853,
#              'grain': 28229,
#              'tegu': 192,
#              'moutard': 19269,
#              'vinaigr': 22672,
#              'vin': 9711,
#              'roug': 12962,
#              'sel': 159427,
#              'sucr': 139948,
#              'mout': 1106,
#              'raisin': 8005,
#              'oignon': 30623,
#              'color': 29900,
#              'extrait': 38049,
#              'carott': 18114,
#              'paprik': 8913,
#              'huil': 90869,
#              'tournesol': 44432,
#              'son': 2285,
#              'cet': 556,
#              'uniqu': 409,
#              'disponibl': 50,
#              'chez': 226,
#              'court': 100,
#              'paill': 19,
#              'antioxyd': 25067,
#              'erythorbat': 2510,
#              'sodium': 44565,
#              'caramel': 9403,
#              'origin': 27291,
#              'tomat': 29621,
#              'mayonnais': 788,
#              'colz': 29878,
#              'jaun': 10479,
#              'oeuf': 49097,
#              'curcum': 6090,
#              'dextros': 23663,
#              'stabilis': 19366,
#              'gomm': 23315,
#              'cellulos': 1416,
#              'conserv': 37035,
#              'sorbat': 5982,
#              'potassium': 15337,
#              'caroten': 2878,
#              'arom': 102792,
#              'baguet': 64,
#              'poit': 11,
#              'pain': 2675,
#              'farin': 85574,
#              'ble': 98164,
#              'levur': 22275,
#              'gluten': 28694,
#              'mait': 27,
#              'desactive': 926,
#              'acid': 65969,
#              'ascorb': 12599,
#              'garnitur': 2520,
#              'fromag': 11386,
#              'chevr': 2761,
#              'lait': 136149,
#              'pasteuris': 10873,
#              'vach': 5565,
#              'ferment': 19169,
#              'lactiqu': 16392,
#              'daffinag': 5,
#              'coagul': 2833,
#              'saladg': 1,
#              'oliv': 16995,
#              'basilic': 6845,
#              'paln': 9,
#              'suedois': 32,
#              'seigl': 4311,
#              'non': 5993,
#              'hydrogene': 3228,
#              'sirop': 43025,
#              'levain': 2793,
#              'poudr': 97078,
#              'lev': 16846,
#              'fructos': 11248,
#              'agent': 9121,
#              'trait': 5558,
#              'enzym': 1797,
#              'saumon': 3597,
#              'atlant': 1786,
#              'fran': 32,
#              'fdorveg': 1,
#              'eeos': 1,
#              'echlli': 1,
#              'salad': 1578,
#              'blanoz': 1,
#              'oulet': 16,
#              'taboul': 32,
#              'legum': 7917,
#              'menth': 3019,
#              'jus': 38936,
#              'citron': 26615,
#              'blanc': 23047,
#              'crem': 24969,
#              'marron': 820,
#              'vanille': 28,
#              'pur': 2285,
#              'chataign': 991,
#              'naturel': 63457,
#              'vanilo': 1,
#              'pure': 18881,
#              'abricot': 4304,
#              'minimun': 11,
#              'aux': 6495,
#              'cereql': 2,
#              'melang': 3329,
#              'cereal': 6298,
#              'rain': 594,
#              'complet': 9033,
#              'orge': 11684,
#              'avoln': 20,
#              'mais': 27755,
#              'semoul': 11580,
#              'dur': 10065,
#              'ci': 119,
#              'millet': 977,
#              'lin': 2806,
#              'sesam': 11181,
#              'copp': 64,
#              'echin': 149,
#              'porc': 31326,
#              'fenouil': 1231,
#              'nitrat': 2226,
#              'nitrit': 9187,
#              'bressan': 1,
#              'malt': 13300,
#              'filet': 5721,
#              'poulet': 11804,
#              'brais': 31,
#              'acidifi': 27023,
#              'lactat': 2229,
#              'acetat': 2294,
#              'amidon': 46548,
#              'modif': 13475,
#              'manioc': 3028,
#              'glucos': 33298,
#              'gelifi': 11060,
#              'eayam$xyd': 1,
#              'erythefbat': 1,
#              'grafnel': 1,
#              'tomatenx': 1,
#              'glycerin': 536,
#              'spirulin': 1067,
#              'maxim': 10,
#              'fruit': 33530,
#              'camu': 27,
#              'myrciari': 2,
#              'dubi': 2,
#              'vert': 10511,
#              'pat': 28688,
#              'tartin': 178,
#              'noiset': 11344,
#              'region': 119,
#              'piemont': 76,
#              'avec': 7904,
#              'edulcor': 4722,
#              'maltitol': 1077,
#              'ingredient': 17761,
#              'ecrem': 30928,
#              'cacao': 62375,
#              'lecithin': 29402,
#              'allergen': 2445,
#              'present': 656,
#              'riz': 21127,
#              'precuit': 3284,
#              'viand': 24671,
#              'dind': 3745,
#              'franc': 22778,
#              'fraich': 7563,
#              'epaiss': 21193,
#              'champignon': 4377,
#              'paris': 1713,
#              'sulfit': 9737,
#              'beurr': 48043,
#              'emulsifi': 42354,
#              'matier': 9717,
#              'grass': 9349,
#              'vegetal': 23612,
#              'coprah': 2627,
#              'deshydrat': 6758,
#              'protein': 23407,
#              'carraghenan': 7325,
#              'quot': 2144,
#              'produit': 11863,
#              'issus': 11043,
#              'agricultur': 16670,
#              'biolog': 20567,
#              'chocolat': 20522,
#              'min': 3132,
#              'soj': 46601,
#              'arab': 1778,
#              'enrobag': 3577,
#              'shellac': 417,
#              'cir': 2165,
#              'carnaub': 1346,
#              'abeil': 685,
#              'concentr': 42531,
#              'patat': 668,
#              'douc': 1394,
#              'rad': 702,
#              'eee': 14,
#              'peut': 14094,
#              'conten': 15917,
#              'de': 25342,
#              'trac': 24763,
#              'coqu': 18251,
#              'eeee': 1,
#              'peuvent': 289,
#              'avoir': 473,
#              'et': 42,
#              'indesir': 180,
#              'sur': 6931,
#              'activit': 249,
#              'attent': 360,
#              'le': 8175,
#              'enfant': 638,
#              'nutritionel': 75,
#              'valeur': 1169,
#              'energel': 2,
#              'ique': 66,
#              'rucol': 3,
#              'vierg': 8754,
#              'extra': 8571,
#              'noix': 13164,
#              'cajou': 1643,
#              'parmigiano': 412,
#              'reggiano': 416,
#              'aop': 1918,
#              'presur': 5420,
#              'ail': 24521,
#              'artichaut': 450,
#              'regul': 1798,
#              'acidit': 14161,
#              'lentill': 2223,
#              'gazeifie': 1812,
#              'haut': 859,
#              'teneur': 1765,
#              'artificiel': 604,
#              'mouss': 461,
#              'graiss': 12160,
#              'karit': 1346,
#              'maigr': 10411,
#              'dextrin': 875,
#              'carbonat': 17847,
#              'ammonium': 5365,
#              'rich': 1529,
#              'part': 1808,
#              'mat': 498,
#              'genet': 68,
#              'benzoat': 700,
#              'exhausteur': 3837,
#              'gout': 4957,
#              'humect': 2501,
#              'deauillai': 1,
#              'flocon': 7983,
#              'pomm': 38536,
#              'saccharos': 2020,
#              'the': 3883,
#              'noir': 14525,
#              'aromatis': 1673,
#              'fleur': 3319,
#              'violet': 257,
#              'parsem': 8,
#              'bleuet': 139,
#              'chin': 336,
#              'zest': 1216,
#              'orang': 10062,
#              'cannel': 3354,
#              'saveur': 1345,
#              'pistach': 1686,
#              'cristallis': 182,
#              'citriqu': 26898,
#              'denre': 424,
#              'alimentair': 2425,
#              'cartham': 1380,
#              'addit': 481,
#              'frambois': 6480,
#              'ceris': 3027,
#              'cass': 3199,
#              'cann': 14853,
#              'pepit': 2520,
#              'minimum': 4668,
#              'tendr': 1672,
#              'isigny': 398,
#              'sal': 2659,
#              'enti': 20345,
#              'guerand': 3457,
#              'vanill': 20959,
#              'bicarbonat': 3371,
#              'soud': 648,
#              'sucroester': 246,
#              'gras': 20225,
#              'diphosphat': 7271,
#              'dissod': 1,
#              'moutjrd': 1,
#              'velour': 17,
#              'ray': 19,
#              'dessert': 355,
#              'pass': 27,
#              'prealablem': 1,
#              'bien': 455,
#              'agit': 239,
#              'avant': 2275,
#              'emploi': 251,
#              'souhait': 45,
#              'ure': 117,
#              'distanc': 5,
#              'pas': 2118,
#              'inger': 11,
#              'direcelt': 1,
#              'sin': 322,
#              'aler': 2,
#              'vapeur': 252,
#              'directem': 2,
#              'vit': 474,
#              'excess': 328,
#              'utilis': 3893,
#              'sev': 57,
#              'perfor': 4,
#              'brul': 29,
#              'lam': 24,
#              'aver': 6,
#              'une': 4391,
#              'flamm': 21,
#              'gard': 188,
#              'bomb': 5,
#              'hor': 603,
#              'tfdernent': 1,
#              'est': 2887,
#              'possibledan': 1,
#              'aval': 36,
#              'tel': 223,
#              'quel': 52,
#              'endroit': 905,
#              'sec': 6227,
#              'frais': 18586,
#              'soleil': 284,
#              'elauw': 1,
#              'dat': 715,
#              'net': 1736,
#              'ult': 9,
#              'kdden': 1,
#              'voor': 76,
#              'cjebrujk': 1,
#              'palm': 16375,
#              'illip': 69,
#              'invert': 5063,
#              'eii': 1131,
#              'ester': 1824,
#              'polyglycer': 139,
#              'monooleat': 3,
#              'polyoxyethylen': 10,
#              'sorbitan': 116,
#              'guar': 8826,
#              'carboxymethylcellu': 2,
#              'los': 45,
#              'correcteur': 12511,
#              'glucono': 298,
#              'delt': 325,
#              'lactin': 1,
#              'autr': 6832,
#              'caeao': 3,
#              'enfer': 9,
#              'cannet': 21,
#              'nougat': 296,
#              'frac': 36,
#              'glutenzsoj': 1,
#              'conseil': 900,
#              'entre': 1298,
#              'abri': 962,
#              'chaleur': 884,
#              'humidit': 817,
#              'plong': 48,
#              'cuilleren': 1,
#              'tass': 96,
#              'chaud': 244,
#              'epeautr': 2182,
#              'rev': 2,
#              'neptun': 2,
#              'spelt': 26,
#              'dream': 1,
#              'ingredienten': 286,
#              'speltbloem': 1,
#              'tomaat': 13,
#              'spinaz': 7,
#              'bietquot': 1,
#              'epinard': 2474,
#              'betterav': 3241,
#              'contient': 22714,
#              'degraisse': 177,
#              'lactoserum': 9628,
#              'dan': 9171,
#              'usin': 275,
#              'qui': 1835,
#              'congel': 402,
#              'recongel': 321,
#              'sorbitol': 3745,
#              'aspartam': 946,
#              'magnesium': 2242,
#              'vichy': 38,
#              'consomm': 3201,
#              'effet': 509,
#              'laxat': 247,
#              'sourc': 1926,
#              'phenylalanin': 488,
#              'passiflor': 40,
#              'aubepin': 21,
#              'eschscholtzi': 3,
#              'asperul': 6,
#              'odor': 41,
#              'melilot': 2,
#              'lactos': 13650,
#              'eerem': 2,
#              'jour': 753,
#              'apre': 1149,
#              'nichon': 2,
#              'ttc': 9,
#              'paysann': 16,
#              'igre': 8,
#              'doux': 2238,
#              'deux': 120,
#              'fois': 223,
#              'kuhn': 1,
#              'leur': 339,
#              'croqu': 209,
#              'il': 81,
#              'sont': 3549,
#              'prepar': 6184,
#              'sclon': 1,
#              'kijhnc': 1,
#              'resist': 31,
#              'cornichon': 1497,
#              'cou': 58,
#              'couvcrdc': 1,
#              'ouvcrtorc': 1,
#              'conscrvcr': 6,
#              'rapid': 300,
#              'arachid': 5584,
#              'iecithin': 19,
#              'phosphor': 382,
#              'dont': 12103,
#              'cafein': 802,
#              'alcool': 14092,
#              'pepin': 301,
#              'riboflavin': 1270,
#              'marmelad': 51,
#              'inqredlent': 6,
#              'pectin': 10471,
#              'dacidit': 70,
#              'citrat': 6371,
#              'complex': 515,
#              'cuivr': 1169,
#              'chlorophyllin': 388,
#              'lutein': 1098,
#              'pour': 10088,
#              'condltlon': 10,
#              'diutilis': 2,
#              'orahg': 1,
#              'lfi': 5,
#              'egul': 2,
#              'mdiurn': 1,
#              'dorang': 64,
#              'prot': 68,
#              'ttnsomm': 1,
#              'preicttit': 1,
#              'lquot': 15,
#              'voir': 1984,
#              'sir': 19,
#              'lumier': 457,
#              'aue': 12,
#              'ouvertur': 898,
#              'refriger': 594,
#              'conmmm': 1,
#              'emain': 1,
#              'energ': 1015,
#              'kcal': 114,
#              'olg': 5,
#              'ture': 2,
#              'glucid': 396,
#              'wcre': 10,
#              'fibr': 7621,
#              'convient': 467,
#              'vegetar': 3,
#              'len': 25,
#              'vegan': 114,
#              'coeliaqu': 17,
#              'olttrlbu': 1,
#              'par': 3600,
#              'ij': 4,
#              'ndukmabk': 1,
#              'azeifie': 3,
#              'vegetau': 2,
#              'preferent': 1050,
#              'chou': 1343,
#              'bovin': 2605,
#              'iod': 1256,
#              'iodat': 212,
#              'epic': 29062,
#              'poivr': 25221,
#              'coriandr': 4353,
#              'piment': 8486,
#              'chil': 603,
#              'carv': 385,
#              'nom': 45,
#              'scientif': 8,
#              'pollachius': 29,
#              'viren': 23,
#              'pech': 3882,
#              'nord': 913,
#              'island': 73,
#              'categor': 558,
#              'engin': 26,
#              'chalut': 314,
#              'terr': 24666,
#              'tapioc': 3109,
#              'dtepic': 8,
#              'persil': 9044,
#              'celer': 12627,
#              'dorad': 20,
#              'sebast': 6,
#              'sauc': 9611,
#              'bechamel': 389,
#              'jam': 201,
#              'bon': 296,
#              'cuit': 10311,
#              'superieur': 4018,
#              'jambon': 6915,
#              'ascorbat': 4687,
#              'emmental': 4293,
#              'comt': 499,
#              'muscad': 3666,
#              'deshydrate': 3770,
#              'mono': 9694,
#              'diglycerid': 9026,
#              'pyrophosphat': 657,
#              'gris': 328,
#              'mollusqu': 3842,
#              'poisson': 10701,
#              'crustac': 5512,
#              'potiron': 859,
#              'dem': 3013,
#              'cam': 23,
#              'hais': 4,
#              'bas': 12741,
#              'agar': 1686,
#              'biscuit': 1400,
#              'gouss': 1374,
#              'bourbon': 1101,
#              'broye': 525,
#              'caroub': 5203,
#              'coagu': 5,
#              'lant': 18,
#              'povr': 17,
#              'pet': 2478,
#              'fev': 2974,
#              'xannan': 1,
#              'alginat': 1411,
#              'saint': 899,
#              'jacqu': 663,
#              'echalot': 3641,
#              'poireau': 4194,
#              'mer': 3844,
#              'feuillete': 542,
#              'tournerot': 1,
#              'grai': 20,
#              'cvc': 1,
#              'diphoe>>phatceu': 1,
#              'carbonate': 6,
#              'amelior': 228,
#              'digty': 1,
#              'cerid': 18,
#              'diacid': 108,
#              'tcr': 3,
#              'diacethytartriquc': 1,
#              'der': 78,
#              'rnono': 1,
#              'digtycerid': 40,
#              'farc': 1731,
#              'mozzarctl': 1,
#              'fin': 5203,
#              'set': 244,
#              'microbien': 1042,
#              'ractettc': 1,
#              'fi': 134,
#              'tait': 279,
#              'ait': 273,
#              'bouillon': 3725,
#              'maltodcxtrin': 2,
#              'pan': 757,
#              'curcu': 4,
#              'plant': 9529,
#              'aromat': 12770,
#              'cayen': 1091,
#              'origan': 3551,
#              'marjolain': 601,
#              'xanthan': 10772,
#              'raviol': 287,
#              'dauphin': 18,
#              'igp': 596,
#              'label': 379,
#              'chlorur': 3136,
#              'calcium': 8789,
#              'courget': 3625,
#              'grille': 2891,
#              'eminc': 693,
#              'aiguillet': 390,
#              'prefr': 264,
#              'oreillon': 60,
#              'nappag': 529,
#              'liquid': 2972,
#              'patissier': 290,
#              'amand': 11127,
#              'chicken': 31,
#              'nachos': 3,
#              'morceau': 3508,
#              'marin': 5535,
#              'cumin': 2709,
#              'fenugrec': 658,
#              'gingembr': 3841,
#              'quatr': 60,
#              'panur': 594,
#              'chip': 282,
#              'cheddar': 702,
#              'doubl': 1639,
#              'poivron': 8602,
#              'jalapeho': 1,
#              'mexicain': 73,
#              'feuill': 2218,
#              'malv': 7,
#              'verticefat': 1,
#              'mauv': 67,
#              'frise': 220,
#              'boeuf': 5288,
#              'emball': 138,
#              'sous': 1600,
#              'atmospher': 815,
#              'protectric': 768,
#              'nutritinnel': 2,
#              'moyen': 1213,
#              'ivlarmit': 1,
#              'original': 71,
#              'levu': 19,
#              'edientg': 2,
#              'acl': 16,
#              'niacin': 1789,
#              'flamin': 1,
#              'vitamin': 9926,
#              'foliqu': 1219,
#              'vitamino': 9,
#              'tondit': 1,
#              'congerv': 3,
#              'utiligatlon': 1,
#              'avril': 3,
#              'lot': 958,
#              'las': 22,
#              'conget': 2,
#              'vor': 32,
#              'dang': 16,
#              'tndroit': 1,
#              'aec': 4,
#              'declar': 117,
#              'nutritionnel': 745,
#              'eneraetlqu': 1,
#              'xipldeg': 1,
#              'qrag': 1,
#              'gatureg': 1,
#              'tracec': 4,
#              'iglucideg': 1,
#              'fibreg': 1,
#              'thiamin': 1498,
#              'rda': 2,
#              'apport': 534,
#              'journali': 33,
#              'recommand': 118,
#              'tomato': 126,
#              'ketchup': 380,
#              'herb': 4294,
#              'contiennent': 382,
#              'maliqu': 1654,
#              'glycerol': 3554,
#              'laitier': 1643,
#              'madelein': 61,
#              'choconoir': 1,
#              'nappe': 26,
#              'anhydr': 1836,
#              'poul': 3111,
#              'eleve': 2563,
#              'plein': 2062,
#              'air': 2035,
#              'tout': 1084,
#              'vos': 371,
#              'remarqu': 41,
#              'suggest': 92,
#              'bienvenu': 2,
#              'contact': 229,
#              'notr': 423,
#              'servic': 334,
#              'qualit': 3292,
#              'indiqu': 604,
#              'numero': 274,
#              'concern': 36,
#              'figur': 158,
#              'dessus': 112,
#              'boit': 323,
#              'mainten': 51,
#              'milieu': 32,
#              'temper': 35,
#              'froid': 876,
#              'propylen': 62,
#              'glycol': 99,
#              'tart': 114,
#              'sucralos': 1849,
#              'plantaardig': 33,
#              'propyleenglycol': 1,
#              'aardbeientaartarom': 1,
#              'zout': 185,
#              'zulaten': 2,
#              'pflanzlich': 16,
#              'confit': 1988,
#              'pastequ': 287,
#              'bigarreau': 250,
#              'ecorc': 3204,
#              'anhydrid': 1324,
#              'sulfur': 1361,
#              'ordinair': 2170,
#              'rhum': 1525,
#              'antioxygen': 1119,
#              'soit': 1474,
#              'reconstitu': 2649,
#              'bi': 165,
#              'respect': 159,
#              'vous': 604,
#              'offre': 21,
#              'votr': 640,
#              'patisser': 115,
#              'denature': 19,
#              'instantaneis': 14,
#              'cacahuet': 1710,
#              'isolat': 571,
#              'inulin': 781,
#              'avoin': 6412,
#              'san': 6457,
#              'mineral': 3880,
#              'oxyd': 1003,
#              'fumarat': 106,
#              'ferreux': 515,
#              'selenit': 470,
#              'zinc': 1250,
#              'manganes': 615,
#              'chrom': 197,
#              'iii': 135,
#              'iodur': 742,
#              'caf': 3616,
#              'decafein': 94,
#              'phosphat': 3249,
#              'alpha': 714,
#              'tocopheryl': 65,
#              'nicotinamid': 224,
#              'retinyl': 51,
#              'pantothenat': 287,
#              'pantothen': 728,
#              'biotin': 680,
#              'cholecalciferol': 148,
#              'phylloquinon': 27,
#              'chlorhydrat': 302,
#              'pyridoxin': 250,
#              'cyanocobalamin': 156,
#              'pteroylmonoglutam': 82,
#              'glycosid': 789,
#              'steviol': 795,
#              'papay': 486,
#              'grenad': 415,
#              'myrtill': 2184,
#              'antiagglomer': 1117,
#              'dioxyd': 1046,
#              'silicium': 359,
#              'oeufsfr': 9,
#              'beurreconcentr': 7,
#              'debl': 109,
#              'cep': 925,
#              'capr': 873,
#              'thon': 1831,
#              'aubergin': 1952,
#              'patissi': 2026,
#              'pulp': 4141,
#              'anan': 3267,
#              'curcumin': 1946,
#              'equivalent': 893,
#              'maltodextrin': 6788,
#              'exprim': 3564,
#              'ensembl': 240,
#              'sarrasin': 1588,
#              'souchet': 48,
#              'toast': 468,
#              'fecul': 8393,
#              'hydroxypropyl': 86,
#              'methyl': 39,
#              'envelopp': 724,
#              'psyllium': 545,
#              'nectar': 106,
#              'coco': 11119,
#              'caracter': 97,
#              'decortique': 1131,
#              'toaste': 320,
#              'germ': 1029,
#              'total': 3201,
#              'anis': 946,
#              'clous': 403,
#              'girofl': 1858,
#              'etoil': 192,
#              'scicr': 1,
#              'saindoux': 452,
#              'sauvag': 632,
#              'glycin': 51,
#              'cuiss': 1304,
#              'peau': 1399,
#              'fourre': 99,
#              'fourrag': 1648,
#              'concentre': 2177,
#              'burg': 48,
#              'pavot': 1040,
#              'olza': 4,
#              'propionat': 1094,
#              'elil': 1,
#              'rehydrat': 3410,
#              'font': 1333,
#              'tourneso': 41,
#              'guacamol': 27,
#              'avocat': 255,
#              'hass': 16,
#              'jalapeno': 201,
#              'batavi': 43,
#              'focon': 11,
#              'davoin': 28,
#              'arin': 81,
#              'oligoructos': 1,
#              'brun': 1404,
#              'croustil': 7,
#              'suar': 9,
#              'calaum': 3,
#              'hul': 90,
#              'emulsii': 10,
#              'lecthin': 24,
#              'moditf': 1,
#              'damand': 23,
#              'moulu': 2550,
#              'tocopherol': 1766,
#              'socium': 2,
#              'calcum': 9,
#              'aom': 12,
#              'inorm': 1,
#              'alergeness': 1,
#              'aleroen': 1,
#              'eart': 4,
#              'cauet': 1,
#              'rehydrate': 1349,
#              'citon': 37,
#              'foi': 4281,
#              'canard': 5484,
#              'perigord': 100,
#              'armagnac': 1044,
#              'gorg': 787,
#              'dijon': 2666,
#              'froment': 3413,
#              'leg': 127,
#              'bet': 2444,
#              'roset': 109,
#              'rot': 1290,
#              'pois': 7802,
#              'rape': 1312,
#              'disulfit': 2325,
#              'oltriqu': 1,
#              'fer': 2461,
#              'smyrn': 57,
#              'blecontient': 2,
#              'desseche': 40,
#              'sech': 2160,
#              'golden': 126,
#              'syrup': 123,
#              'levag': 76,
#              'mel': 1090,
#              'eclat': 1960,
#              'conf': 590,
#              'ingembr': 103,
#              'grossier': 41,
#              'banan': 2907,
#              'bai': 1704,
#              'sureau': 1653,
#              'typ': 796,
#              'vinaigret': 468,
#              'passion': 1990,
#              'concombr': 863,
#              'mentbejus': 1,
#              'blanch': 1679,
#              'bleu': 1062,
#              'penicillium': 218,
#              'roquefort': 329,
#              'mozzarel': 1971,
#              'provolon': 69,
#              'piqu': 122,
#              'animal': 1601,
#              'pecorino': 241,
#              'romano': 144,
#              'breb': 1547,
#              'reibekas': 1,
#              'eventuel': 8518,
#              'ulir': 1,
#              'mi': 658,
#              'tranch': 597,
#              'tortill': 119,
#              'fum': 3679,
#              'fusill': 85,
#              'tartar': 58,
#              'grecqu': 94,
#              'bill': 188,
#              'pesto': 184,
#              'italien': 323,
#              'ran': 37,
#              'padano': 464,
#              'babeurr': 730,
#              'pignon': 485,
#              'pin': 413,
#              'trais': 44,
#              'frit': 1142,
#              'volaill': 2610,
#              'salaison': 2443,
#              'algu': 1606,
#              'euchem': 207,
#              'transforme': 311,
#              'romarin': 4317,
#              'bacon': 397,
#              'carr': 260,
#              'rap': 1451,
#              'acidifli': 2,
#              'comm': 304,
#              'bagnat': 1,
#              'acidifiantacid': 27,
#              'sei': 138,
#              'tapenad': 30,
#              'anchois': 1236,
#              'basil': 39,
#              'provenc': 1873,
#              'cholin': 216,
#              'bitartrat': 192,
#              'racin': 667,
#              'chicore': 1412,
#              'bruxel': 59,
#              'cichorium': 18,
#              'intybus': 14,
#              'sativum': 12,
#              'capsul': 234,
#              'hydroxypropylmethycellulos': 2,
#              'coeur': 530,
#              'petal': 927,
#              'cynar': 14,
#              'scolymus': 11,
#              'pissenl': 81,
#              'taraxacum': 16,
#              'officinal': 149,
#              'rhizom': 39,
#              'long': 1034,
#              'curcuminoid': 1,
#              'bagel': 11,
#              'raffine': 514,
#              'earnitur': 72,
#              'fongiqu': 151,
#              'pasteurise': 1737,
#              'fourm': 29,
#              'ambert': 26,
#              'giucos': 25,
#              'crouton': 198,
#              'toueneseol': 1,
#              'ceuf': 555,
#              'remoulad': 54,
#              'transform': 8252,
#              'aucun': 93,
#              'vegetarien': 363,
#              'vegetalien': 111,
#              'kjkcal': 11,
#              'lipid': 116,
#              'malit': 2,
#              'permeat': 304,
#              'eaiii': 10,
#              'decor': 1105,
#              'garhitur': 1,
#              'sodiumsalad': 1,
#              'triangl': 20,
#              'eiii': 177,
#              'arnitur': 41,
#              'ros': 1333,
#              'haricot': 3659,
#              'cub': 1102,
#              'mesclun': 10,
#              'mimolet': 78,
#              'rocou': 1571,
#              'carotenoid': 3093,
#              ...})

# %%
clean_data = list(map(lambda y: list(filter(lambda x: ingredients[x] > 50, y)), test_list))
clean_data
# Out:
# [['eau',
#   'grain',
#   'tegu',
#   'moutard',
#   'vinaigr',
#   'vin',
#   'roug',
#   'sel',
#   'vin',
#   'roug',
#   'sucr',
#   'mout',
#   'raisin',
#   'oignon',
#   'color',
#   'extrait',
#   'carott',
#   'extrait',
#   'paprik',
#   'huil',
#   'tournesol',
#   'son',
#   'moutard',
#   'sel',
#   'cet',
#   'moutard',
#   'uniqu',
#   'chez',
#   'court'],
#  ['antioxyd',
#   'erythorbat',
#   'sodium',
#   'color',
#   'caramel',
#   'origin',
#   'tomat',
#   'mayonnais',
#   'huil',
#   'colz',
#   'eau',
#   'jaun',
#   'oeuf',
#   'vinaigr',
#   'moutard',
#   'eau',
#   'grain',
#   'moutard',
#   'sel',
#   'vinaigr',
#   'curcum',
#   'sel',
#   'dextros',
#   'stabilis',
#   'gomm',
#   'cellulos',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'color',
#   'caroten',
#   'arom'],
#  ['baguet',
#   'vin',
#   'pain',
#   'baguet',
#   'farin',
#   'ble',
#   'eau',
#   'sel',
#   'levur',
#   'gluten',
#   'farin',
#   'ble',
#   'levur',
#   'desactive',
#   'acid',
#   'ascorb',
#   'garnitur',
#   'fromag',
#   'chevr',
#   'lait',
#   'pasteuris',
#   'lait',
#   'vach',
#   'lait',
#   'chevr',
#   'sel',
#   'ferment',
#   'lactiqu',
#   'coagul',
#   'tomat',
#   'huil',
#   'oliv',
#   'basilic'],
#  ['farin',
#   'ble',
#   'eau',
#   'farin',
#   'seigl',
#   'sucr',
#   'huil',
#   'colz',
#   'non',
#   'hydrogene',
#   'sirop',
#   'sucr',
#   'gluten',
#   'ble',
#   'sel',
#   'levur',
#   'levain',
#   'poudr',
#   'seigl',
#   'poudr',
#   'lev',
#   'fructos',
#   'agent',
#   'trait',
#   'farin',
#   'enzym',
#   'garnitur',
#   'saumon',
#   'atlant',
#   'sel',
#   'origin',
#   'salad',
#   'fromag'],
#  ['legum',
#   'huil',
#   'colz',
#   'sel',
#   'menth',
#   'jus',
#   'citron',
#   'sucr',
#   'conserv',
#   'arom'],
#  ['fromag', 'blanc', 'crem', 'marron', 'sucr', 'pur', 'chataign', 'naturel'],
#  ['jus', 'pure', 'abricot', 'eau', 'sucr'],
#  ['pain',
#   'aux',
#   'farin',
#   'farin',
#   'ble',
#   'gluten',
#   'ble',
#   'melang',
#   'cereal',
#   'rain',
#   'farin',
#   'ble',
#   'complet',
#   'crem',
#   'orge',
#   'farin',
#   'farin',
#   'mais',
#   'semoul',
#   'ble',
#   'dur',
#   'grain',
#   'ci',
#   'millet',
#   'grain',
#   'lin',
#   'grain',
#   'sesam',
#   'farin',
#   'seigl',
#   'sel',
#   'levur',
#   'garnitur',
#   'copp',
#   'echin',
#   'porc',
#   'sel',
#   'dextros',
#   'mais',
#   'fenouil',
#   'arom',
#   'naturel',
#   'sucr',
#   'conserv',
#   'nitrat',
#   'potassium',
#   'nitrit',
#   'sodium',
#   'origin',
#   'salad',
#   'tomat',
#   'basilic',
#   'huil',
#   'oliv'],
#  ['baguet',
#   'pain',
#   'baguet',
#   'farin',
#   'ble',
#   'eau',
#   'sel',
#   'levur',
#   'gluten',
#   'farin',
#   'ble',
#   'malt',
#   'levur',
#   'desactive',
#   'acid',
#   'ascorb',
#   'garnitur',
#   'filet',
#   'poulet',
#   'filet',
#   'poulet',
#   'eau',
#   'acidifi',
#   'lactat',
#   'potassium',
#   'acetat',
#   'sodium',
#   'amidon',
#   'modif',
#   'manioc',
#   'sel',
#   'dextros',
#   'glucos',
#   'arom',
#   'gelifi',
#   'sodium',
#   'color',
#   'origin',
#   'oeuf',
#   'dur',
#   'salad'],
#  ['glycerin',
#   'origin',
#   'naturel',
#   'stabilis',
#   'spirulin',
#   'spirulin',
#   'origin',
#   'naturel',
#   'extrait',
#   'fruit',
#   'arom',
#   'naturel',
#   'citron',
#   'vert'],
#  ['pat',
#   'tartin',
#   'noiset',
#   'region',
#   'piemont',
#   'avec',
#   'edulcor',
#   'maltitol',
#   'ingredient',
#   'noiset',
#   'region',
#   'piemont',
#   'edulcor',
#   'maltitol',
#   'lait',
#   'poudr',
#   'ecrem',
#   'cacao',
#   'poudr',
#   'huil',
#   'colz',
#   'lecithin',
#   'tournesol',
#   'allergen',
#   'present',
#   'lait',
#   'noiset'],
#  ['riz',
#   'precuit',
#   'eau',
#   'riz',
#   'huil',
#   'colz',
#   'sel',
#   'viand',
#   'dind',
#   'precuit',
#   'viand',
#   'dind',
#   'origin',
#   'franc',
#   'eau',
#   'sirop',
#   'glucos',
#   'sel',
#   'stabilis',
#   'amidon',
#   'modif',
#   'mais',
#   'eau',
#   'carott',
#   'crem',
#   'fraich',
#   'epaiss',
#   'champignon',
#   'paris',
#   'oignon',
#   'amidon',
#   'modif',
#   'mais',
#   'arom',
#   'naturel',
#   'extrait',
#   'vin',
#   'blanc',
#   'sulfit',
#   'sel'],
#  ['sucr',
#   'poudr',
#   'lait',
#   'poudr',
#   'beurr',
#   'lait',
#   'emulsifi',
#   'matier',
#   'grass',
#   'vegetal',
#   'hydrogene',
#   'coprah',
#   'jaun',
#   'oeuf',
#   'deshydrat',
#   'amidon',
#   'manioc',
#   'protein',
#   'lait',
#   'gelifi',
#   'carraghenan',
#   'sirop',
#   'glucos',
#   'arom',
#   'color'],
#  ['lait',
#   'chevr',
#   'ferment',
#   'quot',
#   'produit',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['sucr',
#   'chocolat',
#   'cacao',
#   'min',
#   'sucr',
#   'pat',
#   'cacao',
#   'poudr',
#   'cacao',
#   'beurr',
#   'cacao',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'arom',
#   'glucos',
#   'gomm',
#   'arab',
#   'sirop',
#   'glucos',
#   'arom',
#   'agent',
#   'enrobag',
#   'shellac',
#   'cir',
#   'carnaub',
#   'cir',
#   'abeil',
#   'concentr',
#   'patat',
#   'douc',
#   'rad',
#   'color',
#   'peut',
#   'conten',
#   'de',
#   'trac',
#   'fruit',
#   'coqu',
#   'color',
#   'peuvent',
#   'avoir',
#   'de',
#   'indesir',
#   'sur',
#   'activit',
#   'attent',
#   'chez',
#   'le',
#   'enfant',
#   'nutritionel',
#   'valeur',
#   'ique'],
#  ['huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'sel',
#   'noix',
#   'cajou',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'parmigiano',
#   'reggiano',
#   'aop',
#   'lait',
#   'sel',
#   'presur',
#   'ail',
#   'ingredient',
#   'biolog'],
#  ['artichaut',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'sel',
#   'regul',
#   'acidit',
#   'ingredient',
#   'biolog'],
#  ['lentill', 'vert'],
#  ['eau',
#   'gazeifie',
#   'sirop',
#   'mais',
#   'haut',
#   'teneur',
#   'fructos',
#   'color',
#   'caramel',
#   'conserv',
#   'arom',
#   'naturel',
#   'artificiel',
#   'mouss'],
#  ['sucr',
#   'farin',
#   'ble',
#   'graiss',
#   'huil',
#   'vegetal',
#   'karit',
#   'colz',
#   'tournesol',
#   'cacao',
#   'maigr',
#   'poudr',
#   'sirop',
#   'glucos',
#   'dextrin',
#   'beurr',
#   'concentr',
#   'oeuf',
#   'pat',
#   'noiset',
#   'pat',
#   'cacao',
#   'emulsifi',
#   'lecithin',
#   'colz',
#   'tournesol',
#   'sel',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'arom'],
#  ['eau',
#   'gazeifie',
#   'sirop',
#   'mais',
#   'rich',
#   'fructos',
#   'produit',
#   'part',
#   'mat',
#   'genet',
#   'modif',
#   'color',
#   'conserv',
#   'benzoat',
#   'sodium',
#   'exhausteur',
#   'gout',
#   'color',
#   'naturel',
#   'artificiel',
#   'humect',
#   'extrait'],
#  ['flocon',
#   'pomm',
#   'pomm',
#   'amidon',
#   'mais',
#   'saccharos',
#   'emulsifi',
#   'lecithin',
#   'tournesol',
#   'sucr'],
#  ['the', 'noir', 'aromatis', 'fleur', 'violet', 'bleuet'],
#  ['the',
#   'noir',
#   'chin',
#   'zest',
#   'orang',
#   'arom',
#   'naturel',
#   'cannel',
#   'orang',
#   'poudr',
#   'cannel'],
#  ['sirop',
#   'saveur',
#   'pistach',
#   'sirop',
#   'sucr',
#   'cristallis',
#   'eau',
#   'arom',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'denre',
#   'alimentair',
#   'color',
#   'concentr',
#   'cartham',
#   'pomm',
#   'color',
#   'melang',
#   'addit',
#   'sirop',
#   'saveur',
#   'frambois',
#   'sirop',
#   'sucr',
#   'eau',
#   'denre',
#   'alimentair',
#   'color',
#   'concentr',
#   'patat',
#   'douc',
#   'ceris',
#   'pomm',
#   'rad',
#   'cartham',
#   'arom',
#   'naturel',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'color',
#   'melang',
#   'addit',
#   'sirop',
#   'saveur',
#   'citron',
#   'sirop',
#   'sucr',
#   'cristallis',
#   'eau',
#   'arom',
#   'naturel',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'denre',
#   'alimentair',
#   'color',
#   'concentr',
#   'pomm',
#   'cartham',
#   'color',
#   'melang',
#   'addit',
#   'sirop',
#   'saveur',
#   'violet',
#   'sirop',
#   'sucr',
#   'eau',
#   'arom',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'denre',
#   'alimentair',
#   'color',
#   'concentr',
#   'cass',
#   'carott',
#   'pomm',
#   'color',
#   'melang',
#   'addit'],
#  ['sucr', 'sirop', 'glucos', 'eau', 'stabilis', 'acid', 'citriqu', 'conserv'],
#  ['farin',
#   'ble',
#   'gluten',
#   'sucr',
#   'cann',
#   'pepit',
#   'chocolat',
#   'cacao',
#   'minimum',
#   'pat',
#   'cacao',
#   'sucr',
#   'cann',
#   'beurr',
#   'cacao',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'cacao',
#   'biolog',
#   'poudr',
#   'caramel',
#   'tendr',
#   'isigny',
#   'beurr',
#   'sal',
#   'sirop',
#   'glucos',
#   'sucr',
#   'lait',
#   'enti',
#   'sal',
#   'isigny',
#   'aop',
#   'lait',
#   'eau',
#   'sel',
#   'guerand',
#   'arom',
#   'naturel',
#   'vanill',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'emulsifi',
#   'sucroester',
#   'acid',
#   'gras',
#   'bicarbonat',
#   'soud',
#   'diphosphat',
#   'peut',
#   'conten',
#   'de',
#   'trac',
#   'fruit',
#   'coqu',
#   'sesam',
#   'gluten',
#   'lait',
#   'oeuf',
#   'soj',
#   'sulfit'],
#  ['dessert',
#   'bien',
#   'agit',
#   'avant',
#   'emploi',
#   'trait',
#   'ure',
#   'cacao',
#   'color',
#   'de',
#   'trac',
#   'lait',
#   'soj',
#   'fruit',
#   'pas',
#   'sin',
#   'le',
#   'vapeur',
#   'vit',
#   'emploi',
#   'excess',
#   'utilis',
#   'sev',
#   'pas',
#   'une',
#   'gard',
#   'hor',
#   'est',
#   'complet',
#   'est',
#   'de',
#   'pas',
#   'tel',
#   'quel',
#   'endroit',
#   'sec',
#   'frais',
#   'soleil',
#   'dessert',
#   'dat',
#   'net',
#   'voor'],
#  ['sucr',
#   'sirop',
#   'glucos',
#   'huil',
#   'graiss',
#   'vegetal',
#   'palm',
#   'tournesol',
#   'illip',
#   'sirop',
#   'sucr',
#   'invert',
#   'stabilis',
#   'eii',
#   'eau',
#   'humect',
#   'epaiss',
#   'emulsifi',
#   'acidifi',
#   'arom',
#   'conserv'],
#  ['ingredient',
#   'sucr',
#   'cann',
#   'blanc',
#   'oeuf',
#   'eau',
#   'stabilis',
#   'epaiss',
#   'arom',
#   'naturel',
#   'vanill',
#   'cartham',
#   'color'],
#  ['farin',
#   'riz',
#   'sucr',
#   'amidon',
#   'mais',
#   'cacao',
#   'farin',
#   'noiset',
#   'arom',
#   'emulsifi',
#   'ester',
#   'polyglycer',
#   'acid',
#   'gras',
#   'sorbitan',
#   'epaiss',
#   'gomm',
#   'guar',
#   'poudr',
#   'lev',
#   'carbonat',
#   'sodium',
#   'correcteur',
#   'acidit',
#   'glucono',
#   'delt',
#   'sel',
#   'peut',
#   'conten',
#   'de',
#   'trac',
#   'lait',
#   'oeuf',
#   'soj',
#   'autr',
#   'fruit',
#   'coqu'],
#  ['chocolat',
#   'lait',
#   'min',
#   'avec',
#   'noiset',
#   'beurr',
#   'cacao',
#   'lait',
#   'poudr',
#   'sucr',
#   'sucr',
#   'pat',
#   'cacao',
#   'noiset',
#   'emulsifi',
#   'lecithin',
#   'arom',
#   'naturel',
#   'noiset',
#   'arom',
#   'naturel',
#   'vanill',
#   'arom',
#   'naturel',
#   'nougat',
#   'sel',
#   'peut',
#   'conten',
#   'de',
#   'conseil',
#   'conserv',
#   'conserv',
#   'entre',
#   'abri',
#   'chaleur',
#   'humidit',
#   'melang',
#   'une',
#   'tass',
#   'lait',
#   'chaud'],
#  ['pat',
#   'epeautr',
#   'ingredient',
#   'ingredienten',
#   'spirulin',
#   'farin',
#   'epeautr',
#   'tomat',
#   'epinard',
#   'betterav',
#   'spirulin'],
#  ['vin', 'roug', 'sec', 'contient', 'de', 'sulfit'],
#  ['farin',
#   'ble',
#   'soj',
#   'huil',
#   'graiss',
#   'vegetal',
#   'palm',
#   'coprah',
#   'colz',
#   'karit',
#   'tournesol',
#   'eau',
#   'sucr',
#   'dextros',
#   'poudr',
#   'cacao',
#   'degraisse',
#   'levur',
#   'lactoserum',
#   'poudr',
#   'lait',
#   'sel',
#   'poudr',
#   'lev',
#   'emulsifi',
#   'poudr',
#   'lait',
#   'ecrem',
#   'arom',
#   'produit',
#   'dan',
#   'une',
#   'usin',
#   'qui',
#   'utilis',
#   'soj',
#   'lait',
#   'oeuf',
#   'fruit',
#   'coqu',
#   'allergen',
#   'ble',
#   'lait',
#   'soj',
#   'produit',
#   'congel',
#   'pas',
#   'recongel'],
#  ['edulcor',
#   'sorbitol',
#   'aspartam',
#   'agent',
#   'enrobag',
#   'sel',
#   'magnesium',
#   'acid',
#   'extrait',
#   'de',
#   'eau',
#   'arom',
#   'consomm',
#   'excess',
#   'peut',
#   'avoir',
#   'de',
#   'effet',
#   'laxat',
#   'contient',
#   'une',
#   'sourc',
#   'phenylalanin'],
#  ['orang'],
#  ['chocolat',
#   'lait',
#   'sucr',
#   'beurr',
#   'cacao',
#   'chocolat',
#   'lait',
#   'lactos',
#   'lait'],
#  ['chocolat',
#   'lait',
#   'beurr',
#   'cacao',
#   'lait',
#   'grass',
#   'lait',
#   'lactos',
#   'emulsifi',
#   'lecithin',
#   'sucr',
#   'dextros',
#   'dan',
#   'endroit',
#   'sec',
#   'frais',
#   'conserv',
#   'jour',
#   'apre'],
#  ['doux',
#   'deux',
#   'fois',
#   'leur',
#   'leur',
#   'croqu',
#   'il',
#   'sont',
#   'prepar',
#   'pas',
#   'cornichon',
#   'pasteuris',
#   'cornichon',
#   'cou',
#   'vinaigr',
#   'apre',
#   'consomm',
#   'rapid'],
#  ['sucr',
#   'arachid',
#   'pat',
#   'cacao',
#   'lait',
#   'ecrem',
#   'poudr',
#   'lactos',
#   'protein',
#   'lait',
#   'matier',
#   'grass',
#   'vegetal',
#   'beurr',
#   'cacao',
#   'beurr',
#   'concentr',
#   'amidon',
#   'sirop',
#   'glucos',
#   'soj',
#   'gomm',
#   'arab',
#   'color',
#   'arom',
#   'sel',
#   'huil',
#   'vegetal'],
#  ['eau',
#   'gazeifie',
#   'sucr',
#   'color',
#   'caramel',
#   'acidifi',
#   'acid',
#   'phosphor',
#   'arom',
#   'dont',
#   'extrait',
#   'naturel',
#   'vegetal',
#   'cafein'],
#  ['vinaigr',
#   'alcool',
#   'eau',
#   'huil',
#   'pepin',
#   'raisin',
#   'sucr',
#   'farin',
#   'mais',
#   'moutard',
#   'jaun',
#   'oeuf',
#   'pasteuris',
#   'sel',
#   'color',
#   'riboflavin'],
#  ['marmelad',
#   'citron',
#   'citron',
#   'vert',
#   'sirop',
#   'glucos',
#   'fructos',
#   'citron',
#   'citron',
#   'vert',
#   'sucr',
#   'gelifi',
#   'pectin',
#   'acid',
#   'citriqu',
#   'correcteur',
#   'dacidit',
#   'citrat',
#   'sodium',
#   'color',
#   'complex',
#   'cuivr',
#   'chlorophyllin',
#   'lutein',
#   'prepar',
#   'avec',
#   'fruit',
#   'pour',
#   'marmelad',
#   'conserv'],
#  ['sucr',
#   'agent',
#   'citriqu',
#   'citrat',
#   'huil',
#   'dorang',
#   'douc',
#   'prot',
#   'avant',
#   'voir',
#   'endroit',
#   'frais',
#   'abri',
#   'lumier',
#   'ouvertur',
#   'refriger',
#   'dan',
#   'le',
#   'qui',
#   'energ',
#   'kcal',
#   'matier',
#   'gras',
#   'dont',
#   'glucid',
#   'dont',
#   'fibr',
#   'protein',
#   'convient',
#   'aux',
#   'vegan',
#   'produit',
#   'gluten',
#   'par'],
#  ['eau',
#   'sucr',
#   'color',
#   'acidifi',
#   'arom',
#   'naturel',
#   'dont',
#   'extrait',
#   'cafein',
#   'consomm',
#   'preferent',
#   'avant',
#   'voir'],
#  ['chou',
#   'blanc',
#   'garnitur',
#   'viand',
#   'porc',
#   'viand',
#   'bovin',
#   'chou',
#   'blanc',
#   'eau',
#   'farin',
#   'ble',
#   'oignon',
#   'sel',
#   'iod',
#   'sel',
#   'iodat',
#   'potassium',
#   'epic',
#   'poivr',
#   'blanc',
#   'coriandr',
#   'piment',
#   'chil',
#   'carv',
#   'levur',
#   'dextros'],
#  ['pech', 'atlant', 'nord', 'est', 'island', 'categor', 'pech', 'chalut'],
#  ['filet', 'saumon'],
#  ['pomm',
#   'terr',
#   'amidon',
#   'pomm',
#   'terr',
#   'huil',
#   'palm',
#   'oeuf',
#   'epic',
#   'oignon',
#   'curcum',
#   'farin',
#   'riz',
#   'sel',
#   'farin',
#   'ble',
#   'dextros'],
#  ['pomm',
#   'terr',
#   'huil',
#   'tournesol',
#   'amidon',
#   'modif',
#   'mais',
#   'tapioc',
#   'epic',
#   'oignon',
#   'paprik',
#   'ail',
#   'poivr',
#   'piment',
#   'sel',
#   'sucr',
#   'tomat',
#   'poudr',
#   'farin',
#   'riz',
#   'extrait',
#   'paprik',
#   'coriandr',
#   'persil',
#   'trac',
#   'ble',
#   'lait',
#   'oeuf',
#   'celer',
#   'soj'],
#  ['filet',
#   'poulet',
#   'mais',
#   'eau',
#   'huil',
#   'colz',
#   'amidon',
#   'modif',
#   'ble',
#   'sel',
#   'farin',
#   'ble',
#   'sucr',
#   'dextros',
#   'extrait',
#   'malt',
#   'orge',
#   'extrait',
#   'poivr'],
#  ['filet',
#   'farin',
#   'ble',
#   'eau',
#   'poudr',
#   'riz',
#   'oeuf',
#   'enti',
#   'poudr',
#   'amidon',
#   'modif',
#   'ble',
#   'mais',
#   'sel',
#   'persil',
#   'sucr',
#   'poivr',
#   'levur',
#   'acidifi',
#   'acid',
#   'citriqu'],
#  ['garnitur',
#   'sauc',
#   'bechamel',
#   'eau',
#   'jam',
#   'bon',
#   'cuit',
#   'superieur',
#   'jambon',
#   'porc',
#   'sel',
#   'sirop',
#   'glucos',
#   'dextros',
#   'antioxyd',
#   'ascorbat',
#   'sodium',
#   'conserv',
#   'nitrit',
#   'sodium',
#   'farin',
#   'ble',
#   'lait',
#   'ecrem',
#   'poudr',
#   'huil',
#   'tournesol',
#   'emmental',
#   'lait',
#   'sel',
#   'ferment',
#   'coagul',
#   'crem',
#   'fraich',
#   'comt',
#   'lait',
#   'ferment',
#   'sel',
#   'presur',
#   'sel',
#   'poivr',
#   'blanc',
#   'muscad',
#   'pat',
#   'eau',
#   'farin',
#   'ble',
#   'oeuf',
#   'lait',
#   'ecrem',
#   'poudr',
#   'huil',
#   'tournesol',
#   'dextros',
#   'sel',
#   'sucr',
#   'viand',
#   'porc',
#   'origin',
#   'franc',
#   'trac',
#   'celer'],
#  ['pomm',
#   'terr',
#   'oeuf',
#   'eau',
#   'beurr',
#   'farin',
#   'ble',
#   'huil',
#   'tournesol',
#   'flocon',
#   'pomm',
#   'terr',
#   'pomm',
#   'terr',
#   'deshydrate',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'extrait',
#   'epic',
#   'curcum',
#   'poudr',
#   'lait',
#   'enti',
#   'poudr',
#   'lev',
#   'pyrophosphat',
#   'soud',
#   'bicarbonat',
#   'soud',
#   'sel',
#   'amidon',
#   'ble',
#   'poivr',
#   'gris',
#   'muscad',
#   'trac',
#   'mollusqu',
#   'poisson',
#   'crustac',
#   'fruit',
#   'coqu',
#   'celer',
#   'soj',
#   'moutard'],
#  ['potiron',
#   'eau',
#   'lait',
#   'dem',
#   'ecrem',
#   'chataign',
#   'pomm',
#   'terr',
#   'pomm',
#   'terr',
#   'sel',
#   'oignon',
#   'beurr',
#   'sel',
#   'amidon',
#   'modif',
#   'riz',
#   'manioc',
#   'extrait',
#   'poivr'],
#  ['chocolat',
#   'noir',
#   'pat',
#   'cacao',
#   'sucr',
#   'beurr',
#   'cacao',
#   'beurr',
#   'deshydrat',
#   'lait',
#   'enti',
#   'poudr',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'arom',
#   'naturel',
#   'vanill',
#   'lait',
#   'ecrem',
#   'crem',
#   'jus',
#   'frambois',
#   'bas',
#   'concentr',
#   'sauc',
#   'frambois',
#   'pure',
#   'frambois',
#   'sucr',
#   'sirop',
#   'glucos',
#   'sirop',
#   'sucr',
#   'invert',
#   'stabilis',
#   'agar',
#   'agar',
#   'emulsifi',
#   'pectin',
#   'arom',
#   'naturel',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'sucr',
#   'biscuit',
#   'farin',
#   'ble',
#   'huil',
#   'tournesol',
#   'sucr',
#   'oeuf',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'sodium',
#   'sel',
#   'poudr',
#   'lait',
#   'ecrem',
#   'sirop',
#   'glucos',
#   'fructos',
#   'gouss',
#   'vanill',
#   'bourbon',
#   'broye',
#   'sirop',
#   'glucos',
#   'fructos',
#   'poudr',
#   'lait',
#   'ecrem',
#   'arom',
#   'naturel',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'concentr',
#   'jus',
#   'betterav',
#   'roug',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'stabilis',
#   'farin',
#   'grain',
#   'caroub',
#   'gomm',
#   'guar'],
#  ['garnitur',
#   'crem',
#   'fraich',
#   'eau',
#   'fromag',
#   'oeuf',
#   'epinard',
#   'saumon',
#   'emmental',
#   'lait',
#   'vach',
#   'sel',
#   'ferment',
#   'lactiqu',
#   'enzym',
#   'fromag',
#   'lait',
#   'vach',
#   'sel',
#   'presur',
#   'amidon',
#   'modif',
#   'mais',
#   'sel',
#   'extrait',
#   'muscad',
#   'pat',
#   'farin',
#   'ble',
#   'beurr',
#   'eau',
#   'sel',
#   'trac',
#   'mollusqu',
#   'crustac',
#   'celer',
#   'moutard'],
#  ['pet',
#   'epeautr',
#   'contient',
#   'gluten',
#   'carott',
#   'orang',
#   'carott',
#   'jaun',
#   'fev',
#   'soj',
#   'huil',
#   'oliv',
#   'eau',
#   'basilic',
#   'jus',
#   'citron',
#   'menth',
#   'modif',
#   'pomm',
#   'terr',
#   'sirop',
#   'glucos',
#   'alginat',
#   'sodium'],
#  ['garnitur',
#   'noix',
#   'saint',
#   'jacqu',
#   'eau',
#   'crem',
#   'fraich',
#   'oignon',
#   'echalot',
#   'poireau',
#   'carott',
#   'vin',
#   'blanc',
#   'amidon',
#   'modif',
#   'mais',
#   'beurr',
#   'jaun',
#   'oeuf',
#   'pasteuris',
#   'ail',
#   'sel',
#   'mer',
#   'persil',
#   'poivr',
#   'blanc',
#   'pat',
#   'feuillete',
#   'farin',
#   'ble',
#   'beurr',
#   'eau',
#   'jaun',
#   'oeuf',
#   'pasteuris',
#   'sel',
#   'mer',
#   'trac',
#   'crustac',
#   'poisson',
#   'soj',
#   'fruit',
#   'coqu',
#   'celer',
#   'moutard',
#   'grain',
#   'sesam'],
#  ['ingredient',
#   'pat',
#   'farin',
#   'ble',
#   'eau',
#   'huil',
#   'palm',
#   'persil',
#   'sucr',
#   'levur',
#   'poudr',
#   'sodium',
#   'amelior',
#   'farin',
#   'ble',
#   'emulsifi',
#   'mono',
#   'diacid',
#   'gras',
#   'der',
#   'acid',
#   'gras',
#   'agent',
#   'trait',
#   'farin',
#   'acid',
#   'ascorb',
#   'huil',
#   'tournesol',
#   'farc',
#   'produit',
#   'fin',
#   'lait',
#   'set',
#   'presur',
#   'microbien',
#   'ferment',
#   'lactiqu',
#   'tomat',
#   'produit',
#   'fin',
#   'concentr',
#   'tomat',
#   'produit',
#   'fin',
#   'fromag',
#   'produit',
#   'fi',
#   'lait',
#   'sel',
#   'ferment',
#   'lactiqu',
#   'presur',
#   'eau',
#   'fromag',
#   'frais',
#   'produit',
#   'fin',
#   'tait',
#   'crem',
#   'ferment',
#   'lactiqu',
#   'presur',
#   'microbien',
#   'basilic',
#   'ait',
#   'bouillon',
#   'poudr',
#   'set',
#   'sucr',
#   'oignon',
#   'pan',
#   'ail',
#   'extrait',
#   'epic',
#   'noix',
#   'muscad',
#   'amidon',
#   'modif',
#   'mais',
#   'plant',
#   'aromat',
#   'epic',
#   'poivr',
#   'noir',
#   'poivr',
#   'cayen',
#   'origan',
#   'marjolain',
#   'farin',
#   'ble',
#   'epaiss',
#   'gomm',
#   'xanthan',
#   'trac',
#   'soj',
#   'oeuf',
#   'celer',
#   'grain',
#   'sesam'],
#  ['raviol',
#   'igp',
#   'label',
#   'roug',
#   'farin',
#   'ble',
#   'fromag',
#   'blanc',
#   'lait',
#   'vach',
#   'ferment',
#   'sel',
#   'chlorur',
#   'calcium',
#   'presur',
#   'comt',
#   'lait',
#   'vach',
#   'presur',
#   'sel',
#   'ferment',
#   'emmental',
#   'lait',
#   'vach',
#   'presur',
#   'sel',
#   'ferment',
#   'eau',
#   'oeuf',
#   'persil',
#   'sel',
#   'huil',
#   'tournesol',
#   'beurr',
#   'courget',
#   'grille',
#   'eau',
#   'tomat',
#   'crem',
#   'eminc',
#   'poulet',
#   'cuit',
#   'aiguillet',
#   'poulet',
#   'eau',
#   'amidon',
#   'tapioc',
#   'dextros',
#   'sel',
#   'oignon',
#   'prefr',
#   'oignon',
#   'huil',
#   'tournesol',
#   'concentr',
#   'tomat',
#   'basilic',
#   'huil',
#   'tournesol',
#   'amidon',
#   'modif',
#   'pomm',
#   'terr',
#   'sel',
#   'epaiss',
#   'gomm',
#   'xanthan',
#   'poivr',
#   'noir',
#   'trac',
#   'poisson',
#   'crustac'],
#  ['oreillon',
#   'abricot',
#   'sirop',
#   'abricot',
#   'eau',
#   'sucr',
#   'farin',
#   'ble',
#   'sucr',
#   'beurr',
#   'nappag',
#   'eau',
#   'sirop',
#   'glucos',
#   'sucr',
#   'gelifi',
#   'pectin',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'correcteur',
#   'acidit',
#   'citrat',
#   'sodium',
#   'stabilis',
#   'chlorur',
#   'calcium',
#   'oeuf',
#   'enti',
#   'liquid',
#   'eau',
#   'crem',
#   'patissier',
#   'sucr',
#   'amidon',
#   'modif',
#   'pomm',
#   'terr',
#   'lactoserum',
#   'lait',
#   'enti',
#   'poudr',
#   'arom',
#   'naturel',
#   'vanill',
#   'extrait',
#   'vegetal',
#   'color',
#   'carott',
#   'amand',
#   'poudr',
#   'poudr',
#   'lev',
#   'diphosphat',
#   'carbonat',
#   'sodium',
#   'amidon',
#   'ble',
#   'blanc',
#   'oeuf',
#   'sel'],
#  ['morceau',
#   'filet',
#   'poulet',
#   'marin',
#   'morceau',
#   'filet',
#   'poulet',
#   'eau',
#   'sel',
#   'dextros',
#   'epic',
#   'paprik',
#   'piment',
#   'cumin',
#   'poivr',
#   'coriandr',
#   'curcum',
#   'fenugrec',
#   'tomat',
#   'poudr',
#   'ail',
#   'poudr',
#   'oignon',
#   'poudr',
#   'amidon',
#   'pomm',
#   'terr',
#   'sucr',
#   'jus',
#   'citron',
#   'poudr',
#   'extrait',
#   'epic',
#   'paprik',
#   'piment',
#   'gingembr',
#   'quatr',
#   'epic',
#   'origan',
#   'celer',
#   'panur',
#   'chip',
#   'bas',
#   'farin',
#   'mais',
#   'farin',
#   'mais',
#   'huil',
#   'tournesol',
#   'farin',
#   'ble',
#   'amidon',
#   'modif',
#   'ble',
#   'eau',
#   'sel',
#   'levur',
#   'paprik',
#   'poudr',
#   'huil',
#   'colz',
#   'sauc',
#   'fromag',
#   'cheddar',
#   'eau',
#   'fromag',
#   'frais',
#   'doubl',
#   'crem',
#   'crem',
#   'lait',
#   'ecrem',
#   'sel',
#   'huil',
#   'tournesol',
#   'poivron',
#   'roug',
#   'fromag',
#   'cheddar',
#   'oignon',
#   'sucr',
#   'poivron',
#   'vert',
#   'vinaigr',
#   'alcool',
#   'amidon',
#   'modif',
#   'mais',
#   'sel',
#   'piment',
#   'vert',
#   'pure',
#   'tomat',
#   'ail',
#   'poudr',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'extrait',
#   'paprik',
#   'stabilis',
#   'gomm',
#   'xanthan',
#   'sauc',
#   'mexicain',
#   'tomat',
#   'oignon',
#   'poivron',
#   'vert',
#   'sucr',
#   'pure',
#   'tomat',
#   'vinaigr',
#   'alcool',
#   'poivron',
#   'roug',
#   'epic',
#   'piment',
#   'feuill',
#   'coriandr',
#   'cumin',
#   'coriandr',
#   'origan',
#   'quatr',
#   'epic',
#   'pure',
#   'ail',
#   'sel',
#   'amidon',
#   'modif',
#   'mais',
#   'jus',
#   'citron',
#   'bas',
#   'concentr',
#   'stabilis',
#   'gomm',
#   'xanthan',
#   'trac',
#   'soj',
#   'moutard',
#   'oeuf'],
#  ['mauv', 'frise'],
#  ['viand',
#   'boeuf',
#   'sel',
#   'arom',
#   'naturel',
#   'conserv',
#   'emball',
#   'sous',
#   'atmospher',
#   'protectric',
#   'valeur',
#   'moyen',
#   'pour'],
#  ['original',
#   'extrait',
#   'extrait',
#   'levur',
#   'extrait',
#   'vegetal',
#   'niacin',
#   'vitamin',
#   'epic',
#   'celer',
#   'riboflavin',
#   'acid',
#   'foliqu',
#   'consomm',
#   'preferent',
#   'lot',
#   'frais',
#   'declar',
#   'nutritionnel',
#   'pour',
#   'valeur',
#   'dont',
#   'acid',
#   'dont',
#   'sel',
#   'thiamin',
#   'niacin',
#   'vitamin',
#   'apport',
#   'recommand'],
#  ['tomat',
#   'pour',
#   'tomato',
#   'ketchup',
#   'vinaigr',
#   'sucr',
#   'sel',
#   'extrait',
#   'epic',
#   'herb',
#   'contiennent',
#   'celer',
#   'epic'],
#  ['tomat',
#   'pour',
#   'tomato',
#   'ketchup',
#   'vinaigr',
#   'sucr',
#   'sel',
#   'extrait',
#   'epic',
#   'herb',
#   'contiennent',
#   'celer',
#   'epic'],
#  ['eau',
#   'gazeifie',
#   'sucr',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'acid',
#   'maliqu',
#   'arom',
#   'extrait',
#   'naturel',
#   'citron',
#   'citron',
#   'vert',
#   'correcteur',
#   'acidit',
#   'citrat',
#   'sodium'],
#  ['farin',
#   'ble',
#   'huil',
#   'colz',
#   'sucr',
#   'oeuf',
#   'frais',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'lait',
#   'ecrem',
#   'poudr',
#   'arom'],
#  ['farin',
#   'ble',
#   'sucr',
#   'huil',
#   'colz',
#   'oeuf',
#   'frais',
#   'sirop',
#   'glucos',
#   'fructos',
#   'beurr',
#   'cacao',
#   'lait',
#   'enti',
#   'poudr',
#   'stabilis',
#   'glycerol',
#   'pat',
#   'cacao',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'lecithin',
#   'soj',
#   'sel',
#   'lait',
#   'ecrem',
#   'poudr',
#   'arom'],
#  ['farin',
#   'ble',
#   'chocolat',
#   'noir',
#   'pat',
#   'cacao',
#   'sucr',
#   'beurr',
#   'cacao',
#   'matier',
#   'grass',
#   'laitier',
#   'lecithin',
#   'soj',
#   'arom',
#   'huil',
#   'colz',
#   'sucr',
#   'oeuf',
#   'frais',
#   'sirop',
#   'glucos',
#   'fructos',
#   'glycerol',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'lait',
#   'ecrem',
#   'poudr',
#   'arom'],
#  ['madelein',
#   'madelein',
#   'chocolat',
#   'noir',
#   'farin',
#   'ble',
#   'chocolat',
#   'noir',
#   'pat',
#   'cacao',
#   'sucr',
#   'beurr',
#   'cacao',
#   'matier',
#   'grass',
#   'laitier',
#   'anhydr',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'arom',
#   'naturel',
#   'vanill',
#   'sucr',
#   'huil',
#   'colz',
#   'oeuf',
#   'poul',
#   'eleve',
#   'plein',
#   'air',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'citrat',
#   'sodium',
#   'ble',
#   'sel',
#   'gluten',
#   'ble',
#   'lait',
#   'ecrem',
#   'poudr',
#   'fibr',
#   'vegetal',
#   'arom',
#   'naturel',
#   'peut',
#   'conten',
#   'de',
#   'trac',
#   'fruit',
#   'coqu',
#   'tout',
#   'vos',
#   'suggest',
#   'sont',
#   'le',
#   'contact',
#   'notr',
#   'servic',
#   'qualit',
#   'indiqu',
#   'numero',
#   'lot',
#   'produit',
#   'figur',
#   'sur',
#   'dessus',
#   'boit',
#   'pour',
#   'conserv',
#   'tout',
#   'le',
#   'qualit',
#   'produit',
#   'mainten',
#   'dan',
#   'abri',
#   'chaleur',
#   'humidit',
#   'froid'],
#  ['glycerin',
#   'vegetal',
#   'propylen',
#   'glycol',
#   'arom',
#   'tart',
#   'frais',
#   'sel',
#   'sucralos',
#   'ingredienten',
#   'glycerin',
#   'zout',
#   'sucralos',
#   'glycerin'],
#  ['farin',
#   'ble',
#   'oeuf',
#   'frais',
#   'huil',
#   'colz',
#   'sucr',
#   'raisin',
#   'sec',
#   'raisin',
#   'huil',
#   'colz',
#   'dextros',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'lait',
#   'ecrem',
#   'poudr',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'arom',
#   'naturel',
#   'orang'],
#  ['fruit',
#   'fruit',
#   'confit',
#   'fruit',
#   'pastequ',
#   'bigarreau',
#   'ecorc',
#   'orang',
#   'sirop',
#   'glucos',
#   'fructos',
#   'sucr',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'anhydrid',
#   'sulfur',
#   'color',
#   'caramel',
#   'ordinair',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'raisin',
#   'sec',
#   'rhum',
#   'farin',
#   'ble',
#   'huil',
#   'colz',
#   'oeuf',
#   'frais',
#   'sucr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'lait',
#   'ecrem',
#   'poudr',
#   'arom',
#   'naturel',
#   'orang'],
#  ['viand',
#   'porc',
#   'eau',
#   'acidifi',
#   'sel',
#   'dextros',
#   'acidifi',
#   'exhausteur',
#   'gout',
#   'antioxygen',
#   'color',
#   'arom'],
#  ['sucr',
#   'farin',
#   'ble',
#   'oeuf',
#   'frais',
#   'beurr',
#   'concentr',
#   'soit',
#   'beurr',
#   'reconstitu',
#   'beurr',
#   'cacao',
#   'lait',
#   'enti',
#   'poudr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'pat',
#   'cacao',
#   'stabilis',
#   'glycerol',
#   'lait',
#   'ecrem',
#   'poudr',
#   'poudr',
#   'lev',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'bi',
#   'sel',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'lecithin',
#   'soj',
#   'arom',
#   'peut',
#   'conten',
#   'de',
#   'trac',
#   'fruit',
#   'coqu',
#   'respect',
#   'de',
#   'notr',
#   'vous',
#   'pour',
#   'votr',
#   'valeur',
#   'nutritionnel',
#   'moyen',
#   'pour',
#   'patisser',
#   'pour'],
#  ['concentr',
#   'protein',
#   'lait',
#   'non',
#   'arom',
#   'fruit',
#   'roug',
#   'crem',
#   'stabilis',
#   'gomm',
#   'xanthan',
#   'color',
#   'naturel',
#   'roug',
#   'betterav',
#   'edulcor',
#   'sucralos',
#   'agent',
#   'lecithin',
#   'soj'],
#  ['concentr',
#   'protein',
#   'lactoserum',
#   'non',
#   'lait',
#   'lecithin',
#   'soj',
#   'poudr',
#   'cacao',
#   'arom',
#   'chocolat',
#   'cacahuet',
#   'stabilis',
#   'gomm',
#   'xanthan',
#   'edulcor',
#   'sucralos',
#   'agent',
#   'lecithin',
#   'soj'],
#  ['isolat',
#   'protein',
#   'soj',
#   'fructos',
#   'inulin',
#   'fibr',
#   'avoin',
#   'san',
#   'gluten',
#   'huil',
#   'soj',
#   'melang',
#   'mineral',
#   'citrat',
#   'calcium',
#   'oxyd',
#   'magnesium',
#   'fumarat',
#   'ferreux',
#   'selenit',
#   'sodium',
#   'oxyd',
#   'zinc',
#   'carbonat',
#   'manganes',
#   'chlorur',
#   'chrom',
#   'iii',
#   'iodur',
#   'potassium',
#   'citrat',
#   'cuivr',
#   'poudr',
#   'caf',
#   'decafein',
#   'phosphat',
#   'potassium',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'arom',
#   'naturel',
#   'poudr',
#   'lin',
#   'biolog',
#   'epaiss',
#   'gomm',
#   'xanthan',
#   'gomm',
#   'guar',
#   'color',
#   'caramel',
#   'melang',
#   'vitamin',
#   'acid',
#   'ascorb',
#   'vit',
#   'acetat',
#   'alpha',
#   'tocopheryl',
#   'vit',
#   'nicotinamid',
#   'niacin',
#   'acetat',
#   'retinyl',
#   'vit',
#   'pantothenat',
#   'calcium',
#   'acid',
#   'pantothen',
#   'biotin',
#   'biotin',
#   'cholecalciferol',
#   'vit',
#   'vit',
#   'chlorhydrat',
#   'pyridoxin',
#   'vit',
#   'chlorhydrat',
#   'thiamin',
#   'vit',
#   'cyanocobalamin',
#   'vit',
#   'riboflavin',
#   'vit',
#   'acid',
#   'pteroylmonoglutam',
#   'acid',
#   'foliqu',
#   'chlorur',
#   'sodium',
#   'edulcor',
#   'glycosid',
#   'steviol',
#   'poudr',
#   'fruit',
#   'papay',
#   'grenad',
#   'myrtill',
#   'persil',
#   'poudr',
#   'antiagglomer',
#   'dioxyd',
#   'silicium'],
#  ['sucr',
#   'blanc',
#   'poudr',
#   'amand',
#   'farin',
#   'debl',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'sel',
#   'poudr',
#   'lev',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'arom'],
#  ['pure',
#   'tomat',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'cep',
#   'carott',
#   'celer',
#   'oignon',
#   'sel',
#   'persil',
#   'basilic',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['pure',
#   'tomat',
#   'oliv',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'capr',
#   'ail',
#   'poivr',
#   'noir',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['pure',
#   'tomat',
#   'courget',
#   'huil',
#   'oliv',
#   'extra',
#   'vierg',
#   'oignon',
#   'carott',
#   'celer',
#   'sel',
#   'poivr',
#   'noir',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['pure',
#   'tomat',
#   'thon',
#   'oliv',
#   'huil',
#   'oliv',
#   'extra',
#   'vierg',
#   'oignon',
#   'sel',
#   'persil',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['pure',
#   'tomat',
#   'carott',
#   'huil',
#   'oliv',
#   'extra',
#   'vierg',
#   'oignon',
#   'courget',
#   'aubergin',
#   'celer',
#   'basilic',
#   'sel',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['sucr',
#   'blanc',
#   'oeuf',
#   'frais',
#   'poudr',
#   'amand',
#   'beurr',
#   'patissi',
#   'farin',
#   'ble',
#   'pepit',
#   'citron',
#   'sucr',
#   'pomm',
#   'pulp',
#   'citron',
#   'dextros',
#   'fibr',
#   'anan',
#   'gelifi',
#   'alginat',
#   'sodium',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'citrat',
#   'potassium',
#   'stabilis',
#   'phosphat',
#   'calcium',
#   'arom',
#   'naturel',
#   'citron',
#   'color',
#   'curcumin',
#   'oeuf',
#   'frais',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'citron',
#   'equivalent',
#   'jus',
#   'citron',
#   'jus',
#   'concentr',
#   'citron',
#   'maltodextrin',
#   'sel',
#   'poudr',
#   'lev',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'arom',
#   'naturel',
#   'citron',
#   'exprim',
#   'sur',
#   'le',
#   'pepit',
#   'equivalent',
#   'sur',
#   'ensembl',
#   'produit'],
#  ['farin',
#   'riz',
#   'farin',
#   'sarrasin',
#   'farin',
#   'millet',
#   'farin',
#   'toast',
#   'sel',
#   'marin',
#   'produit',
#   'issus',
#   'agricultur',
#   'biolog'],
#  ['sucr',
#   'blanc',
#   'oeuf',
#   'frais',
#   'beurr',
#   'concentr',
#   'poudr',
#   'amand',
#   'farin',
#   'ble',
#   'pat',
#   'cacao',
#   'oeuf',
#   'frais',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'cacao',
#   'maigr',
#   'poudr',
#   'beurr',
#   'cacao',
#   'sel',
#   'arom',
#   'matier',
#   'grass',
#   'laitier',
#   'emulsifi',
#   'lecithin',
#   'soj'],
#  ['eau',
#   'fecul',
#   'tapioc',
#   'farin',
#   'riz',
#   'fecul',
#   'pomm',
#   'terr',
#   'huil',
#   'vegetal',
#   'huil',
#   'colz',
#   'huil',
#   'tournesol',
#   'levur',
#   'humect',
#   'glycerol',
#   'vegetal',
#   'stabilis',
#   'hydroxypropyl',
#   'cellulos',
#   'amidon',
#   'mais',
#   'blanc',
#   'oeuf',
#   'deshydrat',
#   'sucr',
#   'poudr',
#   'envelopp',
#   'psyllium',
#   'poudr',
#   'farin',
#   'mais',
#   'sel',
#   'iod',
#   'sel',
#   'iodat',
#   'potassium',
#   'amidon',
#   'mais',
#   'ferment',
#   'amidon',
#   'riz'],
#  ['dextros',
#   'maltodextrin',
#   'arom',
#   'fruit',
#   'roug',
#   'color',
#   'roug',
#   'betterav',
#   'acid',
#   'citriqu'],
#  ['ingredient',
#   'nectar',
#   'fleur',
#   'coco',
#   'biolog',
#   'allergen',
#   'le',
#   'allergen',
#   'sont',
#   'indiqu',
#   'par',
#   'le',
#   'ingredient',
#   'figur',
#   'caracter',
#   'gras'],
#  ['farin',
#   'ble',
#   'farin',
#   'ble',
#   'gluten',
#   'ble',
#   'farin',
#   'ble',
#   'malt',
#   'eau',
#   'grain',
#   'sesam',
#   'decortique',
#   'toaste',
#   'sel',
#   'germ',
#   'ble',
#   'levur',
#   'emulsifi',
#   'agent',
#   'trait',
#   'farin'],
#  ['farin',
#   'ble',
#   'complet',
#   'eau',
#   'sel',
#   'levur',
#   'gluten',
#   'ble',
#   'farin',
#   'ble',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'huil',
#   'colz',
#   'total',
#   'hydrogene',
#   'agent',
#   'trait',
#   'farin',
#   'acid',
#   'ascorb'],
#  ['epic',
#   'pain',
#   'epic',
#   'epic',
#   'cannel',
#   'gingembr',
#   'coriandr',
#   'anis',
#   'clous',
#   'girofl',
#   'anis',
#   'etoil',
#   'muscad',
#   'poivr'],
#  ['pat',
#   'farin',
#   'saindoux',
#   'eau',
#   'oeuf',
#   'sel',
#   'vinaigr',
#   'garnitur',
#   'bleuet',
#   'sauvag',
#   'sucr',
#   'farin',
#   'contient',
#   'gluten',
#   'oeuf'],
#  ['glycin', 'poudr'],
#  ['viand',
#   'cuiss',
#   'dind',
#   'avec',
#   'peau',
#   'origin',
#   'franc',
#   'eau',
#   'epic',
#   'plant',
#   'aromat',
#   'sel',
#   'fecul',
#   'pomm',
#   'terr',
#   'arom',
#   'naturel',
#   'conserv',
#   'acetat',
#   'sodium'],
#  ['patisser',
#   'fourre',
#   'pulp',
#   'pech',
#   'farin',
#   'ble',
#   'fourrag',
#   'pech',
#   'sirop',
#   'glucos',
#   'fructos',
#   'pure',
#   'pech',
#   'sucr',
#   'gelifi',
#   'pectin',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'citrat',
#   'sodium',
#   'arom',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'huil',
#   'colz',
#   'oeuf',
#   'frais',
#   'sucr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'lait',
#   'ecrem',
#   'poudr',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'arom',
#   'exprim',
#   'sur',
#   'fourrag',
#   'equivalent',
#   'sur',
#   'ensembl',
#   'produit',
#   'patisser',
#   'fourre',
#   'pulp',
#   'abricot',
#   'farin',
#   'ble',
#   'fourrag',
#   'abricot',
#   'sirop',
#   'glucos',
#   'fructos',
#   'pure',
#   'abricot',
#   'sucr',
#   'gelifi',
#   'pectin',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'citrat',
#   'sodium',
#   'arom',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'huil',
#   'colz',
#   'oeuf',
#   'frais',
#   'sucr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'lait',
#   'ecrem',
#   'poudr',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'arom',
#   'exprim',
#   'sur',
#   'fourrag',
#   'equivalent',
#   'sur',
#   'ensembl',
#   'produit',
#   'patisser',
#   'fourre',
#   'pulp',
#   'fruit',
#   'roug',
#   'farin',
#   'ble',
#   'fourrag',
#   'fruit',
#   'roug',
#   'sirop',
#   'glucos',
#   'fructos',
#   'pure',
#   'frais',
#   'sucr',
#   'pure',
#   'frambois',
#   'concentre',
#   'equivalent',
#   'pure',
#   'frambois',
#   'pure',
#   'ceris',
#   'concentre',
#   'equivalent',
#   'pure',
#   'ceris',
#   'gelifi',
#   'pectin',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'citrat',
#   'sodium',
#   'arom',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'huil',
#   'colz',
#   'oeuf',
#   'frais',
#   'sucr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'stabilis',
#   'glycerol',
#   'poudr',
#   'lev',
#   'carbonat',
#   'ammonium',
#   'carbonat',
#   'sodium',
#   'diphosphat',
#   'ble',
#   'sel',
#   'lait',
#   'ecrem',
#   'poudr',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'arom',
#   'soit',
#   'equivalent',
#   'pure',
#   'fruit',
#   'sur',
#   'fourrag',
#   'equivalent',
#   'sur',
#   'ensembl',
#   'produit'],
#  ['pain',
#   'pavot',
#   'farin',
#   'ble',
#   'eau',
#   'levur',
#   'dextros',
#   'huil',
#   'sucr',
#   'arom',
#   'grain',
#   'pavot',
#   'sarrasin',
#   'sel',
#   'gluten',
#   'ble',
#   'farin',
#   'fev',
#   'conserv',
#   'propionat',
#   'calcium',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'gras',
#   'antioxyd',
#   'acid',
#   'ascorb',
#   'garnitur',
#   'aiguillet',
#   'poulet',
#   'pan',
#   'aiguillet',
#   'poulet',
#   'farin',
#   'ble',
#   'eau',
#   'huil',
#   'tournesol',
#   'sel',
#   'amidon',
#   'modif',
#   'arom',
#   'lactos',
#   'gluten',
#   'stabilis',
#   'levur',
#   'epaiss',
#   'fromag',
#   'cheddar',
#   'fromag',
#   'dont',
#   'cheddar',
#   'lait',
#   'ecrem',
#   'rehydrat',
#   'beurr',
#   'sel',
#   'font',
#   'citrat',
#   'sodium',
#   'acid',
#   'citriqu',
#   'protein',
#   'lait',
#   'sel',
#   'color',
#   'extrait',
#   'paprik',
#   'antiagglomer',
#   'lecithin',
#   'avocat',
#   'poivron',
#   'roug',
#   'sel',
#   'piment',
#   'jalapeno',
#   'antioxygen',
#   'acid',
#   'ascorb',
#   'oignon',
#   'epaiss',
#   'gomm',
#   'xanthan',
#   'acidifi',
#   'ascorbat',
#   'sodium',
#   'ail',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'coriandr',
#   'salad',
#   'tomat'],
#  ['complet',
#   'arin',
#   'avoin',
#   'complet',
#   'sirop',
#   'sucr',
#   'sucr',
#   'brun',
#   'cereal',
#   'arin',
#   'riz',
#   'farin',
#   'avoin',
#   'carbonat',
#   'extrait',
#   'mat',
#   'orge',
#   'hul',
#   'tournesol',
#   'glycerol',
#   'soj',
#   'amidon',
#   'arin',
#   'moulu',
#   'poudr',
#   'lait',
#   'ecrem',
#   'antioxyd',
#   'extrait',
#   'tocopherol',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'carbonat',
#   'naturel',
#   'le',
#   'sont',
#   'gras',
#   'peut',
#   'conten',
#   'de',
#   'trac',
#   'noix',
#   'ble',
#   'sesam'],
#  ['semoul',
#   'ble',
#   'dur',
#   'rehydrate',
#   'legum',
#   'poivron',
#   'roug',
#   'vert',
#   'tomat',
#   'tomat',
#   'deshydrate',
#   'huil',
#   'colz',
#   'raisin',
#   'sec',
#   'enrobag',
#   'huil',
#   'colz',
#   'vinaigr',
#   'alcool',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'sel',
#   'menth',
#   'jus',
#   'concentr',
#   'sucr',
#   'conserv',
#   'arom',
#   'salad'],
#  ['foi', 'gras', 'canard', 'perigord', 'eau', 'armagnac', 'sel', 'poivr'],
#  ['viand',
#   'canard',
#   'origin',
#   'franc',
#   'graiss',
#   'canard',
#   'gorg',
#   'porc',
#   'origin',
#   'franc',
#   'eau',
#   'sel',
#   'pulp',
#   'ail',
#   'ail',
#   'rehydrat',
#   'sel',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'echalot',
#   'deshydrate',
#   'poivr'],
#  ['chou',
#   'carott',
#   'huil',
#   'colz',
#   'eau',
#   'vinaigr',
#   'alcool',
#   'sucr',
#   'oignon',
#   'moutard',
#   'dijon',
#   'eau',
#   'grain',
#   'moutard',
#   'vinaigr',
#   'alcool',
#   'sel',
#   'acidifi',
#   'conserv',
#   'jaun',
#   'oeuf',
#   'sel',
#   'amidon',
#   'modif',
#   'mais',
#   'jus',
#   'concentr',
#   'citron',
#   'conserv',
#   'epaiss',
#   'poivr'],
#  ['pain',
#   'baguet',
#   'farin',
#   'froment',
#   'eau',
#   'levur',
#   'sel',
#   'garnitur',
#   'jambon',
#   'jambon',
#   'porc',
#   'origin',
#   'franc',
#   'eau',
#   'sel',
#   'arom',
#   'naturel',
#   'dextros',
#   'bouillon',
#   'porc',
#   'deshydrat',
#   'eau',
#   'viand',
#   'porc',
#   'extrait',
#   'carott',
#   'extrait',
#   'poireau',
#   'sirop',
#   'glucos',
#   'chlorur',
#   'potassium',
#   'antioxyd',
#   'ascorbat',
#   'sodium',
#   'conserv',
#   'nitrit',
#   'sodium',
#   'beurr',
#   'leg',
#   'eau',
#   'beurr',
#   'amidon',
#   'modif',
#   'amidon',
#   'pomm',
#   'terr',
#   'acidifi',
#   'acid',
#   'lactiqu',
#   'sel',
#   'emulsifi',
#   'epaiss',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'color',
#   'bet',
#   'caroten',
#   'arom',
#   'naturel',
#   'exprim',
#   'sur',
#   'garnitur'],
#  ['pain',
#   'baguet',
#   'farin',
#   'froment',
#   'eau',
#   'levur',
#   'sel',
#   'garnitur',
#   'roset',
#   'viand',
#   'porc',
#   'origin',
#   'sel',
#   'lactos',
#   'dextros',
#   'epic',
#   'ail',
#   'antioxyd',
#   'erythorbat',
#   'sodium',
#   'conserv',
#   'nitrat',
#   'potassium',
#   'nitrit',
#   'sodium',
#   'ferment',
#   'beurr',
#   'leg',
#   'eau',
#   'beurr',
#   'amidon',
#   'modif',
#   'amidon',
#   'pomm',
#   'terr',
#   'acidifi',
#   'acid',
#   'lactiqu',
#   'sel',
#   'emulsifi',
#   'epaiss',
#   'conserv',
#   'sorbat',
#   'potassium',
#   'color',
#   'bet',
#   'caroten',
#   'arom',
#   'naturel'],
#  ['farin',
#   'ble',
#   'eau',
#   'farin',
#   'seigl',
#   'sucr',
#   'sirop',
#   'sucr',
#   'huil',
#   'colz',
#   'gluten',
#   'ble',
#   'sel',
#   'levur',
#   'levain',
#   'poudr',
#   'emulsifi',
#   'poudr',
#   'lev',
#   'fructos',
#   'farin',
#   'malt',
#   'orge',
#   'agent',
#   'trait',
#   'de',
#   'farin',
#   'enzym',
#   'garnitur',
#   'salad',
#   'vert',
#   'filet',
#   'poulet',
#   'rot',
#   'filet',
#   'poulet',
#   'origin',
#   'franc',
#   'eau',
#   'dextros',
#   'huil',
#   'tournesol',
#   'sel',
#   'protein',
#   'pois',
#   'arom',
#   'stabilis',
#   'fibr',
#   'ble',
#   'san',
#   'gluten',
#   'gelifi',
#   'carott',
#   'rape',
#   'mayonnais',
#   'huil',
#   'colz',
#   'eau',
#   'vinaigr',
#   'jaun',
#   'oeuf',
#   'moutard',
#   'dijon',
#   'eau',
#   'grain',
#   'moutard',
#   'vinaigr',
#   'sel',
#   'antioxyd',
#   'disulfit',
#   'potassium',
#   'acidifi',
#   'acid'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'sucr',
#   'beurr',
#   'lait',
#   'raisin',
#   'smyrn',
#   'sirop',
#   'glucos',
#   'lait',
#   'poudr',
#   'ecrem',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'sel'],
#  ['morceau',
#   'chocolat',
#   'blanc',
#   'sucr',
#   'lait',
#   'poudr',
#   'enti',
#   'beurr',
#   'cacao',
#   'lait',
#   'poudr',
#   'ecrem',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'arom',
#   'vanill',
#   'farin',
#   'ble',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'beurr',
#   'sucr',
#   'fecul',
#   'mais',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'sirop',
#   'sucr',
#   'invert',
#   'sel'],
#  ['sucr',
#   'beurr',
#   'lait',
#   'flocon',
#   'avoin',
#   'contient',
#   'gluten',
#   'farin',
#   'gluten',
#   'avec',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'raisin',
#   'sec',
#   'noix',
#   'coco',
#   'abricot',
#   'sech',
#   'abricot',
#   'farin',
#   'riz',
#   'conserv',
#   'sulfit',
#   'golden',
#   'syrup',
#   'sirop',
#   'sucr',
#   'invert',
#   'oeuf',
#   'pasteuris',
#   'agent',
#   'levag',
#   'bicarbonat',
#   'sodium',
#   'sel',
#   'mel'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'beurr',
#   'lait',
#   'sucr',
#   'eclat',
#   'pistach',
#   'eclat',
#   'amand',
#   'sirop',
#   'sucr',
#   'invert',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'lait',
#   'poudr',
#   'sel'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'beurr',
#   'lait',
#   'gingembr',
#   'conf',
#   'cristallis',
#   'gingembr',
#   'conf',
#   'sucr',
#   'sucr',
#   'flocon',
#   'avoin',
#   'contiennent',
#   'gluten',
#   'sirop',
#   'sucr',
#   'invert',
#   'gingembr',
#   'moulu',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'lait',
#   'poudr',
#   'ecrem',
#   'sel'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'sucr',
#   'gingembr',
#   'conf',
#   'cristallis',
#   'ingembr',
#   'sucr',
#   'cann',
#   'beurr',
#   'lait',
#   'flocon',
#   'avoin',
#   'contient',
#   'gluten',
#   'avoin',
#   'moulu',
#   'contient',
#   'gluten',
#   'fecul',
#   'mais',
#   'lait',
#   'poudr',
#   'ecrem',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'sirop',
#   'sucr',
#   'invert',
#   'gingembr',
#   'moulu',
#   'sel'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'beurr',
#   'lait',
#   'gingembr',
#   'conf',
#   'cristallis',
#   'gingembr',
#   'conf',
#   'sucr',
#   'sucr',
#   'flocon',
#   'avoin',
#   'contiennent',
#   'gluten',
#   'sirop',
#   'sucr',
#   'invert',
#   'gingembr',
#   'moulu',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'lait',
#   'poudr',
#   'ecrem',
#   'sel'],
#  ['jus',
#   'pomm',
#   'pure',
#   'frais',
#   'pure',
#   'banan',
#   'pure',
#   'pomm',
#   'pure',
#   'bai',
#   'sureau',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'antioxyd',
#   'acid',
#   'ascorb'],
#  ['carott',
#   'sauc',
#   'typ',
#   'vinaigret',
#   'eau',
#   'huil',
#   'colz',
#   'vinaigr',
#   'alcool',
#   'moutard',
#   'eau',
#   'grain',
#   'moutard',
#   'vinaigr',
#   'alcool',
#   'sel',
#   'sel',
#   'epaiss',
#   'arom',
#   'conserv'],
#  ['fruit', 'passion'],
#  ['salad',
#   'vert',
#   'concombr',
#   'semoul',
#   'ble',
#   'dur',
#   'rehydrate',
#   'legum',
#   'poivron',
#   'roug',
#   'vert',
#   'tomat',
#   'tomat',
#   'deshydrate',
#   'huil',
#   'colz',
#   'raisin',
#   'sec',
#   'enrobag',
#   'huil',
#   'colz',
#   'vinaigr',
#   'alcool',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'sel',
#   'citron',
#   'concentr',
#   'sucr',
#   'conserv',
#   'arom',
#   'mais',
#   'tomat',
#   'ceris',
#   'oeuf',
#   'dur',
#   'carott',
#   'rape'],
#  ['pat',
#   'farin',
#   'ble',
#   'tendr',
#   'eau',
#   'huil',
#   'oliv',
#   'extra',
#   'vierg',
#   'sel',
#   'levur',
#   'sauc',
#   'blanch',
#   'eau',
#   'crem',
#   'lait',
#   'poudr',
#   'protein',
#   'lait',
#   'lait',
#   'enti',
#   'poudr',
#   'amidon',
#   'mais',
#   'modif',
#   'sel',
#   'fromag',
#   'bleu',
#   'equivalent',
#   'produit',
#   'fin',
#   'lait',
#   'sel',
#   'ferment',
#   'lactiqu',
#   'presur',
#   'microbien',
#   'penicillium',
#   'roquefort',
#   'huil',
#   'tournesol',
#   'poivr',
#   'noir',
#   'amidon',
#   'mais',
#   'fromag',
#   'mozzarel',
#   'lait',
#   'sel',
#   'presur',
#   'microbien',
#   'ferment',
#   'lactiqu',
#   'fromag',
#   'provolon',
#   'piqu',
#   'lait',
#   'sel',
#   'presur',
#   'animal',
#   'fromag',
#   'pecorino',
#   'romano',
#   'aop',
#   'lait',
#   'breb',
#   'sel',
#   'presur',
#   'animal',
#   'ferment',
#   'lactiqu',
#   'fromag',
#   'lait',
#   'sel',
#   'ferment',
#   'lactiqu',
#   'presur',
#   'microbien',
#   'huil',
#   'tournesol',
#   'trac',
#   'eventuel',
#   'soj',
#   'fin'],
#  ['pain',
#   'mi',
#   'complet',
#   'farin',
#   'complet',
#   'ble',
#   'eau',
#   'farin',
#   'ble',
#   'huil',
#   'colz',
#   'dextros',
#   'sucr',
#   'sel',
#   'gluten',
#   'ble',
#   'arom',
#   'contient',
#   'alcool',
#   'levur',
#   'vinaigr',
#   'conserv',
#   'propionat',
#   'calcium',
#   'emulsifi',
#   'mono',
#   'diglycerid',
#   'acid',
#   'gras',
#   'antioxyd',
#   'acid',
#   'ascorb',
#   'garnitur',
#   'oeuf',
#   'dur',
#   'carott',
#   'rape',
#   'emmental',
#   'tranch',
#   'lait',
#   'vach',
#   'sel',
#   'ferment',
#   'lactiqu',
#   'coagul',
#   'mayonnais',
#   'huil',
#   'colz',
#   'eau',
#   'vinaigr',
#   'jaun',
#   'oeuf',
#   'frais',
#   'moutard',
#   'dijon',
#   'eau',
#   'grain',
#   'moutard',
#   'vinaigr',
#   'sel',
#   'antioxyd',
#   'disulfit',
#   'potassium',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'sel',
#   'sucr',
#   'amidon',
#   'modif',
#   'epaiss',
#   'gomm',
#   'xanthan',
#   'acidifi',
#   'antioxyd',
#   'color',
#   'lutein',
#   'extrait',
#   'paprik',
#   'arom',
#   'salad'],
#  ['tortill',
#   'ble',
#   'farin',
#   'ble',
#   'eau',
#   'huil',
#   'palm',
#   'stabilis',
#   'protein',
#   'ble',
#   'sel',
#   'soj',
#   'poudr',
#   'lev',
#   'sucr',
#   'sirop',
#   'glucos',
#   'acidifi',
#   'malt',
#   'emulsifi',
#   'conserv',
#   'farin',
#   'avoin',
#   'levur',
#   'garnitur',
#   'saumon',
#   'fum',
#   'saumon',
#   'atlant',
#   'sel',
#   'sucr',
#   'salad',
#   'avocat',
#   'poivron',
#   'roug',
#   'sel',
#   'piment',
#   'jalapeno',
#   'antioxygen',
#   'acid',
#   'ascorb',
#   'oignon',
#   'epaiss',
#   'gomm',
#   'xanthan',
#   'acidifi',
#   'ascorbat',
#   'sodium',
#   'ail',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'coriandr',
#   'coriandr',
#   'fraich',
#   'exprim',
#   'sur',
#   'garnitur'],
#  ['pat',
#   'fusill',
#   'cuit',
#   'tartar',
#   'legum',
#   'tomat',
#   'concombr',
#   'poivron',
#   'vert',
#   'poivron',
#   'roug',
#   'oignon',
#   'concentr',
#   'tomat',
#   'huil',
#   'colz',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'vinaigr',
#   'sel',
#   'moutard',
#   'dijon',
#   'eau',
#   'grain',
#   'moutard',
#   'vinaigr',
#   'sel',
#   'conserv',
#   'ail',
#   'poivr',
#   'paprik',
#   'epaiss',
#   'piment',
#   'eminc',
#   'poulet',
#   'rot',
#   'filet',
#   'poulet',
#   'origin',
#   'eau',
#   'acidifi',
#   'lactat',
#   'potassium',
#   'acetat',
#   'sodium',
#   'amidon',
#   'modif',
#   'manioc',
#   'sel',
#   'dextros',
#   'sirop',
#   'glucos',
#   'arom',
#   'gelifi',
#   'antioxyd',
#   'erythorbat',
#   'sodium',
#   'color',
#   'caramel',
#   'salad',
#   'vert',
#   'tomat',
#   'ceris',
#   'oliv',
#   'noir'],
#  ['salad',
#   'grecqu',
#   'salad',
#   'vert',
#   'de',
#   'breb',
#   'lait',
#   'pasteuris',
#   'breb',
#   'sel',
#   'ferment',
#   'lactiqu',
#   'enzym',
#   'coagul',
#   'chlorur',
#   'calcium',
#   'concombr',
#   'poivron',
#   'tomat',
#   'ceris',
#   'oliv',
#   'noir'],
#  ['pat',
#   'fusill',
#   'cuit',
#   'salad',
#   'vert',
#   'bill',
# ...
#   'huil',
#   'colz',
#   'eau',
#   'pure',
#   'gingembr',
#   'piment',
#   'roug',
#   'deshydrat',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'ble',
#   'contient',
#   'gluten',
#   'sucr',
#   'piment',
#   'roug',
#   'huil',
#   'sesam',
#   'grain',
#   'sesam',
#   'bouillon',
#   'poulet',
#   'eau',
#   'poulet',
#   'fev',
#   'soj',
#   'noir',
#   'fecul',
#   'mais',
#   'pure',
#   'gingembr',
#   'huil',
#   'tournesol',
#   'color',
#   'caramel',
#   'ordinair',
#   'fev',
#   'soj',
#   'noir',
#   'fermente',
#   'fev',
#   'soj',
#   'eau',
#   'correcteur',
#   'acidit',
#   'acid',
#   'acet',
#   'sel',
#   'farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'sel',
#   'vinaigr',
#   'farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin'],
#  ['porc',
#   'origin',
#   'britann',
#   'fait',
#   'avec',
#   'porc',
#   'cru',
#   'pour',
#   'trait',
#   'salaison',
#   'rot',
#   'miel',
#   'miel',
#   'fleur',
#   'orang',
#   'salaison',
#   'sel',
#   'conserv',
#   'nitrit',
#   'sodium',
#   'nitrat',
#   'potassium',
#   'inform',
#   'ce',
#   'tranch',
#   'extra',
#   'fin',
#   'peuvent',
#   'avoir',
#   'de',
#   'different',
#   'cel',
#   'rien',
#   'leur',
#   'qualit',
#   'conserv'],
#  ['lait', 'enti', 'crem', 'lait', 'eau', 'riz', 'sucr'],
#  ['sirop',
#   'glucos',
#   'sucr',
#   'gelatin',
#   'poisson',
#   'dextros',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'arom',
#   'agent',
#   'enrobag',
#   'cir',
#   'abeil',
#   'blanch',
#   'cir',
#   'carnaub',
#   'concentr',
#   'fruit',
#   'plant',
#   'citrouill',
#   'pomm',
#   'carott',
#   'hibiscus',
#   'spirulin'],
#  ['sirop',
#   'glucos',
#   'sucr',
#   'gelatin',
#   'poisson',
#   'dextros',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'sirop',
#   'caramel',
#   'arom',
#   'agent',
#   'enrobag',
#   'cir',
#   'abeil',
#   'blanch',
#   'cir',
#   'carnaub'],
#  ['sirop',
#   'glucos',
#   'sucr',
#   'dextros',
#   'gelatin',
#   'poisson',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'arom',
#   'agent',
#   'enrobag',
#   'cir',
#   'abeil',
#   'blanch',
#   'jaun',
#   'cir',
#   'carnaub',
#   'concentr',
#   'fruit',
#   'plant',
#   'citrouill',
#   'pomm',
#   'paprik',
#   'tomat',
#   'carott',
#   'hibiscus',
#   'spirulin'],
#  ['sirop',
#   'glucos',
#   'gelatin',
#   'poisson',
#   'dextros',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'arom',
#   'enrobag',
#   'cir',
#   'abeil',
#   'blanch',
#   'cir',
#   'concentr',
#   'plant',
#   'citrouill',
#   'pomm',
#   'paprik',
#   'tomat',
#   'carott',
#   'hibiscus',
#   'sirop',
#   'sucr',
#   'invert'],
#  ['sirop',
#   'glucos',
#   'sucr',
#   'gelatin',
#   'dextros',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'arom',
#   'agent',
#   'enrobag',
#   'cir',
#   'abeil',
#   'blanch',
#   'jaun',
#   'cir',
#   'carnaub',
#   'concentr',
#   'fruit',
#   'plant',
#   'citrouill',
#   'pomm',
#   'paprik',
#   'tomat',
#   'carott',
#   'hibiscus',
#   'spirulin'],
#  ['sirop',
#   'glucos',
#   'sucr',
#   'amidon',
#   'gelatin',
#   'poisson',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'acid',
#   'maliqu',
#   'arom',
#   'concentr',
#   'fruit',
#   'plant',
#   'carott',
#   'hibiscus',
#   'agent',
#   'dan',
#   'emballag',
#   'ten',
#   'abri',
#   'chaleur'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'beurr',
#   'lait',
#   'eau',
#   'pure',
#   'ail',
#   'fibr',
#   'betterav',
#   'sucrier',
#   'levur',
#   'sel',
#   'jus',
#   'citron',
#   'persil',
#   'agent',
#   'trait',
#   'farin',
#   'acid',
#   'ascorb'],
#  ['ingredient',
#   'protein',
#   'soj',
#   'texture',
#   'san',
#   'oignon',
#   'fibr',
#   'soj',
#   'champignon',
#   'eau',
#   'gluten',
#   'ble',
#   'boulgour',
#   'ble',
#   'celer',
#   'carott',
#   'noix',
#   'fruit',
#   'coqu',
#   'avoin',
#   'poivron',
#   'doux',
#   'huil',
#   'tournesol',
#   'farin',
#   'riz',
#   'doux',
#   'sel',
#   'pure',
#   'tomat',
#   'pomm',
#   'terr',
#   'epic',
#   'ail',
#   'sucr',
#   'vinaigr',
#   'cidr',
#   'pomm',
#   'mel',
#   'vinaigr',
#   'cereal',
#   'grain',
#   'moutard',
#   'moulu',
#   'arom',
#   'naturel',
#   'fume',
#   'poivr',
#   'noir',
#   'huil',
#   'clous',
#   'girofl'],
#  ['tomat',
#   'eau',
#   'crem',
#   'lait',
#   'sucr',
#   'poivr',
#   'noir',
#   'moulu',
#   'ingredient',
#   'issu',
#   'agricultur',
#   'biolog',
#   'pour',
#   'le',
#   'allergen',
#   'le',
#   'ingredient',
#   'gras',
#   'votr',
#   'nous',
#   'vous',
#   'de',
#   'de',
#   'nous',
#   'suiv',
#   'san',
#   'ble'],
#  ['legum',
#   'oignon',
#   'tomat',
#   'concasse',
#   'poivron',
#   'courget',
#   'ail',
#   'chou',
#   'fris',
#   'pure',
#   'tomat',
#   'eau',
#   'pois',
#   'chich',
#   'riz',
#   'brun',
#   'champignon',
#   'huil',
#   'oliv',
#   'sel',
#   'marin',
#   'epic',
#   'basilic'],
#  ['vegetalien',
#   'eau',
#   'filtre',
#   'tomat',
#   'oignon',
#   'blanc',
#   'courget',
#   'champignon',
#   'riz',
#   'roug',
#   'cuit',
#   'poivron',
#   'roug',
#   'doux',
#   'huil',
#   'oliv',
#   'sel',
#   'marin',
#   'ail',
#   'epic',
#   'poivr',
#   'ingredient',
#   'issu',
#   'agricultur',
#   'biolog',
#   'votr',
#   'nous',
#   'vous',
#   'de',
#   'de',
#   'san',
#   'ble'],
#  ['eau',
#   'champignon',
#   'legum',
#   'oignon',
#   'poireau',
#   'celer',
#   'riz',
#   'crem',
#   'beurr',
#   'sel',
#   'marin',
#   'poudr',
#   'cep',
#   'epic',
#   'celer'],
#  ['legum',
#   'pure',
#   'tomat',
#   'courget',
#   'epinard',
#   'oignon',
#   'carott',
#   'feuill',
#   'riz',
#   'eau',
#   'filtre',
#   'fromag',
#   'mozzarel',
#   'ricott',
#   'fromag',
#   'blanc',
#   'huil',
#   'oliv',
#   'vierg',
#   'extra',
#   'basilic',
#   'fromag',
#   'italien',
#   'pat',
#   'dur',
#   'beurr',
#   'sel',
#   'marin',
#   'ail',
#   'epic'],
#  ['mozzarel',
#   'lait',
#   'vach',
#   'partiel',
#   'ecrem',
#   'farin',
#   'riz',
#   'pure',
#   'tomat',
#   'eau',
#   'filtre',
#   'farin',
#   'grain',
#   'tournesol',
#   'pomm',
#   'terr',
#   'fecul',
#   'tapioc',
#   'huil',
#   'oliv',
#   'jus',
#   'agav',
#   'huil',
#   'tournesol',
#   'oignon',
#   'roug',
#   'sel',
#   'marin',
#   'levur',
#   'miel',
#   'epic',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'ail',
#   'poivr',
#   'noir',
#   'contient',
#   'lait',
#   'soj',
#   'de',
#   'grain',
#   'tournesol'],
#  ['riz',
#   'cuit',
#   'riz',
#   'eau',
#   'champignon',
#   'eau',
#   'petit',
#   'pois',
#   'beurr',
#   'lait',
#   'fromag',
#   'italien',
#   'pat',
#   'dur',
#   'lait',
#   'oignon',
#   'sel',
#   'marin',
#   'poudr',
#   'cep',
#   'poivr',
#   'noir',
#   'agricultur',
#   'biolog'],
#  ['pat',
#   'riz',
#   'farin',
#   'riz',
#   'fecul',
#   'pomm',
#   'terr',
#   'fecul',
#   'riz',
#   'farin',
#   'soj',
#   'lait',
#   'brocol',
#   'cheddar',
#   'lait',
#   'beurr',
#   'lait',
#   'farin',
#   'riz',
#   'doux',
#   'farin',
#   'riz',
#   'eau',
#   'filtre',
#   'farin',
#   'grain',
#   'tournesol',
#   'pomm',
#   'terr',
#   'fecul',
#   'tapioc',
#   'sel',
#   'marin',
#   'jus',
#   'agav',
#   'huil',
#   'oliv',
#   'huil',
#   'tournesol',
#   'lecithin',
#   'soj',
#   'emulsifi',
#   'levur',
#   'rocou',
#   'color',
#   'ingredient',
#   'issu',
#   'agricultur',
#   'biolog'],
#  ['feuill',
#   'riz',
#   'pure',
#   'tomat',
#   'fromag',
#   'ricott',
#   'lait',
#   'eau',
#   'fromag',
#   'mozzarel',
#   'lait',
#   'oignon',
#   'courget',
#   'epinard',
#   'huil',
#   'oliv',
#   'carott',
#   'basilic',
#   'italien',
#   'pat',
#   'dur',
#   'lait',
#   'beurr',
#   'lait',
#   'sel',
#   'marin',
#   'ail',
#   'poivr',
#   'noir',
#   'epic',
#   'ingredient',
#   'issu',
#   'agricultur',
#   'biolog'],
#  ['lait',
#   'coco',
#   'sucr',
#   'cann',
#   'extrait',
#   'vanill',
#   'sel',
#   'mer',
#   'emulsifi',
#   'epaiss',
#   'gomm',
#   'guar',
#   'gouss',
#   'vanill',
#   'ingredient',
#   'issu',
#   'agricultur',
#   'biolog'],
#  ['lait',
#   'coco',
#   'sirop',
#   'agav',
#   'poudr',
#   'cacao',
#   'non',
#   'sucr',
#   'chocolat',
#   'noir',
#   'extrait',
#   'vanill',
#   'sel',
#   'mer',
#   'gomm',
#   'guar'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'beurr',
#   'lait',
#   'sucr',
#   'fecul',
#   'mais',
#   'sel',
#   'poudr',
#   'lev',
#   'bicarbonat',
#   'soud',
#   'arom',
#   'pour',
#   'le',
#   'voir',
#   'le',
#   'ingredient',
#   'indiqu',
#   'gras',
#   'convient',
#   'pas',
#   'aux',
#   'person',
#   'allerg',
#   'aux',
#   'de',
#   'method',
#   'fabriqu',
#   'conserv'],
#  ['pomm'],
#  ['spaghet',
#   'cuit',
#   'semoul',
#   'ble',
#   'dur',
#   'contient',
#   'gluten',
#   'eau',
#   'colz',
#   'tomat',
#   'boulet',
#   'viand',
#   'cuit',
#   'porc',
#   'cuit',
#   'boeuf',
#   'cuit',
#   'farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'persil',
#   'sel',
#   'origan',
#   'huil',
#   'colz',
#   'pure',
#   'ail',
#   'poivr',
#   'noir',
#   'conc',
#   'levur',
#   'eau',
#   'tomat',
#   'oignon',
#   'huil',
#   'colz',
#   'vin',
#   'roug',
#   'carott',
#   'celer',
#   'vinaigr',
#   'vin',
#   'roug',
#   'sucr',
#   'sel',
#   'fecul',
#   'mais',
#   'gelifi',
#   'pectin',
#   'poivr',
#   'noir',
#   'conc',
#   'romarin',
#   'origan',
#   'pour',
#   'le',
#   'allergen',
#   'voir',
#   'le',
#   'ingredient',
#   'indiqu',
#   'gras',
#   'import',
#   'apre',
#   'cuisson',
#   'retir',
#   'le',
#   'produit',
#   'chaud',
#   'avec',
#   'precaut',
#   'conten'],
#  ['farin',
#   'ble',
#   'contient',
#   'carbonat',
#   'calcium',
#   'fer',
#   'acid',
#   'thiamin',
#   'eau',
#   'beurr',
#   'ail',
#   'persil',
#   'sel',
#   'levur',
#   'farin',
#   'malt',
#   'agent',
#   'trait',
#   'farin',
#   'acid',
#   'ascorb'],
#  ['sucr',
#   'huil',
#   'palm',
#   'mass',
#   'cacao',
#   'beurr',
#   'cacao',
#   'lait',
#   'poudr',
#   'lait',
#   'sirop',
#   'glucos',
#   'caf',
#   'lait',
#   'poudr',
#   'enti',
#   'sirop',
#   'sucr',
#   'invert',
#   'lecithin',
#   'soj',
#   'cacao',
#   'maigr',
#   'poudr',
#   'arom',
#   'vanill',
#   'chocolat',
#   'blanc',
#   'contient',
#   'matier',
#   'minimum',
#   'chocolat',
#   'lait',
#   'contient',
#   'cacao',
#   'minimum',
#   'matier',
#   'sech',
#   'lait',
#   'minimum'],
#  ['sucr',
#   'fructos',
#   'acid',
#   'citriqu',
#   'contient',
#   'moin',
#   'arom',
#   'naturel',
#   'acid',
#   'ascorb',
#   'vitamin',
#   'maltodextrin',
#   'phosphat',
#   'calcium',
#   'gomm',
#   'guar',
#   'gomm',
#   'xanthan',
#   'agent',
#   'textur',
#   'pyrophosphat',
#   'acid',
#   'sodium',
#   'color',
#   'artificiel',
#   'bha',
#   'agent',
#   'saveur'],
#  ['cook',
#   'cream',
#   'facon',
#   'poid',
#   'net',
#   'ingredient',
#   'sucr',
#   'cook',
#   'farin',
#   'non',
#   'blanch',
#   'enrich',
#   'farin',
#   'ble',
#   'fer',
#   'reduit',
#   'vitamin',
#   'sucr',
#   'le',
#   'palm',
#   'etou',
#   'colz',
#   'cacao',
#   'agent',
#   'lev',
#   'sel',
#   'lecithin',
#   'soj',
#   'chocolat',
#   'amidon',
#   'mais',
#   'arom',
#   'artificiel',
#   'amidon',
#   'mais',
#   'modif',
#   'moin',
#   'epaiss',
#   'color',
#   'sel',
#   'antioxyd',
#   'contient',
#   'de',
#   'ogm',
#   'nutritionnel',
#   'pour',
#   'energ'],
#  ['noix',
#   'coco',
#   'biolog',
#   'rap',
#   'deshydrat',
#   'color',
#   'may',
#   'product',
#   'contain',
#   'produit',
#   'contient',
#   'aucun',
#   'sulfit',
#   'couleur',
#   'peut',
#   'vari'],
#  ['sucr',
#   'noiset',
#   'entier',
#   'beurr',
#   'cacao',
#   'lait',
#   'enti',
#   'deshydrat',
#   'pat',
#   'cacao',
#   'noiset',
#   'moulu',
#   'emulsifi',
#   'lecithin',
#   'soj',
#   'vanillin',
#   'arom'],
#  ['mass',
#   'cacao',
#   'sucr',
#   'beurr',
#   'cacao',
#   'cacao',
#   'poudr',
#   'miel',
#   'amand',
#   'blanc',
#   'oeuf',
#   'poudr',
#   'arom'],
#  ['mis',
#   'chocolat',
#   'noir',
#   'suiss',
#   'extra',
#   'fin',
#   'ngredient',
#   'mass',
#   'cacao',
#   'sucr',
#   'beurr',
#   'cacao',
#   'poudr',
#   'arin',
#   'chocolat',
#   'noir',
#   'contient',
#   'cacao',
#   'minimum',
#   'convient',
#   'pas',
#   'aux',
#   'person',
#   'fruit',
#   'coqu',
#   'aux',
#   'arachid',
#   'soj',
#   'raison',
#   'de',
#   'method',
#   'conserv',
#   'consomm',
#   'avant',
#   'voir',
#   'sur',
#   'dessous',
#   'conserv',
#   'preferent',
#   'dan',
#   'sec',
#   'abri',
#   'lumier'],
#  ['chocolat',
#   'noir',
#   'sucr',
#   'chocolat',
#   'non',
#   'sucr',
#   'beurr',
#   'cacao',
#   'lecithin',
#   'soj',
#   'polyricinoleat',
#   'arom',
#   'naturel',
#   'vanill',
#   'mais'],
#  ['farin',
#   'mais',
#   'huil',
#   'tournesol',
#   'piment',
#   'deshydrat',
#   'sel',
#   'sucr',
#   'oignon',
#   'deshydrat',
#   'tomat',
#   'deshydrate',
#   'extrait',
#   'levur',
#   'poivron',
#   'roug',
#   'deshydrat',
#   'ail',
#   'deshydrat',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'jus',
#   'citron',
#   'vert',
#   'deshydrat',
#   'poudr',
#   'piment',
#   'cumin',
#   'origan',
#   'piment',
#   'cayen',
#   'extrait',
#   'piment',
#   'extrait',
#   'coriandr',
#   'conserv'],
#  ['farin',
#   'ble',
#   'contient',
#   'gluten',
#   'avec',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'huil',
#   'palm',
#   'boeuf',
#   'hach',
#   'origin',
#   'britann',
#   'pomm',
#   'terr',
#   'oignon',
#   'eau',
#   'oeuf',
#   'pasteuris',
#   'huil',
#   'colz',
#   'fecul',
#   'mais',
#   'sel',
#   'bouillon',
#   'boeuf',
#   'eau',
#   'boeuf',
#   'pure',
#   'tomat',
#   'oignon',
#   'carott',
#   'lait',
#   'enti',
#   'poivr',
#   'noir',
#   'moulu',
#   'farin',
#   'moutard'],
#  ['eau',
#   'grain',
#   'moutard',
#   'vinaigr',
#   'sel',
#   'raifort',
#   'acid',
#   'citriqu',
#   'sulfit'],
#  ['eau',
#   'grain',
#   'moutard',
#   'poivron',
#   'roug',
#   'vin',
#   'blanc',
#   'huil',
#   'tournesol',
#   'sel',
#   'ail',
#   'herb',
#   'arom',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'conserv',
#   'sulfit'],
#  ['vinaigr',
#   'balsam',
#   'mout',
#   'raisin',
#   'color',
#   'caramel',
#   'conserv',
#   'metabisulfit',
#   'potassium'],
#  ['sucr',
#   'frambois',
#   'gelifi',
#   'pectin',
#   'agrum',
#   'regul',
#   'acidit',
#   'citrat',
#   'sodium',
#   'conserv',
#   'temperatur',
#   'ambi',
#   'avant',
#   'ouvertur',
#   'fabrique',
#   'par',
#   'son'],
#  ['sucr', 'myrtill', 'gelifi', 'pectin', 'agrum'],
#  ['sucr',
#   'gingembr',
#   'gelifi',
#   'pectin',
#   'agrum',
#   'regul',
#   'acidit',
#   'acid',
#   'citriqu'],
#  ['sucr', 'orang'],
#  ['sucr', 'orang', 'gingembr', 'gelifi', 'pectin', 'agrum'],
#  ['sucr', 'orang', 'pectin', 'agrum'],
#  ['marmelad',
#   'citron',
#   'vert',
#   'san',
#   'zest',
#   'prepare',
#   'avec',
#   'orang',
#   'pour',
#   'avec',
#   'citron',
#   'vert',
#   'total',
#   'sucr',
#   'pour',
#   'ient',
#   'sucr',
#   'orang',
#   'variet',
#   'citron',
#   'vert',
#   'huil',
#   'citron',
#   'vert',
#   'gelifi',
#   'pectin',
#   'agrum',
#   'acidit',
#   'citrat',
#   'temperatur',
#   'ambi',
#   'avant',
#   'fabrique',
#   'son',
#   'nutritionnel',
#   'pour',
#   'grass',
#   'acid',
#   'gras',
#   'satur'],
#  ['sucr',
#   'citron',
#   'regul',
#   'acidit',
#   'citrat',
#   'sodium',
#   'gelifi',
#   'pectin',
#   'agrum'],
#  ['marmelad',
#   'citron',
#   'avec',
#   'ecorc',
#   'moyen',
#   'prepare',
#   'avec',
#   'orang',
#   'pour',
#   'prepare',
#   'avec',
#   'citron',
#   'pour',
#   'teneur',
#   'total',
#   'sucr',
#   'pour',
#   'ingredient',
#   'sucr',
#   'orang',
#   'variet',
#   'citron',
#   'gelifi',
#   'pectin',
#   'agrum',
#   'regul',
#   'acidit',
#   'citrat',
#   'sodium'],
#  ['sugar', 'orang', 'lemon'],
#  ['raisin',
#   'sultan',
#   'corinth',
#   'raisin',
#   'sucr',
#   'cidr',
#   'chapelur',
#   'farin',
#   'ble',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'sel',
#   'levur',
#   'vegetal',
#   'huil',
#   'palm',
#   'huil',
#   'tournesol',
#   'farin',
#   'riz',
#   'melang',
#   'ecorc',
#   'ecorc',
#   'orang',
#   'ecorc',
#   'citron',
#   'sucr',
#   'sirop',
#   'glucos',
#   'fructos',
#   'sel',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'oeuf',
#   'entier',
#   'marmelad',
#   'orang',
#   'sucr',
#   'orang',
#   'brandy',
#   'farin',
#   'ble',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'melang',
#   'epic',
#   'sel'],
#  ['raisin',
#   'sultan',
#   'corinth',
#   'raisin',
#   'sucr',
#   'cidr',
#   'chapelur',
#   'farin',
#   'ble',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'sel',
#   'levur',
#   'vegetal',
#   'huil',
#   'palm',
#   'huil',
#   'toumesol',
#   'farin',
#   'riz',
#   'melang',
#   'ecorc',
#   'ecorc',
#   'orang',
#   'ecorc',
#   'citron',
#   'sucr',
#   'sirop',
#   'glucosefructos',
#   'sel',
#   'acidifi',
#   'acid',
#   'citriqu',
#   'oeuf',
#   'entier',
#   'marmelad',
#   'orang',
#   'sucr',
#   'orang',
#   'brandy',
#   'farin',
#   'ble',
#   'farin',
#   'ble',
#   'carbonat',
#   'calcium',
#   'fer',
#   'niacin',
#   'thiamin',
#   'melang',
#   'epic',
#   'sel',
#   'pour',
#   'le',
#   'allergen',
#   'le',
#   'cereal',
#   'conten',
#   'gluten',
#   'voir',
#   'le',
#   'ingredient',
#   'marqu',
#   'gras'],
#  ['sucr',
#   'beurr',
#   'lait',
#   'brandy',
#   'pour',
#   'le',
#   'allergen',
#   'voir',
#   'le',
#   'ingredient',
#   'marqu'],
#  ['sucr',
#   'beurr',
#   'sal',
#   'lait',
#   'jus',
#   'citron',
#   'jaun',
#   'oeuf',
#   'elevag',
#   'plein',
#   'air',
#   'entier',
#   'correcteur',
#   'acidit',
#   'acid',
#   'citriqu',
#   'gelifi',
#   'pectin',
#   'agrum',
#   'huil',
#   'citron'],
#  ['sucr',
#   'jus',
#   'fruit',
#   'passion',
#   'beurr',
#   'lait',
#   'jaun',
#   'oeuf',
#   'oeuf',
#   'enti',
#   'gelifi',
#   'pectin',
#   'agrum'],
#  ...]

# %%
def custom_tokenizer(text):
    return Doc(nlp_fr.vocab, tokenizer(text))

# %%
nlp_fr.tokenizer = custom_tokenizer

# %% [markdown]
# %%time
# doc_test = []
# for i in range(10000):
#     doc_test.append(nlp_fr(fr_db2.iloc[i]['ingredients_text']))

# %%
import gensim.models

# %%
class MyCorpus:
    """An iterator that yields sentences (lists of str)."""

    def __iter__(self):
        for ingredient_list in clean_data:
            yield ingredient_list

# %%
# %%time

sentences = MyCorpus()
model = gensim.models.Word2Vec(sentences=sentences)
# Out:
# Wall time: 7.18 s

# %%
# %%time

from sklearn.decomposition import IncrementalPCA    # inital reduction
from sklearn.manifold import TSNE                   # final reduction
import numpy as np                                  # array handling


def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    # extract the words & their vectors, as numpy arrays
    vectors = np.asarray(model.wv.vectors)
    labels = np.asarray(model.wv.index_to_key)  # fixed-width numpy strings

    # reduce using t-SNE
    tsne = TSNE(n_components=num_dimensions, random_state=0)
    vectors = tsne.fit_transform(vectors)

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels


x_vals, y_vals, labels = reduce_dimensions(model)

def plot_with_plotly(x_vals, y_vals, labels, plot_in_notebook=True):
    from plotly.offline import init_notebook_mode, iplot, plot
    import plotly.graph_objs as go

    trace = go.Scatter(x=x_vals, y=y_vals, mode='text', text=labels)
    data = [trace]

    if plot_in_notebook:
        init_notebook_mode(connected=True)
        iplot(data, filename='word-embedding-plot')
    else:
        plot(data, filename='word-embedding-plot.html')


def plot_with_matplotlib(x_vals, y_vals, labels):
    import matplotlib.pyplot as plt
    import random

    random.seed(0)

    plt.figure(figsize=(12, 12))
    plt.scatter(x_vals, y_vals)

    #
    # Label randomly subsampled 25 data points
    #
    indices = list(range(len(labels)))
    selected_indices = random.sample(indices, 25)
    for i in selected_indices:
        plt.annotate(labels[i], (x_vals[i], y_vals[i]))
# Out:
# C:\Users\licor\OneDrive\Documents\work\ESILV\S9\NLP\nlp_s9_env\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\licor\OneDrive\Documents\work\ESILV\S9\NLP\nlp_s9_env\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Wall time: 7.4 s

# %%
# %%time

try:
    get_ipython()
except Exception:
    plot_function = plot_with_matplotlib
else:
    plot_function = plot_with_plotly

plot_function(x_vals, y_vals, labels)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="35deac44-461c-4245-b13c-41b1b0dabd5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35deac44-461c-4245-b13c-41b1b0dabd5b")) {                    Plotly.newPlot(                        "35deac44-461c-4245-b13c-41b1b0dabd5b",                        [{"mode":"text","text":["sel","sucr","lait","eau","arom","ble","poudr","huil","farin","acid","naturel","cacao","oeuf","beurr","soj","amidon","sodium","tournesol","sirop","concentr","emulsifi","jus","pomm","extrait","conserv","fruit","glucos","porc","ecrem","oignon","color","colz","tomat","lecithin","epic","gluten","pat","grain","mais","origin","acidifi","citriqu","citron","de","poivr","antioxyd","crem","trac","viand","terr","ail","dextros","vegetal","protein","gomm","blanc","franc","contient","vinaigr","levur","epaiss","riz","vanill","biolog","chocolat","enti","gras","stabilis","moutard","ferment","pure","frais","coqu","carott","carbonat","ingredient","oliv","lev","agricultur","lactiqu","palm","conten","potassium","cann","noir","acidit","peut","alcool","lactos","modif","malt","noix","roug","aromat","bas","celer","ascorb","correcteur","graiss","dont","produit","poulet","orge","semoul","fromag","noiset","fructos","sesam","amand","coco","gelifi","issus","pasteuris","xanthan","poisson","vert","jaun","pectin","maigr","cuit","pour","dur","orang","vitamin","sulfit","matier","vin","mono","lactoserum","sauc","plant","caramel","grass","nitrit","dan","agent","persil","complet","diglycerid","paprik","guar","calcium","vierg","poivron","issu","extra","eventuel","piment","fecul","transform","le","raisin","flocon","legum","avec","pois","fibr","fraich","carraghenan","diphosphat","bio","sur","jambon","basilic","autr","maltodextrin","deshydrat","aux","frambois","san","avoin","citrat","cereal","sec","prepar","curcum","non","sorbat","miel","filet","arachid","vach","trait","marin","crustac","canard","presur","ammonium","boeuf","fin","caroub","invert","entier","gout","edulcor","ascorbat","thym","minimum","une","champignon","coriandr","romarin","seigl","abricot","herb","emmental","foi","gelatin","poireau","pulp","superieur","utilis","the","fabriqu","pech","mineral","fume","mer","mollusqu","gingembr","exhausteur","deshydrate","dind","sorbitol","bouillon","seche","fum","muscad","haricot","echalot","courget","caf","par","saumon","chapelur","enrobag","exprim","glycerol","origan","sont","morceau","guerand","froment","rehydrat","bicarbonat","cannel","melang","fleur","qualit","precuit","anan","phosphat","betterav","hydrogene","cru","ecorc","total","consomm","cass","chlorur","min","poul","tapioc","carotenoid","manioc","ceris","menth","dem","pourcentag","mangu","fev","liquid","cuisin","disod","banan","grille","est","caroten","coagul","lin","levain","boyau","inform","chevr","roux","cumin","pain","dijon","sal","reconstitu","poir","coprah","volaill","bovin","eleve","moulu","petit","pepit","garnitur","erythorbat","humect","ciboulet","ateli","pet","epinard","possibl","fer","allergen","bet","salaison","alimentair","lauri","caramelis","disulfit","acetat","pur","son","avant","palmist","crevet","magnesium","doux","lactat","nitrat","lentill","feuill","myrtill","epeautr","concentre","ordinair","cir","sech","quot","poid","poitrin","pas","plein","air","allerg","yaourt","patissi","saccharos","person","passion","confit","mis","voir","mozzarel","eclat","chich","aubergin","curcumin","sourc","aop","houblon","vanillin","acesulfam","provenc","sulfat","girofl","sucralos","grill","anhydr","qui","thon","ester","raffin","gazeifie","part","regul","enzym","niacin","atlant","arab","cuisson","quino","tocopherol","partiel","teneur","carmin","pasteurise","net","farc","glutamat","couen","presenc","paris","cacahuet","bai","proport","agar","pistach","margarin","blanch","a ...
# Wall time: 2.63 s

# %%
len(labels)
# Out:
# 2588
